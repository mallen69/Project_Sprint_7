# %% [markdown]
# # Shell, Operating Systems, Internet, Programming Language Basics
#
# ## Our Technology Stack
#
# Projects
# - Markdown Viewer
# - Github
# - The Internet
# - Github Desktop
# - Git
# - Programming Languages and Applications (R, Python, Excel, SQL, Tableau, Terminal/Emulator, Atom / Text Editor)
# - **Shell (Graphical User Interface / Command Line Interface)**
# - Operating System (Windows / macOS)
# - Laptop (CPU, Memory, Disk)
#
# Classroom Materials
# - Jupyter Notebooks Viewer
# - Github
# - The Internet
# - Github Desktop
# - Git
# - Jupyter Notebooks Browser Application
# - Browser
# - Jupyter Notebooks Server Application
# - Anaconda / Terminal / Emulator
# - **Shell (Graphical User Interface / Command Line Interface)**
# - Operating System (Windows / macOS)
# - Laptop (CPU, Memory, Disk)
#
#
#
# ## 6:00-7:00 Discussing The Shell and Graphical User Interface Operating Systems
#
# What is a shell?
# > In computing, a shell is a user interface for access to an operating system's services. In general, operating system shells use either a **command-line interface (CLI)** or graphical user interface (GUI), depending on a computer's role and particular operation. It is named a shell because it is the outermost layer around the operating system kernel.
#
# > https://en.wikipedia.org/wiki/Shell_(computing)
#
# > http://linuxcommand.org/lc3_lts0010.php
#
# What is an Operating System?
# > An operating system (OS) is system software that manages computer hardware and software resources and provides common services for computer programs. All computer programs, excluding firmware, require an operating system to function.
#
# > https://en.wikipedia.org/wiki/Operating_system
#
# Why Command lines?
# > The CLI was the primary means of interaction with most computer systems on computer terminals in the mid-1960s, and continued to be used throughout the 1970s and 1980s on OpenVMS, Unix systems and personal computer systems including MS-DOS, CP/M and Apple DOS. The interface is usually implemented with a command line shell, which is a program that accepts commands as text input and converts commands into appropriate operating system functions.
#
# >Command-line interfaces are often preferred by more advanced computer users, as they often provide a more concise and powerful means to control a program or operating system.
#
# > Programs with command-line interfaces are generally easier to automate via scripting.
# https://en.wikipedia.org/wiki/Command-line_interface
#
# 5 Benefits of Command Line Tools
# 1. Scalability
# 2. Scriptability
# 3. Simple Design
# 4. Simple Interface
# 5. Stable Design
# https://www.techrepublic.com/blog/linux-and-open-source/five-benefits-of-command-line-tools/
#
# A nice quick overview
# https://www.davidbaumgold.com/tutorials/command-line/
#
# Discussion Questions:
# - What does Windows do?
# - What does Mac OS do?
# - What is iPhone OS?
#
# https://www.wikihow.com/Make-a-Computer-Operating-System
# https://www.quora.com/What-goes-into-the-creation-of-an-operating-system

# %% [markdown]
# ## 7:00-8:00 How the Internet Works
#
# ** Featuring NAT!!!**
#
# [SLIDES](https://docs.google.com/presentation/d/1U6z_0LG_Z4ZEFdm3g2T84-Wp9AiChUiVfvKGogaaB1c/edit?usp=sharing)
#
# ### Key Terminology
# - **User:** a person who wants to view and interact with webpages using an internet-capable device, like a computer or smartphone.
# - **Client:** the User’s internet browser, running on his or her device.
# - **Server:** the computer—which could be anywhere in the world—where the desired website is hosted (stored).
# - **Local:** stored on, happening in, or otherwise pertaining to the environment of the User’s device.
# - **Remote:** stored on, happening in, or otherwise pertaining to the environment of the server.
#
# **Resources:**<br />
# Internet Protocols - http://searchunifiedcommunications.techtarget.com/definition/Internet-Protocol <br />
# How the Internet Works - https://blog.hubspot.com/marketing/how-the-internet-works <br />
# What is Server-side - https://developer.mozilla.org/en-US/docs/Learn/Server-side/First_steps/Introduction <br />
# Creating SSH key for GitHub - https://help.github.com/articles/generating-a-new-ssh-key-and-adding-it-to-the-ssh-agent/ <br />
# Intro to APIs - https://www.upwork.com/hiring/development/intro-to-apis-what-is-an-api/<br />
# CLI Command Cheatsheet for Mac Users - https://github.com/junior-devleague-educators/command-line-cheat-sheet-mac <br />
# AWS - https://aws.amazon.com/what-is-aws/<br />

# %% [markdown]
# ## 8:30-10:00 Programming Languages
#
# ### A Thought Exercise: How Do Apps work?
# #### The Basic Elements of Any Program / Application
# - Input
# - Computation
# - Output
#
# #### How do programs run on computers?
# 1.) They take input
# 2.) They run instructions in the CPU / machine language
# 3.) They display the machine output?
#
# #### What is Machine Language?
# >Machine code or machine language is a set of instructions executed directly by a computer's central processing unit (CPU). Each instruction performs a very specific task, such as a load, a jump, or an ALU operation on a unit of data in a CPU register or memory.
#
# >Numerical machine code (i.e., not assembly code) may be regarded as the lowest-level representation of a compiled or assembled computer program or as a primitive and hardware-dependent programming language. While it is possible to write programs directly in numerical machine code, it is tedious and error prone to manage individual bits and calculate numerical addresses and constants manually. For this reason, programs are almost never written directly in machine code in modern contexts.
# https://en.wikipedia.org/wiki/Machine_code
#
# ![Machine Code](machine.jpeg)
# Image of Machine Code
# By BigDumbDinosaur, representing BCS Technology Limited - Own work, CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=20228037
#
# #### How do humans write machine code?
# > All practical programs today are written in higher-level languages or assembly language. The source code is then translated to executable machine code by utilities such as compilers, assemblers, and linkers, with the important exception of interpreted programs,[1] which are not translated into machine code. However, the interpreter itself, which may be seen as an executor or processor, performing the instructions of the source code, typically consists of directly executable machine code (generated from assembly or high-level language source code).
# https://en.wikipedia.org/wiki/Machine_code
#
# #### What is a Programming Language?
# >A programming language is a formal language that specifies a set of instructions that can be used to produce various kinds of output. Programming languages generally consist of instructions for a computer. Programming languages can be used to create programs that implement specific algorithms.
# https://en.wikipedia.org/wiki/Programming_language
#
# #### Discussion Question?: What then is the relationship between programming languages, a computer, and apps?

# %% [markdown]
# ### What do programming languages need to work?
#
# #### Syntax = Grammar
# >In computer science, the syntax of a computer language is the set of rules that defines the combinations of symbols that are considered to be a correctly structured document or fragment in that language.
# https://en.wikipedia.org/wiki/Syntax_(programming_languages)
#
# > what if the English you speak/write had no grammar?
#
# >This is a similar concept except between you and your machine.  Without some type of formal language, it's fairly difficult to communicate.
# https://www.quora.com/Why-is-syntax-so-important-in-programming-Could-we-easily-change-the-syntax
#
# - expressions
# - statements
#
# #### Basic Elements of a Programming Language
#
# Let's go back to our description of what applications do. In the most general terms:
# - They take **Input**
# - They operate on the input, performing some **computation**
# - They produce **Output**
#
# What elements does a programming language need to build programs that can do this?
#
# Some good takes on it:
# - http://study.com/academy/lesson/5-basic-elements-of-programming.html
# - https://blog.programminghub.io/blog/2016/06/14/5-basic-concepts-programming-language/
# - https://www.cs.princeton.edu/courses/archive/fall12/cos109/10javascript.pdf
# - http://composingprograms.com/pages/12-elements-of-programming.html
# - http://www.assignmenthelp.net/assignment_help/elements-of-programming
#
# #### Input / Output
# - prints
# - loading data
# - reading from keyboard
# - mouse input
# - displaying charts
# - displaying windows, pixels
#
# #### Objects and Data Structures
# - Variables
# - Lists
# - Objects
#
# #### Conditional Flow and Control Structures
# - boolean
# - if / then / else
#
# #### Loops
# - for loops
# - while loops
# - looping conditions
#
# #### Functions / Subroutines
# - evaluation
# - parameters
# - return values
# - libraries
# - Methods
#
# Let's look at some of the functions we've called in our projects from last week.
#
# Discussion Questions:
# - What is procedural programming?
# - What is object oriented programming?
# - What is functional programming?

# %%
nums = [1,2,3,4,5,9,10,4,3,5]
for num in nums:
    if (num < 5):
        print("hello tori "+str(num))
        print ("between")
        new_var = num*10
        print(new_var)
    else:
        print("hello ben "+str(num))
        new_var = num*4
        print(new_var)
# Out:
# hello tori 1
# between
# 10
# hello tori 2
# between
# 20
# hello tori 3
# between
# 30
# hello tori 4
# between
# 40
# hello ben 5
# 20
# hello ben 9
# 36
# hello ben 10
# 40
# hello tori 4
# between
# 40
# hello tori 3
# between
# 30
# hello ben 5
# 20
