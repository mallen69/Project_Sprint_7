# %% [markdown]
# # HART Survey Data Exploratory Data Analysis Example
#
# *Introduction to the file: this is a dataset produced by an onboard bus survey intended to suppor the study of the rail project's impact on transit. There is an accompanying study, but I did not review it prior to this analysis. *
#
# Going into this analysis, I don't have any particular interest, just trying to assess the value of the dataset to any of my related interests. This could include characterizing people who ride the bus, understanding commute times, understanding which routes are most important, understanding what might make more people ride the bus and move away from driving personal vehicles for transportation

# %%
library(ggplot2)

# %%
library(tidyverse)

file.info("_bentrevino_files/HART_survey_data.csv")
# Out:
#                                        size     isdir mode mtime
# _bentrevino_files/HART_survey_data.csv 25448194 FALSE 644  2018-01-17 23:12:35
#                                        ctime               atime
# _bentrevino_files/HART_survey_data.csv 2018-01-23 16:23:38 2018-01-30 13:22:36
#                                        uid gid uname      grname
# _bentrevino_files/HART_survey_data.csv 501 20  bentrevino staff

# %% [markdown]
# ## Step 1: Load the file

# %%
tb = read.csv("_bentrevino_files/HART_survey_data.csv")

# %% [markdown]
# *It's worth noting that this file is 25MB which suggests a large file that might be slow to work with. Will probably want to get it down to be manageable for both performance and management*

# %% [markdown]
# ## Step 2: Get a sense for Variables

# %%
glimpse(tb)
# Out:
# Observations: 26,246
# Variables: 157
# Error in nchar(x): invalid multibyte string, element 46
# Traceback:
#
# 1. glimpse(tb)
# 2. glimpse.data.frame(tb)
# 3. str_trunc(formatted, data_width)
# 4. nchar(x)

# %% [markdown]
# We found out there are **26K rows ** and **157 variables/columns**
# looks like there's an error in the load somewhere. Probably in the formatting of one of the columns. May not be an issue if we filter down.
#
# 157 is a lot of variables to work with. Will see what I can get from summary and try to categorize or isolate interesting variables

# %%
summary(tb)
# Out:
#   ETC_ID_FINAL       ETC.ID             DATE           ROUTE
#  Min.   :    1   Min.   :   1   2012-04-26:  978   1      : 2033
#  1st Qu.: 6562   1st Qu.:1393   2012-05-14:  862   2      : 1952
#  Median :13124   Median :2144   2012-05-03:  848   A      : 1562
#  Mean   :13124   Mean   :3516   2012-04-24:  808   3      : 1511
#  3rd Qu.:19686   3rd Qu.:5553   2012-04-16:  789   40     : 1288
#  Max.   :26251   Max.   :9999   2012-05-08:  755   13     : 1152
#                                 (Other)   :21206   (Other):16748
#  Direction_Code Direction_Text VISITOR.2.HAWAII_Code VISITOR.2.HAWAII_Text
#  E:13468        East:13468     Min.   :1.000         No :24691
#  W:12778        West:12778     1st Qu.:2.000         Yes: 1555
#                                Median :2.000
#                                Mean   :1.941
#                                3rd Qu.:2.000
#                                Max.   :2.000
#
#  WHERE.VISITOR.LIVES_Code WHERE.VISITOR.LIVES_Text HOW.LONG.VISITING.HI_Code
#  Min.   :  1.00                     :24691         Min.   :1.000
#  1st Qu.: 11.00           California:  242         1st Qu.:1.000
#  Median : 53.00           Canada    :  142         Median :1.000
#  Mean   : 76.99           Australia :  138         Mean   :1.341
#  3rd Qu.:111.00           Japan     :  138         3rd Qu.:1.000
#  Max.   :282.00           Washington:   70         Max.   :4.000
#  NA's   :24691            (Other)   :  825         NA's   :24691
#      HOW.LONG.VISITING.HI_Text HOME.ADDRESS.TYPE_Code
#                   :24691       Min.   :1.000
#  1-2 months       :  124       1st Qu.:1.000
#  3-4 months       :   71       Median :1.000
#  5+ months        :   88       Mean   :1.039
#  less than 30 days: 1272       3rd Qu.:1.000
#                                Max.   :2.000
#
#                  HOME.ADDRESS.TYPE_Text                          HOME_ADDRESS
#  Home Street or Intersection:25217      SEE HOTEL DETAIL IN COLUMNS U-V: 1029
#  Hotel Information          : 1029      2280 Kuhio Ave                 :   79
#                                         3020 Waialae Ave               :   47
#                                         1545 Linapuni St               :   46
#                                         Kapiolani Blvd & Date St       :   41
#                                         1475 Linapuni St               :   39
#                                         (Other)                        :24965
#                            HOME_CITY         HOME_PLACE_GEOCODED
#  Honolulu                       :14510   Urban Honolulu:14728
#  Waipahu                        : 2135   Waipahu       : 1530
#  Waianae                        : 1315   Pearl City    :  818
#  Ewa Beach                      : 1180   East Honolulu :  692
#  SEE HOTEL DETAIL IN COLUMNS U-V: 1029   Kailua        :  530
#  Kapolei                        :  881   Ewa Beach     :  484
#  (Other)                        : 5196   (Other)       : 7464
#       HOME_STATE    HOME_ZIP_GIVEN  HOME_ZIP_GEOCODED HOME_HOTEL_Code
#  California:    1   Min.   :60467   Min.   :60467     Min.   : 1.00
#  Hawaii    :26244   1st Qu.:96792   1st Qu.:96792     1st Qu.:12.00
#  Illinois  :    1   Median :96815   Median :96815     Median :36.00
#                     Mean   :97042   Mean   :96795     Mean   :38.07
#                     3rd Qu.:96819   3rd Qu.:96818     3rd Qu.:56.00
#                     Max.   :99999   Max.   :99999     Max.   :99.00
#                                                       NA's   :25225
#                                                 HOME_HOTEL_Text
#                                                         :25217
#  Hilton Honolulu Hawaiian Village at 2005 Kalia Rd      :  119
#  Ambassador Hotel Of Waikiki at 2040 Kuhio Ave          :   43
#  Hyatt Regency Waikiki Resort & Spa at 2424 Kalakaua Ave:   37
#  Aston Hawaiian Waikiki Beach Hotel at 2570 Kalakaua Ave:   36
#  Pacific Beach Hotel at 2490 Kalakaua Ave               :   36
#  (Other)                                                :  758
#     HOME_LAT           HOME_LON          HOME_TAZ_FINAL  HOME_DISTRICT_FINAL
#  Min.   :19632734   Min.   :-159573791   Min.   :  2.0   Min.   : 1.0
#  1st Qu.:21297215   1st Qu.:-158001689   1st Qu.:157.0   1st Qu.: 5.0
#  Median :21331725   Median :-157863567   Median :334.0   Median :10.0
#  Mean   :21348889   Mean   :-157899551   Mean   :350.7   Mean   :11.1
#  3rd Qu.:21386107   3rd Qu.:-157827168   3rd Qu.:506.0   3rd Qu.:17.0
#  Max.   :41561239   Max.   : -87875607   Max.   :762.0   Max.   :26.0
#                                          NA's   :11      NA's   :11
#  ORIGIN_TYPE_Code                                             ORIGIN_TYPE_Text
#  Min.   : 1.000   Your HOME                                           :12565
#  1st Qu.: 2.000   Your WORKPLACE                                      : 5129
#  Median : 9.000   Shopping                                            : 2492
#  Mean   : 6.773   Social visit / church / personal / friend\xd5s house: 1471
#  3rd Qu.:10.000   College / University (students only)                : 1362
#  Max.   :11.000   School (grades K-12)                                :  935
#                   (Other)                                             : 2292
#         ORIGIN_TYPE_Other                             ORIGIN_NAME
#                  :25963   Home                              :12550
#  School          :   10   Work                              : 3528
#  Not provided    :    7   Store                             : 1233
#  Business        :    6   University of Hawaii at Manoa     :  531
#  Post office     :    5   Ala Moana Center                  :  315
#  Business meeting:    4   Hawaii Pacific University Honolulu:  227
#  (Other)         :  251   (Other)                           : 7862
#                 ORIGIN_ADDRESS     ORIGIN_CITY        ORIG_PLACE_GEOCODED
#  1450 Ala Moana Blvd   :  559   Honolulu :18186   Urban Honolulu:17400
#  2500 Campus Road      :  515   Waipahu  : 1526   Waipahu       : 1137
#  1164 Bishop Street    :  227   Waianae  :  864   Pearl City    :  729
#  4303 Diamond Head Road:  206   Ewa Beach:  744   East Honolulu :  599
#  1039 S. King Street   :  148   Kapolei  :  684   Kapolei       :  466
#  874 Dillingham Blvd   :  122   Aiea     :  678   Waimalu       :  434
#  (Other)               :24469   (Other)  : 3564   (Other)       : 5481
#  ORIGIN_STATE   ORIGIN_ZIP_GIVEN ORIG_ZIP_GEOCODED   ORIGIN_LAT
#  Hawaii:26246   99999  : 4716    Min.   :96701     Min.   :21256651
#                 96813  : 2249    1st Qu.:96797     1st Qu.:21293988
#                 96817  : 2181    Median :96815     Median :21315477
#                 96815  : 1895    Mean   :96800     Mean   :21336313
#                 96819  : 1829    3rd Qu.:96817     3rd Qu.:21360800
#                 96814  : 1821    Max.   :99999     Max.   :21705710
#                 (Other):11555
#    ORIGIN_LON         ORIG_TAZ_FINAL  ORIG_DISTRICT_FINAL
#  Min.   :-158229490   Min.   :  2.0   Min.   : 1.0
#  1st Qu.:-157936399   1st Qu.:167.0   1st Qu.: 4.0
#  Median :-157859564   Median :286.0   Median : 7.0
#  Mean   :-157889295   Mean   :316.5   Mean   :10.1
#  3rd Qu.:-157828570   3rd Qu.:441.0   3rd Qu.:15.0
#  Max.   :-157661183   Max.   :764.0   Max.   :26.0
#
#  MODE.FROM.ORIGIN.TO.BUS_Code
#  Min.   :1.000
#  1st Qu.:1.000
#  Median :1.000
#  Mean   :1.088
#  3rd Qu.:1.000
#  Max.   :8.000
#
#                                   MODE.FROM.ORIGIN.TO.BUS_Text
#  Bike                                           :  186
#  Drove alone and parked                         :  146
#  Drove or rode with others and parked           :   53
#  Other                                          :   22
#  Walk                                           :25256
#  Was dropped off by someone going someplace else:  540
#  Wheelchair/scooter                             :   43
#             DROPOFF.PLACE.OR.PARKING.LOCATION
#                              :25507
#  Mililani, 95-1101 Ukuwai St,:   39
#  Park and Ride Lot           :   17
#  Not Provided                :   16
#  Kapolei Transit Center East :   12
#  Royal Kunia, 94-640 Kupuohi :   11
#  (Other)                     :  644
#  MILES.BIKED.TO.FIRST.BUS.FROM.ORIGIN DESTIN_TYPE_Code
#  Min.   : 0.000                       Min.   : 1.000
#  1st Qu.: 0.200                       1st Qu.: 2.000
#  Median : 0.700                       Median : 8.000
#  Mean   : 1.126                       Mean   : 6.202
#  3rd Qu.: 1.000                       3rd Qu.:10.000
#  Max.   :10.000                       Max.   :11.000
#  NA's   :26060
#                                              DESTIN_TYPE_Text
#  Your HOME                                           :9790
#  Your WORKPLACE                                      :6273
#  Shopping                                            :2867
#  Social visit / church / personal / friend\xd5s house:2392
#  College / University (students only)                :1596
#  Recreation / sightseeing                            :1249
#  (Other)                                             :2079
#              DESTIN_TYPE_Other                             DESTIN_NAME
#                       :26027   Home                              :9752
#  School               :   12   Work                              :4348
#  Business             :    7   Store                             :1463
#  Language school      :    4   University of Hawaii at Manoa     : 604
#  Business meeting     :    3   Ala Moana Center                  : 372
#  Mid pacific institute:    3   Hawaii Pacific University Honolulu: 304
#  (Other)              :  190   (Other)                           :9403
#                          DESTIN_ADDRESS     DESTIN_CITY
#  1450 Ala Moana Blvd            :  811   Honolulu :18246
#  2500 Campus Road               :  587   Waipahu  : 1472
#  1164 Bishop Street             :  304   Waianae  :  799
#  4303 Diamond Head Road         :  242   Kapolei  :  763
#  Ala Moana Bl + Ala Moana Center:  161   Aiea     :  744
#  98-1025 Moanalua Rd            :  125   Ewa Beach:  687
#  (Other)                        :24016   (Other)  : 3535
#      DEST_PLACE_GEOCODED DESTIN_STATE   DESTIN_ZIP_GIVEN DEST_ZIP_GEOCODED
#  Urban Honolulu:17489    Hawaii:26246   Min.   :96701    Min.   :96701
#  Waipahu       : 1079                   1st Qu.:96813    1st Qu.:96797
#  Pearl City    :  738                   Median :96816    Median :96814
#  Kapolei       :  572                   Mean   :97452    Mean   :96799
#  East Honolulu :  537                   3rd Qu.:96822    3rd Qu.:96817
#  Waimalu       :  447                   Max.   :99999    Max.   :96863
#  (Other)       : 5384
#    DESTIN_LAT         DESTIN_LON         DEST_TAZ_FINAL  DEST_DISTRICT_FINAL
#  Min.   :21256273   Min.   :-158229349   Min.   :  1.0   Min.   : 1.0
#  1st Qu.:21293382   1st Qu.:-157934374   1st Qu.:177.0   1st Qu.: 4.0
#  Median :21312760   Median :-157859239   Median :276.0   Median : 7.0
#  Mean   :21334878   Mean   :-157888238   Mean   :315.2   Mean   :10.2
#  3rd Qu.:21356620   3rd Qu.:-157829799   3rd Qu.:440.0   3rd Qu.:16.0
#  Max.   :21703999   Max.   :-157651196   Max.   :762.0   Max.   :26.0
#
#  MODE.FROM.BUS.TO.DESTINATION_Code
#  Min.   :1.000
#  1st Qu.:1.000
#  Median :1.000
#  Mean   :1.061
#  3rd Qu.:1.000
#  Max.   :9.000
#
#                                 MODE.FROM.BUS.TO.DESTINATION_Text
#  Be picked up by someone                         :  251
#  Bike                                            :  172
#  Get in a parked vehicle & drive alone           :   89
#  Get in a parked vehicle & drive/ride with others:   44
#  Other                                           :   30
#  Walk                                            :25611
#  Wheelchair/scooter                              :   49
#                                             PICKUP.PLACE.OR.PARKING.LOCATION
#                                                             :25979
#  Mililani, 95-1101 Ukuwai St, Mililani                      :   27
#  Hawaii- Kai, 240 Keahole St, Honolulu                      :    9
#  Did Not Know                                               :    6
#  Park and Ride Lot                                          :    6
#  Kalanianaole Hwy & Kuliouou RdHonoluluHawaii9682121.2860729:    4
#  (Other)                                                    :  215
#  MILES.BIKED.TO.DESTIN.FROM.LAST.BUS TIME.BOARDED.BUS_Code
#  Min.   :0.000                       Min.   : 1.000
#  1st Qu.:0.000                       1st Qu.: 5.000
#  Median :0.000                       Median : 8.000
#  Mean   :0.756                       Mean   : 7.899
#  3rd Qu.:1.000                       3rd Qu.:11.000
#  Max.   :8.000                       Max.   :16.000
#  NA's   :26074
#    TIME.BOARDED.BUS_Text TIMEPERIOD_Code
#  4 - 5  p.m.  : 2314     A:5673
#  10 - 11  a.m.: 2193     M:9789
#  8 - 9  a.m.  : 2099     O:3059
#  9 - 10  a.m. : 2088     P:7725
#  11 - 12 a.m. : 2030
#  7 - 8  a.m.  : 1976
#  (Other)      :13546
#                              TIME.PERIOD_Text                 BOARDING.LOCATION
#  AM Peak (6am-9am)                   :5673    KONA ST OPP KEEAUMOKU ST :  516
#  MIDDAY (9am-2pm)                    :9789    S HOTEL ST BISHOP ST     :  435
#  Other Hours                         :1385    S BERETANIA ST PALI HWY B:  333
#  Other Hours (before 6am & after 6pm):1685    S KING ST PUNCHBOWL ST   :  329
#  PM PEAK (2pm-6pm)                   :7714    ALA MOANA BL ALA MOANA CE:  312
#                                               S BERETANIA ST PUNCHBOWL :  309
#                                               (Other)                  :24012
#  BOARDING_STOPID                  BOARDING_STOPNAME BOARDING_SEGMENT
#  Min.   :   1.0   KONA ST OPP KEEAUMOKU ST :  644   A      :4680
#  1st Qu.:  51.0   KALIHI TRANSIT CENTER - I:  573   B      :2776
#  Median : 171.0   S HOTEL ST BISHOP ST     :  486   C      :2654
#  Mean   : 255.7   S BERETANIA ST PALI HWY B:  409   E      :2361
#  3rd Qu.: 351.0   S BERETANIA ST PUNCHBOWL :  350   D      :2200
#  Max.   :1871.0   S KING ST PUNCHBOWL ST   :  334   G      :2133
#                   (Other)                  :23450   (Other):9442
#   BOARDING_LAT       BOARDING_LON        BOARDING_TAZ_FINAL
#  Min.   :21258444   Min.   :-158228553   Min.   :  2.0
#  1st Qu.:21293293   1st Qu.:-157924270   1st Qu.:185.0
#  Median :21311748   Median :-157859287   Median :264.0
#  Mean   :21333318   Mean   :-157888237   Mean   :310.6
#  3rd Qu.:21347863   3rd Qu.:-157833645   3rd Qu.:425.0
#  Max.   :21703454   Max.   :-157661800   Max.   :762.0
#
#  BOARDING_DISTRICT_FINAL                 ALIGHTING.LOCATION ALIGHTING_STOPID
#  Min.   : 1.00           S KING ST PUNCHBOWL ST   :  588    Min.   :   1.0
#  1st Qu.: 3.00           S HOTEL ST BISHOP ST     :  484    1st Qu.: 201.0
#  Median : 7.00           KAPIOLANI BL KEEAUMOKU ST:  350    Median : 351.0
#  Mean   : 9.35           S KING ST ALAKEA ST      :  322    Mean   : 414.7
#  3rd Qu.:14.00           S BERETANIA ST PUNCHBOWL :  309    3rd Qu.: 551.0
#  Max.   :26.00           KONA ST OPP KEEAUMOKU ST :  306    Max.   :2101.0
#                          (Other)                  :23887
#                      ALIGHTING_STOPNAME ALIGHTING_SEGMENT ALIGHTING.LAT
#  S KING ST PUNCHBOWL ST       :  633    G      : 3344     Min.   :21257182
#  S HOTEL ST BISHOP ST         :  535    H      : 2367     1st Qu.:21293600
#  S KING ST ALAKEA ST          :  455    F      : 2300     Median :21310486
#  KONA ST OPP KONA IKI ST - EOL:  410    I      : 2168     Mean   :21332374
#  KUHIO AVE SEASIDE AVE        :  394    J      : 2066     3rd Qu.:21347458
#  KAPIOLANI BL KEEAUMOKU ST    :  379    M      : 2060     Max.   :21703459
#  (Other)                      :23440    (Other):11941
#  ALIGHTING.LON        ALIGHTING_TAZ_FINAL ALIGHTING_DISTRICT_FINAL
#  Min.   :-158228552   Min.   :  1.0       Min.   : 1.000
#  1st Qu.:-157922566   1st Qu.:185.0       1st Qu.: 3.000
#  Median :-157859566   Median :258.0       Median : 7.000
#  Mean   :-157887554   Mean   :309.6       Mean   : 9.168
#  3rd Qu.:-157833989   3rd Qu.:424.0       3rd Qu.:14.000
#  Max.   :-157661800   Max.   :762.0       Max.   :26.000
#
#  TRANSFER.FROM.ANOTHER.BUS.BEFORE.BOARDING.THIS.BUS_Code
#  Min.   :1.000
#  1st Qu.:2.000
#  Median :2.000
#  Mean   :1.836
#  3rd Qu.:2.000
#  Max.   :2.000
#
#  TRANSFER.FROM.ANOTHER.BUS.BEFORE.BOARDING.THIS.BUS_Text
#  No :21929
#  Yes: 4317
#
#
#
#
#
#  ROUTE.JUST.TRANSFERRED.FROM WAS.THERE.A.PRIOR.TRANSFER_Code
#         :21929               Min.   :1.000
#  A      :  466               1st Qu.:2.000
#  1      :  349               Median :2.000
#  2      :  264               Mean   :1.944
#  UNK    :  199               3rd Qu.:2.000
#  3      :  195               Max.   :2.000
#  (Other): 2844               NA's   :21927
#  WAS.THERE.A.PRIOR.TRANSFER_Text ROUTE.FOR.PRIOR.TRANSFER
#     :21927                              :26002
#  No : 4075                       UN     :   26
#  Yes:  244                       1      :   15
#                                  43     :   12
#                                  A      :   12
#                                  2      :   10
#                                  (Other):  169
#  WERE.THERE.3.OR.MORE.TRANSFERS.BEFORE.BOARDING.THIS.BUS_Code
#  Min.   :1.000
#  1st Qu.:2.000
#  Median :2.000
#  Mean   :1.955
#  3rd Qu.:2.000
#  Max.   :2.000
#  NA's   :26004
#  WERE.THERE.3.OR.MORE.TRANSFERS.BEFORE.BOARDING.THIS.BUS_Text
#    :26004
#  No:  231
#  Ye:   11
#
#
#
#
#  TRANSFER.TO.ANOTHER.BUS.AFTER.THIS.BUS_Code
#  Min.   :1.000
#  1st Qu.:2.000
#  Median :2.000
#  Mean   :1.842
#  3rd Qu.:2.000
#  Max.   :2.000
#
#  TRANSFER.TO.ANOTHER.BUS.AFTER.THIS.BUS_Text X1ST.ROUTE.TRANSFER.TO
#  No :22091                                          :22091
#  Yes: 4155                                   A      :  390
#                                              1      :  366
#                                              2      :  327
#                                              3      :  217
#                                              42     :  181
#                                              (Other): 2674
#  WILL.TRANSFER.MORE.THAN.ONCE_Code WILL.TRANSFER.MORE.THAN.ONCE_Text
#  Min.   :1.000                        :22091
#  1st Qu.:2.000                     No : 3918
#  Median :2.000                     Yes:  237
#  Mean   :1.943
#  3rd Qu.:2.000
#  Max.   :2.000
#  NA's   :22091
#  X2ND.ROUTE.TRANSFER.TO WILL.TRANSFER.3.OR.MORE.TIMES_Code
#         :26009          Min.   :1.000
#  2      :   13          1st Qu.:2.000
#  9      :   12          Median :2.000
#  A      :   11          Mean   :1.932
#  C      :   11          3rd Qu.:2.000
#  3      :   10          Max.   :2.000
#  (Other):  180          NA's   :26009
#  WILL.TRANSFER.3.OR.MORE.TIMES_Text BOARDED.AT.ALA.MOANA.CENTER_Code
#     :26009                          Min.   :1.000
#  No :  221                          1st Qu.:2.000
#  Yes:   16                          Median :2.000
#                                     Mean   :1.931
#                                     3rd Qu.:2.000
#                                     Max.   :2.000
#
#  BOARDED.AT.ALA.MOANA.CENTER_Text REASON.VISITED.ALA.MOANA.CENTER_Code
#  No :24439                        Min.   :1.000
#  Yes: 1807                        1st Qu.:1.000
#                                   Median :2.000
#                                   Mean   :1.764
#                                   3rd Qu.:2.000
#                                   Max.   :3.000
#                                   NA's   :24439
#                                                                                                                                                                                    REASON.VISITED.ALA.MOANA.CENTER_Text
#                                                                                                                                                                                                      :24439
#  I was at Ala Moana Center to board a bus (or transfer to another bus) but I also did a few other things that were convenient to do while I was waiting, such as shopping, eating, using an ATM, etc.:  196
#  The main reason I was at Ala Moana Center was to board a bus or transfer to another bus                                                                                                             :  988
#  The main reason I was at Ala Moana Center was to go to work, shop, dine, or something other than board a bus or transfer to another bus                                                             :  623
#
#
#
#  IF.NO.TRANSIT.AVAILABLE_HOW.MAKE.TRIP_Code
#  Min.   :1.000
#  1st Qu.:1.000
#  Median :3.000
#  Mean   :3.121
#  3rd Qu.:4.000
#  Max.   :6.000
#
#       IF.NO.TRANSIT.AVAILABLE_HOW.MAKE.TRIP_Text
#  Drive myself              :4532
#  Drive with someone else   :7635
#  I could not make this trip:6979
#  Other                     : 293
#  Taxi                      :1661
#  Walk/Bike                 :5146
#
#  IF.NO.TRANSIT.AVAILABLE_HOW.MAKE.TRIP_Other HOW.LONG.RIDING.THE.BUS_Code
#            :25954                            Min.   :1.000
#  Not Sure  :   52                            1st Qu.:2.000
#  Buy a car :   40                            Median :4.000
#  Shuttle   :   27                            Mean   :4.053
#  Rent a car:   25                            3rd Qu.:6.000
#  Handivan  :   21                            Max.   :9.000
#  (Other)   :  127
#      HOW.LONG.RIDING.THE.BUS_Text DAYS.PER.WEEK.RIDE.THE.BUS_Code
#  more than 15 years:6633          Min.   :0.000
#  3 to 5 years      :5360          1st Qu.:5.000
#  1 to 2 years      :3592          Median :5.000
#  6 to 9 years      :3181          Mean   :5.523
#  Less than 1 year  :3172          3rd Qu.:7.000
#  10 to 14 years    :2753          Max.   :9.000
#  (Other)           :1555
#  DAYS.PER.WEEK.RIDE.THE.BUS_Text HOW.PAID.FOR.TRIP_Code
#  Five   :9085                    Min.   :1.000
#  Seven  :6437                    1st Qu.:2.000
#  Six    :2527                    Median :2.000
#  Four   :2396                    Mean   :2.417
#  Three  :1912                    3rd Qu.:3.000
#  Two    :1212                    Max.   :8.000
#  (Other):2677
#                      HOW.PAID.FOR.TRIP_Text FARE.DISCOUNTS_Code
#  Monthly Pass                   :12582      Min.   :1.000
#  One Way (Single Ride) Cash Fare: 6041      1st Qu.:1.000
#  Annual Pass                    : 3840      Median :1.000
#  U Pass                         : 3171      Mean   :1.597
#  Two Year Pass                  :  404      3rd Qu.:2.000
#  4-Day Pass                     :  135      Max.   :6.000
#  (Other)                        :   73
#     FARE.DISCOUNTS_Text VEHICLES.IN.HH_Code   VEHICLES.IN.HH_Text
#  Disability   : 2147    Min.   :0.000       Four or more:1282
#  None         :17568    1st Qu.:0.000       None        :9574
#  Senior       : 2244    Median :1.000       One         :8175
#  Student      : 4158    Mean   :1.406       Three       :2016
#  TheHandi-Van :   63    3rd Qu.:2.000       Two         :5199
#  U.S. Medicare:   66    Max.   :5.000
#
#  HOUSEHOLD.SIZE_Code HOUSEHOLD.SIZE_Text ADULTS.IN.HH_Code ADULTS.IN.HH_Text
#  Min.   : 1.000      Two    :8674        Min.   : 0.000    One    :8596
#  1st Qu.: 2.000      One    :6364        1st Qu.: 1.000    Two    :8281
#  Median : 3.000      Three  :5015        Median : 2.000    Three  :4608
#  Mean   : 2.954      Four   :3188        Mean   : 2.676    Four   :2502
#  3rd Qu.: 4.000      Five   :1418        3rd Qu.: 3.000    Five   :1102
#  Max.   :11.000      Six    : 655        Max.   :11.000    Six    : 476
#                      (Other): 932                          (Other): 681
#  EMPLOYMENT.STATUS_Code
#  Min.   :1.000
#  1st Qu.:1.000
#  Median :2.000
#  Mean   :2.252
#  3rd Qu.:4.000
#  Max.   :6.000
#
#                                       EMPLOYMENT.STATUS_Text
#  Employed full-time (at least 35 hours per week) :12173
#  Employed part-time (less than 35 hours per week): 5370
#  Homemaker                                       :  306
#  Not currently employed and not seeking work     : 4257
#  Not currently employed but seeking work         : 1691
#  Retired                                         : 2449
#
#  BEEN.TO.WORK.TODAY_Code BEEN.TO.WORK.TODAY_Text WILL.GO.TO.WORK.TODAY_Code
#  Min.   :1.00               : 8703               Min.   :1.000
#  1st Qu.:1.00            No :11400               1st Qu.:1.000
#  Median :2.00            Yes: 6143               Median :2.000
#  Mean   :1.65                                    Mean   :1.583
#  3rd Qu.:2.00                                    3rd Qu.:2.000
#  Max.   :2.00                                    Max.   :2.000
#  NA's   :8703                                    NA's   :8703
#  WILL.GO.TO.WORK.TODAY_Text STUDENT.STATUS_Code
#     : 8703                  Min.   :1.000
#  No :10222                  1st Qu.:1.000
#  Yes: 7321                  Median :1.000
#                             Mean   :1.448
#                             3rd Qu.:2.000
#                             Max.   :5.000
#
#                             STUDENT.STATUS_Text
#  Not a student                        :19242
#  Yes \xd0 Full Time college/university: 3844
#  Yes \xd0 Other                       :  381
#  Yes \xd0 Part Time college/university:  824
#  Yes \xd0 student thru 12th grade     : 1955
#
#
#                                                                                                     SCHOOL.NAME
#                                                                                                           :19242
#  Did Not Want to Provide                                                                                  : 3225
#  Not provided                                                                                             : 1237
#  University of Hawaii at Manoa @ 2500 Campus Road, Honolulu, HI 96822 ON Oahu (University)                :  565
#  Kapi`olani Community College @ 4303 Diamond Head Road, Honolulu, Hawaii 96816 ON Oahu (Community College):  228
#  Hawaii Pacific University Honolulu @ 1164 Bishop Street, Honolulu, Hawaii 96813 ON Oahu (University)     :  194
#  (Other)                                                                                                  : 1555
#  BEEN.TO.SCHOOL.TODAY_Code BEEN.TO.SCHOOL.TODAY_Text
#  Min.   :1.00                 :19242
#  1st Qu.:1.00              No : 3993
#  Median :2.00              Yes: 3011
#  Mean   :1.57
#  3rd Qu.:2.00
#  Max.   :2.00
#  NA's   :19242
#  WILL.GO.TO.SCHOOL.BEFORE.GOING.HOME_Code
#  Min.   :1.000
#  1st Qu.:1.000
#  Median :2.000
#  Mean   :1.634
#  3rd Qu.:2.000
#  Max.   :2.000
#  NA's   :19242
#  WILL.GO.TO.SCHOOL.BEFORE.GOING.HOME_Text DRIVER.LICENSE_Code
#     :19242                                Min.   :1.000
#  No : 4440                                1st Qu.:1.000
#  Yes: 2564                                Median :1.000
#                                           Mean   :1.469
#                                           3rd Qu.:2.000
#                                           Max.   :2.000
#
#  DRIVER.LICENSE_Text DISABILITY_Code DISABILITY_Text    AGE_Code
#  No :12317           Min.   :1.000   No :24829       Min.   :1.000
#  Yes:13929           1st Qu.:2.000   Yes: 1417       1st Qu.:2.000
#                      Median :2.000                   Median :4.000
#                      Mean   :1.946                   Mean   :3.838
#                      3rd Qu.:2.000                   3rd Qu.:5.000
#                      Max.   :2.000                   Max.   :7.000
#
#      AGE_Text    SPEAK.NON.ENGLISH.AT.HOME_Code SPEAK.NON.ENGLISH.AT.HOME_Text
#  18-24   :5900   Min.   :1.000                  No :17401
#  25-34   :4589   1st Qu.:1.000                  Yes: 8845
#  35-44   :3750   Median :2.000
#  45-54   :4152   Mean   :1.663
#  55-64   :3156   3rd Qu.:2.000
#  65+     :2627   Max.   :2.000
#  Under 18:2072
#  LANGUAGE.SPOKEN.AT.HOME_Code LANGUAGE.SPOKEN.AT.HOME_Text
#  Min.   :  2.0                        :17401
#  1st Qu.:159.0                TAGALOG : 1291
#  Median :489.0                Japanese: 1072
#  Mean   :383.8                Filipino: 1029
#  3rd Qu.:497.0                Ilocano :  973
#  Max.   :999.0                Spanish :  596
#  NA's   :17428                (Other) : 3884
#  LANGUAGE.SPOKEN.AT.HOME_Other  INCOME_Code                INCOME_Text
#         :26227                 Min.   : 1.000   Below $12,000    :3831
#  Po     :    7                 1st Qu.: 3.000   $15,000 - $29,999:3705
#  Am     :    3                 Median : 5.000   $30,000 - $39,999:3474
#  Ta     :    2                 Mean   : 5.058   $40,000 - $49,999:2788
#  Ne     :    1                 3rd Qu.: 7.000   $50,000 - $59,999:2670
#  Pa     :    1                 Max.   :13.000   $60,000 - $74,999:2234
#  (Other):    5                                  (Other)          :7544
#  FIRST.SURVEY.FOR.THE.BUS_Code FIRST.SURVEY.FOR.THE.BUS_Text ETHNICITY_Code
#  Min.   :1.00                  No : 3143                     Min.   : 1.000
#  1st Qu.:1.00                  Yes:23103                     1st Qu.: 2.000
#  Median :1.00                                                Median : 6.000
#  Mean   :1.12                                                Mean   : 5.522
#  3rd Qu.:1.00                                                3rd Qu.: 9.000
#  Max.   :2.00                                                Max.   :10.000
#
#                              ETHNICITY_Text  GENDER_Code    GENDER_Text
#  Pacific Islander or Native Hawaiian:6332   Min.   :1.000   Female:13974
#  White                              :6134   1st Qu.:1.000   Male  :12272
#  Asian Filipino                     :5147   Median :2.000
#  Asian Japanese                     :2855   Mean   :1.532
#  Asian-other                        :1892   3rd Qu.:2.000
#  Asian Chinese                      :1283   Max.   :2.000
#  (Other)                            :2603
#      Wgt.Fct.Name   UNLINKED_WGT_Factor TotalTransfers   LINKED_WGT_Factor
#  40-40a_E_M:  280   Min.   : 0.3333     Min.   :0.0000   Min.   :0.25
#  40-40a_W_M:  186   1st Qu.: 4.4380     1st Qu.:0.0000   1st Qu.:0.50
#  40-40a_W_A:  173   Median : 7.2286     Median :0.0000   Median :1.00
#  40-40a_W_P:  143   Mean   : 8.5297     Mean   :0.3421   Mean   :0.84
#  40-40a_E_P:  141   3rd Qu.:10.4566     3rd Qu.:1.0000   3rd Qu.:1.00
#  40-40a_W_O:   52   Max.   :35.1731     Max.   :3.0000   Max.   :1.00
#  (Other)   :25271
#   PURPOSE.Code               PURPOSE.Text
#  HBW    :10041   HomeBased Work    :10041
#  HBO    : 5362   HomeBased Other   : 5362
#  HBSH   : 3766   HomeBased Shopping: 3766
#  HBC    : 2456   HomeBased College : 2456
#  NHBO   : 1964   NonHomeBased Other: 1964
#  HBSC   : 1351   HomeBased School  : 1351
#  (Other): 1306   (Other)           : 1306

# %% [markdown]
# ## Step 3: Notes from looking through the summary
# - First ID column seems to just be a line number, and I can't make sense of ETC.ID
# - survey was conducted on several different dates... looks like primarily in 2012. 750-100 surveys per day on the top days shown. If that holds up looks like 30-60 days of surveys. ** Would like to follow up with complete look at dates and how many surveys done on each date **
# - Routes have up to 2000 surveys. Not sure what routes are used, but would be interested to see some information about the surveys per route. **Look at route data and see if can plot route data... maybe against route general ridership**
# - Direction is a factor ** This would be a logical thing to split on to compare **
# - Visitor to Hawaii looks interesting, but they make up a relatively small proportion (less than 10%) of bus ridership. Not sure how indicative they would be. **But could be interesting to compare the incidence of local vs visitor traffic as a proportion of surveys?**
# - Then there's generally a lot of visitor detail. Not sure the value for the 10% of riders surveyed. But perhaps if we were looking at visitor specific questions, this could be interesting.
# - There's a home city and home city geocoded column. Would probably be more interested in the **zip codes for mapping**. However, in the meantime a **bar chart for home places could be interesting if there weren't too many entries**
# - There's a home_lat and home_lon. Not sure how this is calculated... **could map to find out what's in there**. Or **could look at documentation on the data set**
# - The Origin Type Data looks strange.
# - Origin name looks more useful. Home and work give rise to questions about **Time of day that surveys took place...** but half are starting from home which seems to make sense in the overall balance of things
# - There is an origin address. These could be bus stops. ** One way to test the origin concept is to see if there are groupings of lats and lons or a lot of single origins **
# - **Mode looks like it could be kind of interesting**, but seems like all rows include walking. So it's really about other modes on top of walking
# - Could be interesting to compare destination to origin... homes don't line up exactly, so it would be interesting to see what that means, or what it suggests about the timing. ** That would be an interesting future question about transit use that this may be able to help define -- but only if questions about how the survey was conducted are answered **
# - Origin to Destination locations could be used to calculate ** Distance or path ** between the LAT/LON combinations
# - There are some general parameters for time periods. ** This is a key to plot**
# - There are also boardings and these might be different from the origin and destination locations. So could ** Map the differences in the origins and boardings ** this could get interesting to see what the catchment around a given station looks like
# - There is also transfer information. Looks like maybe 20% were transfer. So there could be a semi interesting transfer study in there... Would need to compare to the main data set and the overall transit ridership
# - questions about boarding at ala moana specifically
# - here's an interesting one ** If No transit was available, how would you go **
# - How **long riding the bus, Pass Status, and fare discounts** all interesting as well. Could be subject of different direction of study.
# - Employment status (working currently, full time part time, etc) and household size could be used to **characterize bus riders**
# - Student status is another one
# - Drivers License status could be an interesting ID question and equity issue. Preliminary, only about half have drivers licenses. ** Voter registration? **
# - Language and ethnicity would also be interesting.
# - Purpose of Trip seems like it could correlate to other fields. **Might be worth looking into to understand how to use the information and if it's accurate**

# %% [markdown]
# Chart Reference:
# www.stat.wisc.edu/~larget/stat302/chap2.pdf

# %% [markdown]
# ## Date Bar Chart

# %%
ggplot(tb, aes(x=DATE)) + geom_bar()
# Out:
# plot without title

# %%
ggplot(tb, aes(x = reorder(DATE, -table(DATE)[DATE]), fill=Direction_Code)) + geom_bar()
# Out:
# plot without title

# %% [markdown]
# ## Route Bar Chart

# %%
ggplot(tb, aes(x=ROUTE)) + geom_bar()
# Out:
# plot without title

# %%
ggplot(tb, aes(x=ROUTE, fill=Direction_Code)) + geom_bar()
# Out:
# plot without title

# %% [markdown]
# ## Home Place Geocoded Bar Chart

# %%
ggplot(tb, aes(x=HOME_PLACE_GEOCODED)) + geom_bar()
ggplot(tb, aes(x=HOME_PLACE_GEOCODED, fill=Direction_Code)) + geom_bar()
# Out:
# plot without title
# plot without title

# %%
## Route Bar Chart
ggplot(tb, aes(x=HOW.PAID.FOR.TRIP_Text, fill=Direction_Code)) + geom_bar()
# Out:
# plot without title
# plot without title

# %%
ggplot(tb, aes(x=FARE.DISCOUNTS_Text, fill=Direction_Code)) + geom_bar()
# Out:
# plot without title

# %%
    #ggplot(tb, aes(x = reorder(varname, -table(varname)[varname]), fill=Direction_Code)) + geom_bar()


ew_plot = function(p1) {
    ggplot(tb, aes_string(x = p1, fill='Direction_Code')) + geom_bar()
}

hart_vars = c('DATE', 'ROUTE','HOME_PLACE_GEOCODED' ,'FARE.DISCOUNTS_Text', 'HOW.PAID.FOR.TRIP_Text')

lapply(hart_vars, ew_plot)
# Out:
# plot without title
# plot without title
# plot without title
# [[1]]
#
# [[2]]
#
# [[3]]
#
# [[4]]
#
# [[5]]
# plot without title
# plot without title

# %%
factors(tb %>% select(FARE.DISCOUNTS_Text, HOW.PAID.FOR.TRIP_Text))
# Out:
# Error in factors(tb %>% select(FARE.DISCOUNTS_Text, HOW.PAID.FOR.TRIP_Text)): could not find function "factors"
# Traceback:
