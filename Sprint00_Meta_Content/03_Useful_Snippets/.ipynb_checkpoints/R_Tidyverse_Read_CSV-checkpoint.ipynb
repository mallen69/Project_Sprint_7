# %%
library(tidyverse)
hart_tb = read_csv('_bentrevino_files/HART_survey_data.csv')
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   ETC_ID_FINAL = col_integer(),
#   `ETC ID` = col_integer(),
#   DATE = col_date(format = ""),
#   `VISITOR 2 HAWAII_Code` = col_integer(),
#   `WHERE VISITOR LIVES_Code` = col_integer(),
#   `HOW LONG VISITING HI_Code` = col_integer(),
#   `HOME ADDRESS TYPE_Code` = col_integer(),
#   HOME_ZIP_GIVEN = col_integer(),
#   HOME_ZIP_GEOCODED = col_integer(),
#   HOME_HOTEL_Code = col_integer(),
#   HOME_LAT = col_integer(),
#   HOME_LON = col_integer(),
#   HOME_TAZ_FINAL = col_integer(),
#   HOME_DISTRICT_FINAL = col_integer(),
#   ORIGIN_TYPE_Code = col_integer(),
#   ORIG_ZIP_GEOCODED = col_integer(),
#   ORIGIN_LAT = col_integer(),
#   ORIGIN_LON = col_integer(),
#   ORIG_TAZ_FINAL = col_integer(),
#   ORIG_DISTRICT_FINAL = col_integer()
#   # ... with 56 more columns
# )
# See spec(...) for full column specifications.

# %%
print(typeof(hart_tb))
print(class(hart_tb))
# Out:
# [1] "list"
# [1] "tbl_df"     "tbl"        "data.frame"

# %%
hart_tb
# Out:
#       ETC_ID_FINAL ETC ID DATE       ROUTE Direction_Code Direction_Text
# 1      1            1     2012-04-02 2     E              East
# 2      2            2     2012-04-02 2     E              East
# 3      3            3     2012-04-02 2     E              East
# 4      4            4     2012-04-02 2     E              East
# 5      5            5     2012-04-02 2     E              East
# 6      6            6     2012-04-02 2     E              East
# 7      7            7     2012-04-02 2     E              East
# 8      8            8     2012-04-02 2     E              East
# 9      9            9     2012-04-02 2     E              East
# 10    10           10     2012-04-02 2     E              East
# 11    11           11     2012-04-02 2     E              East
# 12    12           12     2012-04-02 2     E              East
# 13    13           13     2012-04-02 2     W              West
# 14    14           14     2012-04-02 2     E              East
# ...
