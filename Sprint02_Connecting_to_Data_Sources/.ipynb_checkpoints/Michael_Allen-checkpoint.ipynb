# %% [markdown]
# ### 11/30/2017 Michael Allen Sprint 2
#
# ###3 Description: Create an "End of Sprint Survey" in Google Forms and read the survey results in R.  And then create a script in R to automate (simplify) the process of reading it into R.
#
# ## Skill Backlog User Story
#
# (Using Bayesian Statistical Theory):
# As a Technology Teacher I need to get exposed to Google Forms and Google Sheets and create a Survey with Google Forms instead of SurveyMonkey (as there are limitations without a paid subscriptionn so that I am able to read the Google Form Survey data in R, and to understand a basic R script.
#
# ## Project Proposal
# This is what I propose to do in this project and why I think it will be useful to me and my overall objective
#
# ## Key Questions
# - Things I want to find out
# - Definitions I want to establish and clarify
#
# ## Key Findings
# - A running list of things that I'm learning and don't want to forget
#
# ## Gameplan
# Here is my overall approach
# 1. Step 1
# 2. Step 2
# 3. Step 3
# 4. Step 4
#
# ---
#
# ## Day 1 Work
#
# This is what I tried to do on Day 1. Here's some Code
#
# ## Day 2 Work
#
# This is what I tried to do on Day 2. Here's some more code
#
# ## Peer Feedback on Day 3
#
# After talking it over with a peer, I received the following feedback and decided to make these changes
#
# ## Here are some overall notes on the skills I learned
# And perhaps some stream of consciousness notes about what I did, and other questions I might have

# %% [markdown]
# Sprint 2:
#
# Story Board: Sprint 2 - (Using Bayesian Statistical Theory): As a Technology Teacher: I need to get exposed to Google Forms (and possibly Google Sheets) and create Surveys with Google Forms instead of SurveyMonkey (as there are limitations without paid subscriptions), be able to read the Google Form Survey data in R, and to understand basic R scripting
#
# R Scripting:
#
# https://cran.r-project.org/doc/contrib/Lemon-kickstart/kr_scrpt.html
#
# So what is an R script? An R script is simply a text file containing (almost) the same commands that you would enter on the command line of R. (almost) refers to the fact that if you are using sink() to send the output to a file, you will have to enclose some commands in print() to get the same output as on the command line. To run a script, let's say one with the name: /home/jim/psych/adoldrug/partyuse1.R you may either use: source("/home/jim/psych/adoldrug/partyuse1.R") on the command line of R OR R CMD BATCH /home/jim/psych/adoldrug/partyuse1.R Let's pause to note a little historical bifurcation that has caused almost as much strife as the question of exactly what the
# store the current directory
#
# initial.dir<-getwd()
# change to the new directory
#
# setwd("/home/jim/psych/risk/adol")
# load the necessary libraries
#
# library(nlme)
# set the output file
#
# sink("adolrisk03.out")
# load the dataset
#
# ...
# close the output file
#
# sink()
# unload the libraries
#
# detach("package:nlme")
# change back to the original directory
#
# setwd(initial.dir) First notice that the script stores the initial directory and changes to the directory where the data is, and where output will be generated. The libraries necessary for the analysis are then loaded. Finally, the output of the script is directed to a text file, producing a record of the analysis. Then comes the action. After the analysis has been completed, the output file is closed, the libraries are unloaded, and the directory is changed back to where the scripts reside. At this point, you may want to start another script or shut down R.
#
# Annotating the output file R's output can often be terse. Annotating it will make it much easier for someone unfamiliar with R or statistical analysis to understand.
#
# cat("\nMean risk-taking scores for all groups\n\n") brkdn(risk~group,adolrisk03.df) Here cat() is used to label a breakdown of means, leaving a blank line above and two below the label. Spacing the output with meaningful labels improves the appearance and comprehensibility.
# Sprint 2 (Initial Day Statements)
#
# I enrolled in this class: Because it helps to keep me off the streets and learn about big data.
#
# I am most worried about: Successfully learning and getting thru this program!
#
# I learn best: When attending a class with a patient instructor & peers who instill confidence during lecture, having hands on practice conducive to learning in class, and plenty of time outside of class to study and practice!
#
# I am most excited about: Learning about big data because it will be a necessity to know and understand in the future.
#
# After this class I hope to:
# Have the confidence and qualifications to secure a teaching position utilizing the skills and knowledge acquired during this program.
#
# My dream job is:
# To teach online (Quantitative Analysis / Telecommunications / Big Data..?) with part-time face-to-face delivery in Hawaii and/or San Francisco.
#
# Expectations for Big Data Analyst Track: Articulate your expecations for this class in as much detail as you need. A response that is helpful to both you and your cohort may include statements such as:
#
# After this class I expect to be able to: Be compfortable working with big data and understand the basics of what it entails.
#
# I expect this classroom and environment to support my goals and objectives by: Providing a learning environment which teaches me skills that I and an employer find useful and valuable.
#
# In reaching my goals, my coaches and cohort are responsible for: Providing a supportive learning environment.
#
# In reaching my goals, I am responsible for my own learning with the necessary support from my coaches.
#
# Expectations for Myself:
#
# Describe your objectives and vision for yourself, particularly as it pertains to the skills you will learn as part of this class.
#
# Here is how I envision my life / myself will look after I complete this class: To have the necessary skills and knowledge to tackle big data questions as the need arises.
#
# This is the type of job I can imagine myself working in after I complete this class: Part-time online/face-to-face teaching position which utilizes some of the knowledge and skills acquired throughout this program.
#
# This is what I would like to be doing 6 months after this class ends: Part-time online/face-to-face teaching position which utilizes some of the knowledge and skills acquired throughout this program in addition to developing a short-course (half day) for survey analysis utilizing some of the skills acquired thoughout this program
#
# What I want most out of life is to... and this is supporting that desire: To continue to have a good balance between work and play, by learning new skills that are sought after.
# My R commands that I sent to myself
#
# read.csv("Simulated Survey Data II/CSV/Mock Survey Data.csv",header = TRUE,skip = 1)
#
# updated_survey = read.csv("Simulated Survey Data II/CSV/Mock Survey Data.csv",header = TRUE,skip = 1)
#
# updated_survey
#
# colnames<-`(update_survey[1],"Course")
#
# Per Justin: on slack
#
# colnames(updated_survey) <- c("column_header1", "column_header2", "column_header3, ...")
#
# colnames(update_survey) <- c("column_header1", "column_header2", "column_header3")
#
# colnames(updated_survey) <- c("Course", "Instructor", "Experience", "Instructors Lecture", "Reponse to Questions", "Pace", "Length","Support Portals", "Sprints", "Classroom")
#
# updated_survey
# Created new End of Sprint Survey in Google Forms
#
# Same ten questions as before.
# link to new google forms survey
#
# https://goo.gl/forms/kO8XziFjHinbA1Rv2
# Calculating the means of the various columns.
#
# In the current state, the column Pace is returning an "NA" due to a blank field. Looking to try and fix that below
#
# mean(updated_survey[["Pace"]]) [1] NA
#
# mean(updated_survey[["Classroom"]]) [1] 25.65217
#
# mean(updated_survey[["Length"]]) [1] 36.08696
#
# mean(updated_survey[["Support Portals"]]) [1] 36.08696
#
# mean(updated_survey[["Length"]]) [1] 36.08696
#
# mean(updated_survey[["Instructors Lecture"]]) [1] 35.65217
#
# mean(updated_survey[["Response to Questions"]]) [1] NA
# Trying to fix the empty cell which becomes an NA
#
# This command below simply changed it to a 0 (zero) which would then screw up calculations
#
# updated_survey[c('Pace')][is.na(updated_survey[c('Pace')])] <- 0
# Justin need help ...!!
#
# https://stats.idre.ucla.edu/r/faq/how-does-r-handle-missing-values/
# Five Pitches for the 11/29/2017 Session for Sprint Number 2
#
# 1. Since SurveyMonkey requires a subscription in order to export data (also to have more than ten questions) so instead create the "End of Sprint Survey" in Google Forms (per Hunter and Justin's suggestion) and to write a script to read the output in R.
#
#     Write a script which takes the Text of the answers and turns it into a value "Strongly Agree" = 40, "Agree" = 30, "Disagree" = 20, "Strongly Disagree" = 10
#
#     To write a script in R which cleans any field that is not filled out (currently gives a NA Value) so as not to mess up any calculations.
#
#     Take existing "End of Course Survey" data which is in Excel and begin to look at it in "R".
#
#     Take a previous Macro (Script) in Excel that my former Manager (Bosses Boss) wrote in order to help clean the data being exported from SurveyMonkey to Excel.
#
# Game Plan 1
#
# Create Version 1.0 "End of Sprint Survey" in Google Forms Images of Survey Below
#
# Trying to Read Google sheets into R (after filling out a few of the surveys and then reading / creating the info into google sheets
#
# Downloaded the install.packages("googlesheets")
# Which gave me this result:
#
# Installing package into ‘C:/Users/micha/Documents/R/win-library/3.4’ (as ‘lib’ is unspecified) also installing the dependencies ‘bindr’, ‘rematch’, ‘tibble’, ‘assertthat’, ‘bindrcpp’, ‘glue’, ‘pkgconfig’, ‘rlang’, ‘BH’, ‘plogr’, ‘hms’, ‘tidyselect’, ‘cellranger’, ‘dplyr’, ‘purrr’, ‘readr’, ‘tidyr’, ‘xml2’
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/bindr_0.1.zip' Content type 'application/zip' length 14967 bytes (14 KB) downloaded 14 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/rematch_1.0.1.zip' Content type 'application/zip' length 14619 bytes (14 KB) downloaded 14 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/tibble_1.3.4.zip' Content type 'application/zip' length 675890 bytes (660 KB) downloaded 660 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/assertthat_0.2.0.zip' Content type 'application/zip' length 43876 bytes (42 KB) downloaded 42 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/bindrcpp_0.2.zip' Content type 'application/zip' length 639197 bytes (624 KB) downloaded 624 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/glue_1.2.0.zip' Content type 'application/zip' length 75945 bytes (74 KB) downloaded 74 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/pkgconfig_2.0.1.zip' Content type 'application/zip' length 20016 bytes (19 KB) downloaded 19 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/rlang_0.1.4.zip' Content type 'application/zip' length 465175 bytes (454 KB) downloaded 454 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/BH_1.65.0-1.zip' Content type 'application/zip' length 17006683 bytes (16.2 MB) downloaded 16.2 MB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/plogr_0.1-1.zip' Content type 'application/zip' length 17918 bytes (17 KB) downloaded 17 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/hms_0.4.0.zip' Content type 'application/zip' length 33288 bytes (32 KB) downloaded 32 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/tidyselect_0.2.3.zip' Content type 'application/zip' length 624406 bytes (609 KB) downloaded 609 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/cellranger_1.1.0.zip' Content type 'application/zip' length 75545 bytes (73 KB) downloaded 73 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/dplyr_0.7.4.zip' Content type 'application/zip' length 2883837 bytes (2.8 MB) downloaded 2.8 MB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/purrr_0.2.4.zip' Content type 'application/zip' length 243143 bytes (237 KB) downloaded 237 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/readr_1.1.1.zip' Content type 'application/zip' length 1272745 bytes (1.2 MB) downloaded 1.2 MB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/tidyr_0.7.2.zip' Content type 'application/zip' length 894490 bytes (873 KB) downloaded 873 KB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/xml2_1.1.1.zip' Content type 'application/zip' length 3529076 bytes (3.4 MB) downloaded 3.4 MB
#
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/googlesheets_0.2.2.zip' Content type 'application/zip' length 1631886 bytes (1.6 MB) downloaded 1.6 MB
#
# package ‘bindr’ successfully unpacked and MD5 sums checked package ‘rematch’ successfully unpacked and MD5 sums checked package ‘tibble’ successfully unpacked and MD5 sums checked package ‘assertthat’ successfully unpacked and MD5 sums checked package ‘bindrcpp’ successfully unpacked and MD5 sums checked package ‘glue’ successfully unpacked and MD5 sums checked package ‘pkgconfig’ successfully unpacked and MD5 sums checked package ‘rlang’ successfully unpacked and MD5 sums checked package ‘BH’ successfully unpacked and MD5 sums checked package ‘plogr’ successfully unpacked and MD5 sums checked package ‘hms’ successfully unpacked and MD5 sums checked package ‘tidyselect’ successfully unpacked and MD5 sums checked package ‘cellranger’ successfully unpacked and MD5 sums checked package ‘dplyr’ successfully unpacked and MD5 sums checked package ‘purrr’ successfully unpacked and MD5 sums checked package ‘readr’ successfully unpacked and MD5 sums checked package ‘tidyr’ successfully unpacked and MD5 sums checked package ‘xml2’ successfully unpacked and MD5 sums checked package ‘googlesheets’ successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in C:\Users\micha\AppData\Local\Temp\RtmpALotuU\downloaded_packages
# In addition installed the library install.packages('gsheet')
#
# Installing package into ‘C:/Users/micha/Documents/R/win-library/3.4’ (as ‘lib’ is unspecified) trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/gsheet_0.4.2.zip' Content type 'application/zip' length 16864 bytes (16 KB) downloaded 16 KB
#
# package ‘gsheet’ successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in C:\Users\micha\AppData\Local\Temp\RtmpALotuU\downloaded_packages
# getwd()
#
# [1] "C:/Users/micha/Documents"
#
#     michael <- 'docs.google.com/spreadsheets/d/1MTAfHE2KQ0zmFdTo7VywUCZW_Hl039UHxelgculBaxo/edit#gid=1617586725' michael [1] "docs.google.com/spreadsheets/d/1MTAfHE2KQ0zmFdTo7VywUCZW_Hl039UHxelgculBaxo/edit#gid=1617586725" nv<-
#
#         michael nv [1] "docs.google.com/spreadsheets/d/1MTAfHE2KQ0zmFdTo7VywUCZW_Hl039UHxelgculBaxo/edit#gid=1617586725" library(googlesheets) Warning message: package ‘googlesheets’ was built under R version 3.4.2 gs_ls() Adding .httr-oauth to .gitignore Waiting for authentication in browser... Press Esc/Ctrl + C to abort Authentication complete. # A tibble: 4 x 10
#
#                  sheet_title        author  perm version             updated sheet_key
#                        <chr>         <chr> <chr>   <chr>              <dttm>     <chr>
#
#         1 End of Sprint Survey (R… michael.nj.a… rw new 2017-11-30 09:23:54 1MTAfHE2… 2 End of Course Survey michael.nj.a… rw new 2017-11-30 04:53:11 1MM3nuCI… 3 Travel Comp'd Time jim.pellegri… rw new 2017-07-13 20:34:03 1CSgMLhq… 4 cobra arra billing mike… michael.nj.a… rw new 2010-02-08 00:00:27 1_n42isC… # ... with 4 more variables: ws_feed

# %% [markdown]
# ### getting R to read a google sheet
#
# get()
# Error in get() : argument "x" is missing, with no default
# > getwd()
# [1] "C:/Users/micha/Documents"
# > library(googlesheets)
# Warning message:
# package ‘googlesheets’ was built under R version 3.4.2
# > spreadsheet_names
#                             sheet_title           author perm version             updated                                    sheet_key
# 1      End of Sprint Survey (Responses) michael.nj.allen   rw     new 2017-11-30 09:23:54 1MTAfHE2KQ0zmFdTo7VywUCZW_Hl039UHxelgculBaxo
# 2                  End of Course Survey michael.nj.allen   rw     new 2017-11-30 04:53:11 1MM3nuCIeprGXiPUDDiqkkW8qf49e0EtRR3hzURWPP9M
# 3                    Travel Comp'd Time   jim.pellegrini   rw     new 2017-07-13 20:34:03 1CSgMLhqqedFOR8mdTByz-amRIv2gAtj_LsScMt1mcVM
# 4 cobra arra billing mike allen feb2010 michael.nj.allen   rw     new 2010-02-08 00:00:27 1_n42isCZzhRvdWVbvwPhpiOcusoXhYE6oLxQ1nDmtmE
#                                                                                                      ws_feed
# 1 https://spreadsheets.google.com/feeds/worksheets/1MTAfHE2KQ0zmFdTo7VywUCZW_Hl039UHxelgculBaxo/private/full
# 2 https://spreadsheets.google.com/feeds/worksheets/1MM3nuCIeprGXiPUDDiqkkW8qf49e0EtRR3hzURWPP9M/private/full
# 3 https://spreadsheets.google.com/feeds/worksheets/1CSgMLhqqedFOR8mdTByz-amRIv2gAtj_LsScMt1mcVM/private/full
# 4 https://spreadsheets.google.com/feeds/worksheets/1_n42isCZzhRvdWVbvwPhpiOcusoXhYE6oLxQ1nDmtmE/private/full
#                                                                                  alternate
# 1 https://docs.google.com/spreadsheets/d/1MTAfHE2KQ0zmFdTo7VywUCZW_Hl039UHxelgculBaxo/edit
# 2 https://docs.google.com/spreadsheets/d/1MM3nuCIeprGXiPUDDiqkkW8qf49e0EtRR3hzURWPP9M/edit
# 3 https://docs.google.com/spreadsheets/d/1CSgMLhqqedFOR8mdTByz-amRIv2gAtj_LsScMt1mcVM/edit
# 4 https://docs.google.com/spreadsheets/d/1_n42isCZzhRvdWVbvwPhpiOcusoXhYE6oLxQ1nDmtmE/edit
#                                                                                                           self alt_key
# 1 https://spreadsheets.google.com/feeds/spreadsheets/private/full/1MTAfHE2KQ0zmFdTo7VywUCZW_Hl039UHxelgculBaxo    <NA>
# 2 https://spreadsheets.google.com/feeds/spreadsheets/private/full/1MM3nuCIeprGXiPUDDiqkkW8qf49e0EtRR3hzURWPP9M    <NA>
# 3 https://spreadsheets.google.com/feeds/spreadsheets/private/full/1CSgMLhqqedFOR8mdTByz-amRIv2gAtj_LsScMt1mcVM    <NA>
# 4 https://spreadsheets.google.com/feeds/spreadsheets/private/full/1_n42isCZzhRvdWVbvwPhpiOcusoXhYE6oLxQ1nDmtmE    <NA>
# > gs_read(ws = "End of Sprint Survey (Responses)")
# Error in inherits(ss, "googlesheet") :
#   argument "ss" is missing, with no default
# > gs_read(ss = "End of Sprint Survey (Responses)")
# Error: inherits(ss, "googlesheet") is not TRUE
# > end_of_sprint_survey
#                   Spreadsheet title: End of Sprint Survey (Responses)
#                  Spreadsheet author: michael.nj.allen
#   Date of googlesheets registration: 2017-12-01 05:31:35 GMT
#     Date of last spreadsheet update: 2017-11-30 09:23:54 GMT
#                          visibility: private
#                         permissions: rw
#                             version: new
#
# Contains 1 worksheets:
# (Title): (Nominal worksheet extent as rows x columns)
# Form Responses 1: 111 x 17
#
# Key: 1MTAfHE2KQ0zmFdTo7VywUCZW_Hl039UHxelgculBaxo
# Browser URL: https://docs.google.com/spreadsheets/d/1MTAfHE2KQ0zmFdTo7VywUCZW_Hl039UHxelgculBaxo/
# > end_of_sprint_survey <- gs_read(ss=end_of_sprint_survey, ws =(Nominal worksheet extent as rows x columns))
# Error: unexpected symbol in "end_of_sprint_survey <- gs_read(ss=end_of_sprint_survey, ws =(Nominal worksheet"
# > end_of_sprint_survey <- gs_read(ss=end_of_sprint_survey, ws ="(Nominal worksheet extent as rows x columns)")
# Error: Worksheet (Nominal worksheet extent as rows x columns) not found.
# > gs_ws_ls(end_of_sprint_survey)
# [1] "Form Responses 1"
# > end_of_sprint_survey <- gs_read(ss=end_of_sprint_survey, ws ="(Form Responses 1")
# Error: Worksheet (Form Responses 1 not found.
# > end_of_sprint_survey <- gs_read(ss=end_of_sprint_survey, ws ="Form Responses 1")
# Accessing worksheet titled 'Form Responses 1'.
# Downloading: 340 B
# Parsed with column specification:
# cols(
#   Timestamp = col_character(),
#   Course = col_character(),
#   Experience = col_character(),
#   Instructor = col_character(),
#   Lecture = col_character(),
#   `Responsive ` = col_character(),
#   `Pace ` = col_character(),
#   Length = col_character(),
#   `Portals  ` = col_character(),
#   `Sprints ` = col_character(),
#   Classroom = col_character()
# )
# > end_of_sprint_survey
# # A tibble: 10 x 11
#              Timestamp            Course Experience    Instructor           Lecture  `Responsive `           `Pace `         Length       `Portals  `
#                  <chr>             <chr>      <chr>         <chr>             <chr>          <chr>             <chr>          <chr>             <chr>
#  1 11/23/2017 10:45:27  Big Data Analyst         No Instructor #1             Agree          Agree             Agree          Agree Strongly Disagree
#  2 11/23/2017 10:46:11  Big Data Analyst Very litte Instructor #1          Disagree       Disagree          Disagree       Disagree          Disagree
#  3 11/23/2017 10:46:55  Big Data Analyst        Yes Instructor #1    Strongly Agree Strongly Agree             Agree          Agree             Agree
#  4 11/23/2017 10:47:27  Big Data Analyst        Yes Instructor #1             Agree          Agree             Agree       Disagree             Agree
#  5 11/23/2017 10:47:53 Java Web Engineer        Yes Instructor #2             Agree          Agree             Agree          Agree             Agree
#  6 11/23/2017 10:49:43  Big Data Analyst         No Instructor #1    Strongly Agree Strongly Agree    Strongly Agree Strongly Agree             Agree
#  7 11/23/2017 10:50:53  Big Data Analyst Very litte Instructor #1 Strongly Disagree Strongly Agree          Disagree Strongly Agree    Strongly Agree
#  8 11/23/2017 10:51:18  Big Data Analyst        Yes Instructor #1    Strongly Agree Strongly Agree    Strongly Agree Strongly Agree             Agree
#  9 11/23/2017 10:51:50  Big Data Analyst         No Instructor #1             Agree Strongly Agree             Agree          Agree             Agree
# 10 11/29/2017 23:23:51  Big Data Analyst         No Instructor #1             Agree Strongly Agree Strongly Disagree          Agree Strongly Disagree
# # ... with 2 more variables: `Sprints ` <chr>, Classroom <chr>
# > eoss_frame<- as.data.frame(end_of_sprint_survey)
# > eoss_frame
#              Timestamp            Course Experience    Instructor           Lecture    Responsive              Pace          Length         Portals
# 1  11/23/2017 10:45:27  Big Data Analyst         No Instructor #1             Agree          Agree             Agree          Agree Strongly Disagree
# 2  11/23/2017 10:46:11  Big Data Analyst Very litte Instructor #1          Disagree       Disagree          Disagree       Disagree          Disagree
# 3  11/23/2017 10:46:55  Big Data Analyst        Yes Instructor #1    Strongly Agree Strongly Agree             Agree          Agree             Agree
# 4  11/23/2017 10:47:27  Big Data Analyst        Yes Instructor #1             Agree          Agree             Agree       Disagree             Agree
# 5  11/23/2017 10:47:53 Java Web Engineer        Yes Instructor #2             Agree          Agree             Agree          Agree             Agree
# 6  11/23/2017 10:49:43  Big Data Analyst         No Instructor #1    Strongly Agree Strongly Agree    Strongly Agree Strongly Agree             Agree
# 7  11/23/2017 10:50:53  Big Data Analyst Very litte Instructor #1 Strongly Disagree Strongly Agree          Disagree Strongly Agree    Strongly Agree
# 8  11/23/2017 10:51:18  Big Data Analyst        Yes Instructor #1    Strongly Agree Strongly Agree    Strongly Agree Strongly Agree             Agree
# 9  11/23/2017 10:51:50  Big Data Analyst         No Instructor #1             Agree Strongly Agree             Agree          Agree             Agree
# 10 11/29/2017 23:23:51  Big Data Analyst         No Instructor #1             Agree Strongly Agree Strongly Disagree          Agree Strongly Disagree
#    Sprints          Classroom
# 1     Agree Strongly Disagree
# 2  Disagree          Disagree
# 3     Agree             Agree
# 4     Agree          Disagree
# 5     Agree             Agree
# 6     Agree    Strongly Agree
# 7  Disagree             Agree
# 8     Agree    Strongly Agree
# 9  Disagree             Agree
# 10    Agree          Disagree
# >

# %% [markdown]
# ### I created a second survey in Google Forms
# Which I called "Newer End of Sprint Survey" which has eleven questions and the link to it is as follows:
# https://docs.google.com/forms/d/e/1FAIpQLSfYtJ3OlhToajt_tKpjlRMpmpIXfAUZv_4ccRG3HNvOcyzZPQ/viewform?usp=sf_link

# %% [markdown]
# ### This is how you get to the Google docs in the first place:
# docs.google.com/
#
# Then search for surveys.  After finding it read the results.  Then create a spreadsheet - far right button. Then go to Google Sheets
#
# Then click the "Main Menu" (though it's not obvious)on the top left.

# %% [markdown]
# ### here is the link for the "Newer End of Sprint Survey" Spreadsheet
# https://docs.google.com/spreadsheets/d/1RnCzH5uTBuIoucfc2P1jiE2Kr-ynRhN3KW3MUgQBvYQ/edit#gid=656764795

# %% [markdown]
#  ### commands to get the google form
#
#  gs_ls()
# # A tibble: 6 x 10
#                sheet_title        author  perm version             updated sheet_key
#                      <chr>         <chr> <chr>   <chr>              <dttm>     <chr>
# 1                    EOSSF michael.nj.a…    rw     new 2017-12-02 17:30:18 1QE2nlUv…
# 2 Newer End of Sprint Sur… michael.nj.a…    rw     new 2017-12-02 17:03:06 1RnCzH5u…
# 3 End of Sprint Survey (R… michael.nj.a…    rw     new 2017-12-02 03:17:54 1MTAfHE2…
# 4     End of Course Survey michael.nj.a…    rw     new 2017-11-30 04:53:11 1MM3nuCI…
# 5       Travel Comp'd Time jim.pellegri…    rw     new 2017-07-13 20:34:03 1CSgMLhq…
# 6 cobra arra billing mike… michael.nj.a…    rw     new 2010-02-08 00:00:27 1_n42isC…
# # ... with 4 more variables: ws_feed <chr>, alternate <chr>, self <chr>, alt_key <chr>
# > EOSSF <- gs_read(ss=EOSSF, ws ="Form Responses 1")
# Error in stopifnot(inherits(ss, "googlesheet")) :
#   object 'EOSSF' not found
# > EOSSF <- gs_title("EOSSF")
# Sheet successfully identified: "EOSSF"
# > EOSSF <- gs_read(ss=EOSSF, ws ="EOSSF")
# Error: Worksheet EOSSF not found.
# > EOSSF <- gs_read(ss=EOSSF, ws = "Form Responses 1")
# Accessing worksheet titled 'Form Responses 1'.
# Downloading: 290 B
# Parsed with column specification:
# cols(
#   Timestamp = col_character(),
#   Course = col_character(),
#   Experience = col_character(),
#   Instructor = col_character(),
#   Lecture = col_character(),
#   Responsive = col_character(),
#   Pace = col_character(),
#   Length = col_character(),
#   `Portals  ` = col_character(),
#   Sprints = col_character(),
#   Classroom = col_character(),
#   `Having Fun` = col_character()
# )
# > EOSSF
# # A tibble: 20 x 12
#             Timestamp           Course Experience    Instructor        Lecture     Responsive           Pace
#                 <chr>            <chr>      <chr>         <chr>          <chr>          <chr>          <chr>
#  1 12/1/2017 17:27:49 Big Data Analyst         No Instructor #1          Agree       Disagree          Agree
#  2 12/1/2017 17:28:19 Big Data Analyst         No Instructor #1       Disagree       Disagree Strongly Agree
#  3 12/1/2017 17:28:43 Big Data Analyst         No Instructor #1          Agree          Agree          Agree
#  4 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree
#  5 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree
#  6 12/1/2017 17:27:49 Big Data Analyst         No Instructor #1          Agree       Disagree          Agree
#  7 12/1/2017 17:28:19 Big Data Analyst         No Instructor #1       Disagree       Disagree Strongly Agree
#  8 12/1/2017 17:28:43 Big Data Analyst         No Instructor #1          Agree          Agree          Agree
#  9 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree
# 10 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree
# 11 12/1/2017 17:27:49 Big Data Analyst         No Instructor #1          Agree       Disagree          Agree
# 12 12/1/2017 17:28:19 Big Data Analyst         No Instructor #1       Disagree       Disagree Strongly Agree
# 13 12/1/2017 17:28:43 Big Data Analyst         No Instructor #1          Agree          Agree          Agree
# 14 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree
# 15 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree
# 16 12/1/2017 17:27:49 Big Data Analyst         No Instructor #1          Agree       Disagree          Agree
# 17 12/1/2017 17:28:19 Big Data Analyst         No Instructor #1       Disagree       Disagree Strongly Agree
# 18 12/1/2017 17:28:43 Big Data Analyst         No Instructor #1          Agree          Agree          Agree
# 19 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree
# 20 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree
# # ... with 5 more variables: Length <chr>, `Portals  ` <chr>, Sprints <chr>, Classroom <chr>, `Having Fun` <chr>
# > EOSSF
# # A tibble: 20 x 12
#             Timestamp           Course Experience    Instructor        Lecture     Responsive           Pace         Length       `Portals  `        Sprints         Classroom
#                 <chr>            <chr>      <chr>         <chr>          <chr>          <chr>          <chr>          <chr>             <chr>          <chr>             <chr>
#  1 12/1/2017 17:27:49 Big Data Analyst         No Instructor #1          Agree       Disagree          Agree          Agree Strongly Disagree          Agree Strongly Disagree
#  2 12/1/2017 17:28:19 Big Data Analyst         No Instructor #1       Disagree       Disagree Strongly Agree       Disagree             Agree          Agree             Agree
#  3 12/1/2017 17:28:43 Big Data Analyst         No Instructor #1          Agree          Agree          Agree          Agree          Disagree       Disagree Strongly Disagree
#  4 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree Strongly Agree             Agree Strongly Agree             Agree
#  5 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree Strongly Agree             Agree Strongly Agree             Agree
#  6 12/1/2017 17:27:49 Big Data Analyst         No Instructor #1          Agree       Disagree          Agree          Agree Strongly Disagree          Agree Strongly Disagree
#  7 12/1/2017 17:28:19 Big Data Analyst         No Instructor #1       Disagree       Disagree Strongly Agree       Disagree             Agree          Agree             Agree
#  8 12/1/2017 17:28:43 Big Data Analyst         No Instructor #1          Agree          Agree          Agree          Agree          Disagree       Disagree Strongly Disagree
#  9 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree Strongly Agree             Agree Strongly Agree             Agree
# 10 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree Strongly Agree             Agree Strongly Agree             Agree
# 11 12/1/2017 17:27:49 Big Data Analyst         No Instructor #1          Agree       Disagree          Agree          Agree Strongly Disagree          Agree Strongly Disagree
# 12 12/1/2017 17:28:19 Big Data Analyst         No Instructor #1       Disagree       Disagree Strongly Agree       Disagree             Agree          Agree             Agree
# 13 12/1/2017 17:28:43 Big Data Analyst         No Instructor #1          Agree          Agree          Agree          Agree          Disagree       Disagree Strongly Disagree
# 14 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree Strongly Agree             Agree Strongly Agree             Agree
# 15 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree Strongly Agree             Agree Strongly Agree             Agree
# 16 12/1/2017 17:27:49 Big Data Analyst         No Instructor #1          Agree       Disagree          Agree          Agree Strongly Disagree          Agree Strongly Disagree
# 17 12/1/2017 17:28:19 Big Data Analyst         No Instructor #1       Disagree       Disagree Strongly Agree       Disagree             Agree          Agree             Agree
# 18 12/1/2017 17:28:43 Big Data Analyst         No Instructor #1          Agree          Agree          Agree          Agree          Disagree       Disagree Strongly Disagree
# 19 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree Strongly Agree             Agree Strongly Agree             Agree
# 20 12/1/2017 17:43:07 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree Strongly Agree Strongly Agree             Agree Strongly Agree             Agree
# # ... with 1 more variables: `Having Fun` <chr>
# >
