# %% [markdown]
# # Connecting Multiple Data Sources to SQL DB
# #### 11/29/17 | Natalie | Sprint 2
# #### Description
# This project connects multiple data sources with DevLeague student information for DevLeague and pulls data into one SQL database.
#
# ## Skill Backlog User Story
# As a the Director of Technology I need to identify errors and inconsistencies in the data so that I can develop solutions to address them, and possibly their source.
#
# ## Project Proposal
# Retrieve all existing student data from multiple data sources and place them in one central database using a Python script and PostgreSQL. Data is currently stored in Hubspot, Asana, and a google drive.
#
#
# ## Key Questions
# - How to access api data sources using python and postgreSQL.
#
# ## Key Findings
# - How to write a python scripts and execute from the command line, since I'm only taking data in at this step, I don't need to create a full application. A script should work fine.
#
# ## Gameplan
# Here is my overall approach
# 1. Determine what python libraries I can use to pull in data from an api.
# 2. Determine how to execute command line scripts in python.
# 3. Create a python script to grab data from hubspots api.
# 3. Determine how to create a postgres db in python.
# 4. Create script to connect a postgres db in python.
# 5. Understand how to grab data in python data structures and store in sql db.

# %% [markdown]
# ## Day 1 Work
#
# Initially, I was going to create a python application, however I realized that since I'm only taking data in, I don't need a huge framework or application to do so. I can just create a script that will pull data from any data source and store it to a database. My first step will just be to work with one data source (Hubspot's API) and just try to bring in the data and parse it.
#
# Below is the first script I wrote using my own generated Hubspot api key.

# %%
import urllib.request, json

# Store api key value into variable
APIKEY_VALUE = "my api key"

# concat query string with api key
APIKEY = "?hapikey=" + APIKEY_VALUE

#user id
usrid = "&userID=0000000"

# hs api end point stored to a variable
HS_API_URL = "http://api.hubapi.com"

def get_total_number_of_contacts():
    # First, we build the correct url
    xurl = "/contacts/v1/lists/all/contacts/all"
    url = HS_API_URL + xurl + APIKEY + usrid
    # Now we use urllib to open the url and read it
    response = urllib.request.urlopen(url).read()
    # print(response) to see what it looks like
    statistics = json.loads(response)
    # Finally, return all contacts in dict
    return statistics["contacts"]

print (get_total_number_of_contacts())
# Out:
# b'{"contacts":[],"has-more":false,"vid-offset":0}'
# []

# %% [markdown]
# ## Day 2 Work
# My api script to Hubspot works, however it gives me back an empty dataset with zero records in it. Tried using user id, however I still get 0 results. I may just need to use the demo api key to prototype a solution.
#
# Once I used the demo key, I was able to pull in the data from hubspot. Below is the script I created that just pulls in all the data.

# %%
from pprint import pprint
import urllib.request, json

# Store api key value into variable
APIKEY_VALUE = "demo"

# concat query string with api key
APIKEY = "?hapikey=" + APIKEY_VALUE

# hs api end point stored to a variable
HS_API_URL = "http://api.hubapi.com"

def get_contacts():
    # builds the correct url
    xurl = "/contacts/v1/lists/all/contacts/all"
    url = HS_API_URL + xurl + APIKEY 
    # Now we use urllib to open the url and read it
    response = urllib.request.urlopen(url).read()
    #loads to json obj to all_contacts variable
    all_contacts = json.loads(response)
    #return the contact data
    return all_contacts

# calls the function stores to variable
contacts = get_contacts()

# pretty print just the first name of a contact
pprint(contacts)
# Out:
# {'contacts': [{'addedAt': 1456333855820,
#                'canonical-vid': 860626,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333855819,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'c4324a6f-ef03-4250-a2a8-252536f4e443'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1502322131721,
#                                                       'type': 'EMAIL',
#                                                       'value': 'new-email1@hubspot.com'}],
#                                       'saved-at-timestamp': 1511397633819,
#                                       'vid': 860626}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mPIF_l-ipw8UIYNgWYzk_MqcNU-s5wkdi_lnIkxbog3bj6dfLykevP-9CQ0Su1EMBiSKpvceH2pbX57T1iDlMszXqfcGN-w5ShbTMBapG40BN0L_yzFTead2BUoy7I1sTS4HEhc',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mPIF_l-ipw8UIYNgWYzk_MqcNU-s5wkdi_lnIkxbog3bj6dfLykevP-9CQ0Su1EMBiSKpvceH2pbX57T1iDlMszXqfcGN-w5ShbTMBapG40BN0L_yzFTead2BUoy7I1sTS4HEhc/',
#                'properties': {'company': {'value': 'MadKudu'},
#                               'firstname': {'value': 'kolokithas'},
#                               'lastmodifieddate': {'value': '1511808703222'},
#                               'lastname': {'value': 'Record11'}},
#                'vid': 860626},
#               {'addedAt': 1456333839974,
#                'canonical-vid': 860674,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333839969,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '1d13913a-4b63-437e-9799-b900fe7d63c6'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333839969,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-578@test-org.com'}],
#                                       'saved-at-timestamp': 1511413619107,
#                                       'vid': 860674}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOvwdkvAT7XVit73nR7hngykwzd1QwYD7EnKRRCLMqvVF1zQwMBVRpB3-VF3obWrAoQ1q0RBTBi-WJn3bjtPlvOedWsez3LjP5otNmEtvZNGrw4YwdokUlog0wPgl6YFZOhTuVA',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOvwdkvAT7XVit73nR7hngykwzd1QwYD7EnKRRCLMqvVF1zQwMBVRpB3-VF3obWrAoQ1q0RBTBi-WJn3bjtPlvOedWsez3LjP5otNmEtvZNGrw4YwdokUlog0wPgl6YFZOhTuVA/',
#                'properties': {'company': {'value': 'MadKudu'},
#                               'firstname': {'value': 'John'},
#                               'lastmodifieddate': {'value': '1511807791583'},
#                               'lastname': {'value': 'cruz'}},
#                'vid': 860674},
#               {'addedAt': 1456333849586,
#                'canonical-vid': 860724,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333849582,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '33644ef6-0b8d-4b1e-ab1b-346e3a4773ae'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1512081116939,
#                                                       'type': 'EMAIL',
#                                                       'value': 'new-email99@hubspot.com'}],
#                                       'saved-at-timestamp': 1512081116948,
#                                       'vid': 860724}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mPaihhUh0-SW8iYkvzHSUkZtsJlxoRjQQIDUf4dgpX5x3n1WkEBVLDc-7G5DvkW1mHyyBsW7eVIhPqxMijS4JDiIg1EtOVbCeRNjXkzAQVD7tYf7x3grs2t5FIDfXKH_uUN9unX',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mPaihhUh0-SW8iYkvzHSUkZtsJlxoRjQQIDUf4dgpX5x3n1WkEBVLDc-7G5DvkW1mHyyBsW7eVIhPqxMijS4JDiIg1EtOVbCeRNjXkzAQVD7tYf7x3grs2t5FIDfXKH_uUN9unX/',
#                'properties': {'company': {'value': 'MadKudu'},
#                               'firstname': {'value': 'Updated'},
#                               'lastmodifieddate': {'value': '1512081140521'},
#                               'lastname': {'value': 'Record'}},
#                'vid': 860724},
#               {'addedAt': 1456333869192,
#                'canonical-vid': 860775,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333869190,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '8e77a1e2-a2f3-4700-ad16-2194118ea169'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333869201,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-587@test-org.com'}],
#                                       'saved-at-timestamp': 1511401626850,
#                                       'vid': 860775}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mMVWp8a98KvH-VAlGJTq08W2GMXslyOjQVHfxcqt8B1HSI1w21uvDKHrm9oi8rtvJkOQH-JJ0hUVx_gzszXQa3F5OD-q-SCV6GSW2CTosUNaFqEgQpooXSRJCapnIQSATVII9yY',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mMVWp8a98KvH-VAlGJTq08W2GMXslyOjQVHfxcqt8B1HSI1w21uvDKHrm9oi8rtvJkOQH-JJ0hUVx_gzszXQa3F5OD-q-SCV6GSW2CTosUNaFqEgQpooXSRJCapnIQSATVII9yY/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993245'},
#                               'lastname': {'value': ''}},
#                'vid': 860775},
#               {'addedAt': 1456333873752,
#                'canonical-vid': 860824,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333873749,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'afdfb6ba-167d-4483-b763-4c7d54061522'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333873748,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-588@test-org.com'}],
#                                       'saved-at-timestamp': 1511414279605,
#                                       'vid': 860824}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOn0THmeKP-Koj1NF2MNGSQXURqKBuc6T-jU324qWs0ru7eqacR-2GZKASI15XTG5CtYy7bOipXtSenjeWpFkxrWi83MkFgRGC1z3Tf2WC8VSiRXGrt4SGl1EE5ijKa_eOywijw',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOn0THmeKP-Koj1NF2MNGSQXURqKBuc6T-jU324qWs0ru7eqacR-2GZKASI15XTG5CtYy7bOipXtSenjeWpFkxrWi83MkFgRGC1z3Tf2WC8VSiRXGrt4SGl1EE5ijKa_eOywijw/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985312'},
#                               'lastname': {'value': ''}},
#                'vid': 860824},
#               {'addedAt': 1456333895045,
#                'canonical-vid': 860826,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333895033,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'ed60d869-a96d-48a4-9434-6e00c8e70b02'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333894997,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-594@test-org.com'}],
#                                       'saved-at-timestamp': 1511417369152,
#                                       'vid': 860826}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mM9v25C8qxWMldMSyMZxp5hhRPNaTIeJQg0DxctfTEjPTskkSgvSTaCYS614N8dwb__HmjYbMeJTIFg_sM8LJAAsacJULIqBHIwQo5VpSNLsO3xucqS9fofd5A7xW4TocZSNhiE',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mM9v25C8qxWMldMSyMZxp5hhRPNaTIeJQg0DxctfTEjPTskkSgvSTaCYS614N8dwb__HmjYbMeJTIFg_sM8LJAAsacJULIqBHIwQo5VpSNLsO3xucqS9fofd5A7xW4TocZSNhiE/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168984918'},
#                               'lastname': {'value': ''}},
#                'vid': 860826},
#               {'addedAt': 1456333905477,
#                'canonical-vid': 860827,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333905475,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'bb7d2d4c-e2b6-4a7c-a109-e0c623a2eea8'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333905475,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-597@test-org.com'}],
#                                       'saved-at-timestamp': 1511387850983,
#                                       'vid': 860827}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mP48ASNesqUqZDFZB_9FuYqjV5dFMfcLsK6seRC1vuJFISMg7uMPTHs-RimRyrqZ2MVldLNQhg-FX0CzuyEmWJWuESAcb6jxSHr6GPwY0AvzNZtzkP5x5ZUsH3FjF5zGgxhTJjg',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mP48ASNesqUqZDFZB_9FuYqjV5dFMfcLsK6seRC1vuJFISMg7uMPTHs-RimRyrqZ2MVldLNQhg-FX0CzuyEmWJWuESAcb6jxSHr6GPwY0AvzNZtzkP5x5ZUsH3FjF5zGgxhTJjg/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985223'},
#                               'lastname': {'value': ''}},
#                'vid': 860827},
#               {'addedAt': 1456333876933,
#                'canonical-vid': 860874,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333876930,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'a40b38e3-a6e1-4589-937b-0b0bac1e77b5'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333876932,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-589@test-org.com'}],
#                                       'saved-at-timestamp': 1511406703625,
#                                       'vid': 860874}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mM_t6h2GphdIQ6J9JLUT7lu9eBeE79x-5FOG9Yq86JWwfav4NFSWlvbVrRpqJPH00v4l7RzAawFpaHi6wAIsVn6Yr9q9k3PyVv6azmL-hadH_YWcLQ3sM6YnDIZ5KDR4AMAWzO8',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mM_t6h2GphdIQ6J9JLUT7lu9eBeE79x-5FOG9Yq86JWwfav4NFSWlvbVrRpqJPH00v4l7RzAawFpaHi6wAIsVn6Yr9q9k3PyVv6azmL-hadH_YWcLQ3sM6YnDIZ5KDR4AMAWzO8/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168986341'},
#                               'lastname': {'value': ''}},
#                'vid': 860874},
#               {'addedAt': 1456333879866,
#                'canonical-vid': 860924,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333879862,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '6c9c08c2-9ca6-4c9b-b29a-7573abeb2bc9'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333879859,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-590@test-org.com'}],
#                                       'saved-at-timestamp': 1511406511747,
#                                       'vid': 860924}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mNL1z7y87n0I8c66J4QrRK-_EumMnjAtrP5q3NdHH5Vh-IjOhV-hPTWqlf5sr-6qv1W-R8P1K3MPO2c-_yFSn4HvxWA0aDDsCM1IAG9gQIln8cUmfj-p9VnAC3tqRzH0V7dCZdg',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mNL1z7y87n0I8c66J4QrRK-_EumMnjAtrP5q3NdHH5Vh-IjOhV-hPTWqlf5sr-6qv1W-R8P1K3MPO2c-_yFSn4HvxWA0aDDsCM1IAG9gQIln8cUmfj-p9VnAC3tqRzH0V7dCZdg/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993245'},
#                               'lastname': {'value': ''}},
#                'vid': 860924},
#               {'addedAt': 1456333891024,
#                'canonical-vid': 860925,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333891023,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'af8028c1-643e-4b09-98a2-a722443f96fa'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333891019,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-593@test-org.com'}],
#                                       'saved-at-timestamp': 1511394679428,
#                                       'vid': 860925}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mODb0Pdptg5gecvgU6HIFHGmqU2q9f1wZLURHwMSkcW2TpyrgjfDtP7XYtpwfo5QQKez7jDwBR_dKgLYTmWPgH05LOdBpAXm_L0yB5JrNVY78-TyK0ORHiAoL-m913AQAk1-dej',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mODb0Pdptg5gecvgU6HIFHGmqU2q9f1wZLURHwMSkcW2TpyrgjfDtP7XYtpwfo5QQKez7jDwBR_dKgLYTmWPgH05LOdBpAXm_L0yB5JrNVY78-TyK0ORHiAoL-m913AQAk1-dej/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993208'},
#                               'lastname': {'value': ''}},
#                'vid': 860925},
#               {'addedAt': 1456333886862,
#                'canonical-vid': 860974,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333886858,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '30beee07-69d6-4bb5-abd3-7dce8e2fdfcb'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333886845,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-592@test-org.com'}],
#                                       'saved-at-timestamp': 1511406703629,
#                                       'vid': 860974}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOPYWpuCQTNkbOC-sxlitzU6z8IHgAMolGSA8YQ0pHglaUfjqE_Oowzhmp9iyHAokX4AOxuR3Cff4zIc2pVzjtqm_k5ftfRkd9UBW3hgXL7oO-D5DfI30FCwaPNpeu6PSdclMPo',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOPYWpuCQTNkbOC-sxlitzU6z8IHgAMolGSA8YQ0pHglaUfjqE_Oowzhmp9iyHAokX4AOxuR3Cff4zIc2pVzjtqm_k5ftfRkd9UBW3hgXL7oO-D5DfI30FCwaPNpeu6PSdclMPo/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985313'},
#                               'lastname': {'value': ''}},
#                'vid': 860974},
#               {'addedAt': 1456333898836,
#                'canonical-vid': 861024,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333898833,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '8569af4e-9a43-410d-bbd8-06b70627a860'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333898816,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-595@test-org.com'}],
#                                       'saved-at-timestamp': 1511412528538,
#                                       'vid': 861024}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mP9FwSyt-yTQ3mOioHJt9Z31ni8q2Cf1nG2MkC_RvV7uc-T4D40lpiAMPoDtfoWUbCP74uBg0S_mdsaDutP2kduTmbvYRBxTeQ2Llu89fL4_2-XznB1akCX6fp-5j4FumCVU6MJ',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mP9FwSyt-yTQ3mOioHJt9Z31ni8q2Cf1nG2MkC_RvV7uc-T4D40lpiAMPoDtfoWUbCP74uBg0S_mdsaDutP2kduTmbvYRBxTeQ2Llu89fL4_2-XznB1akCX6fp-5j4FumCVU6MJ/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985402'},
#                               'lastname': {'value': ''}},
#                'vid': 861024},
#               {'addedAt': 1456333902068,
#                'canonical-vid': 861074,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333902065,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '7c3b72b9-9546-496e-b36c-e0d78915ccd7'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333902053,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-596@test-org.com'}],
#                                       'saved-at-timestamp': 1511387850985,
#                                       'vid': 861074}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mMZd_1KGC-HC_pJH5yzSniYf_TpZI8nqV5W5jIMCVZM8kw8RurRJEGXGljaK8VMoMGc_rHSho_V5eAMnRyCTXH8MQKWLQ29AfDVf5IuVk6F91wt1h5AtcFC6GID1DjfuqYJS-L-',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mMZd_1KGC-HC_pJH5yzSniYf_TpZI8nqV5W5jIMCVZM8kw8RurRJEGXGljaK8VMoMGc_rHSho_V5eAMnRyCTXH8MQKWLQ29AfDVf5IuVk6F91wt1h5AtcFC6GID1DjfuqYJS-L-/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985462'},
#                               'lastname': {'value': ''}},
#                'vid': 861074},
#               {'addedAt': 1456333909454,
#                'canonical-vid': 861124,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333909451,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '6efbeed0-3ae5-4f5d-bf1c-4a66b70aadb1'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333909440,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-598@test-org.com'}],
#                                       'saved-at-timestamp': 1511417369155,
#                                       'vid': 861124}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mPi2c1L70ts2Jmo28bjM1DX8u1-aInU1uT418jDVIu3Uf6OeewwPyAXqf7_6y0x7AEXnNl_RAk5paQzDMtgKRprZnGmL1WvOK_pd9xP20VDHfSYrwjEfG3DPK--igK9Fst24cif',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mPi2c1L70ts2Jmo28bjM1DX8u1-aInU1uT418jDVIu3Uf6OeewwPyAXqf7_6y0x7AEXnNl_RAk5paQzDMtgKRprZnGmL1WvOK_pd9xP20VDHfSYrwjEfG3DPK--igK9Fst24cif/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993149'},
#                               'lastname': {'value': ''}},
#                'vid': 861124},
#               {'addedAt': 1456333912776,
#                'canonical-vid': 861125,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333912775,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'aef91226-9c9f-41cf-9ec8-087e86425a3c'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333912774,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-599@test-org.com'}],
#                                       'saved-at-timestamp': 1511417369158,
#                                       'vid': 861125}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mMMuFqAqicmCMQjNzM3dKZ1duax1bBS4ojO2Huo7wBWMBWBOZXTgTZAoahDbeyoX2dXNUY3BDBKZd_nJ5fTV_Y2-NlmATzHE9xSDdh9KUZaK4L9SoFHjtwagxkogIy7CmqMX74h',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mMMuFqAqicmCMQjNzM3dKZ1duax1bBS4ojO2Huo7wBWMBWBOZXTgTZAoahDbeyoX2dXNUY3BDBKZd_nJ5fTV_Y2-NlmATzHE9xSDdh9KUZaK4L9SoFHjtwagxkogIy7CmqMX74h/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993299'},
#                               'lastname': {'value': ''}},
#                'vid': 861125},
#               {'addedAt': 1456333916475,
#                'canonical-vid': 861126,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333916475,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'ea55e82f-9430-442a-a587-89e9f72c1be5'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333916472,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-600@test-org.com'}],
#                                       'saved-at-timestamp': 1511412528539,
#                                       'vid': 861126}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOqLx90CVWZ515KEKMOZAd2texTGrhQmFRDW22ot1VvJCyJwGT2qVgcAm3FCJRLjsG8IJgq6wgOPpj3RrXKBBsvZS8f4KSsQnJUhcb_ySwVlROO9oMSj6rJ3v1HdhOH7GMbmDJN',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOqLx90CVWZ515KEKMOZAd2texTGrhQmFRDW22ot1VvJCyJwGT2qVgcAm3FCJRLjsG8IJgq6wgOPpj3RrXKBBsvZS8f4KSsQnJUhcb_ySwVlROO9oMSj6rJ3v1HdhOH7GMbmDJN/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993221'},
#                               'lastname': {'value': ''}},
#                'vid': 861126},
#               {'addedAt': 1456333921007,
#                'canonical-vid': 861127,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333921006,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'e8d18c0a-2f60-4264-a03b-bc2a899ac922'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333921003,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-601@test-org.com'}],
#                                       'saved-at-timestamp': 1511414279608,
#                                       'vid': 861127}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOmCcKJXOFR554oPgirH-2eaD1CsyzC4qoctAnyf-taYkBfCjcgkgpMhH660tI0jRk2OhmkRnu-INWxa-IHUU2YSvrAArPKoBquYG5J1QoR4ib4gUEpZ_Et_KSbr5Y63zSyCpnx',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOmCcKJXOFR554oPgirH-2eaD1CsyzC4qoctAnyf-taYkBfCjcgkgpMhH660tI0jRk2OhmkRnu-INWxa-IHUU2YSvrAArPKoBquYG5J1QoR4ib4gUEpZ_Et_KSbr5Y63zSyCpnx/',
#                'properties': {'company': {'value': 'MadKudu'},
#                               'firstname': {'value': 'heloooo'},
#                               'lastmodifieddate': {'value': '1511808702486'},
#                               'lastname': {'value': 'world'}},
#                'vid': 861127},
#               {'addedAt': 1456346615407,
#                'canonical-vid': 861324,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456346615403,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '019c059a-5ea8-474a-83c9-09df44d7ba6a'}],
#                                       'saved-at-timestamp': 1456346615407,
#                                       'vid': 861324}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mMtDuFi4MyWzJEE1Y_uKa_3kMRWc-djr4B02JvvD24kFRNmGQBvINF1K177YqXXK3gVuvuEy1MAD3sI2spMjsdH9d_ZL2CKGMjfmA249c2vClsdjGvoEMRGh2iOTaNTYKj-CAwm',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mMtDuFi4MyWzJEE1Y_uKa_3kMRWc-djr4B02JvvD24kFRNmGQBvINF1K177YqXXK3gVuvuEy1MAD3sI2spMjsdH9d_ZL2CKGMjfmA249c2vClsdjGvoEMRGh2iOTaNTYKj-CAwm/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1506640548059'},
#                               'lastname': {'value': ''}},
#                'vid': 861324},
#               {'addedAt': 1456346646707,
#                'canonical-vid': 861374,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456346646597,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '38af330f-84cd-4f98-84e7-17b3e1bf45bd'}],
#                                       'saved-at-timestamp': 1456346646707,
#                                       'vid': 861374}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mNlceFsgeK7W3EZw3DWa6zPwNg5VCr1Fgd006PVdWOrtrOeU6IT5X0ylBjGUdbPucLYb2pKrcyibJBrf7haufNWn43BYszqRPA0PYnyoLtQDkO2OESy8CFGjvNP3SHWhKwASzYb',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mNlceFsgeK7W3EZw3DWa6zPwNg5VCr1Fgd006PVdWOrtrOeU6IT5X0ylBjGUdbPucLYb2pKrcyibJBrf7haufNWn43BYszqRPA0PYnyoLtQDkO2OESy8CFGjvNP3SHWhKwASzYb/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1506607498918'},
#                               'lastname': {'value': ''}},
#                'vid': 861374},
#               {'addedAt': 1456348505362,
#                'canonical-vid': 861424,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456348505357,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '90e35407-95bf-493f-9558-a37b86d179da'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456348505349,
#                                                       'type': 'EMAIL',
#                                                       'value': 'jefftaggart@gmail.com'}],
#                                       'saved-at-timestamp': 1511397633821,
#                                       'vid': 861424}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mPMhlD_m-3L_LN3mtdehbGQSH05ysEAWqQFT-_2roSUVK4opHz52HuVrJ1Di-voG7HveNpk48K4rJO7rxH02CZHDVQNVEaAqvdmTJU5AYoUqPGGvigviGq2K6wBfjAIkrEnHnd_',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mPMhlD_m-3L_LN3mtdehbGQSH05ysEAWqQFT-_2roSUVK4opHz52HuVrJ1Di-voG7HveNpk48K4rJO7rxH02CZHDVQNVEaAqvdmTJU5AYoUqPGGvigviGq2K6wBfjAIkrEnHnd_/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': 'Jeff'},
#                               'lastmodifieddate': {'value': '1507664534064'},
#                               'lastname': {'value': 'Taggart'}},
#                'vid': 861424}],
#  'has-more': True,
#  'vid-offset': 861424}

# %% [markdown]
# ## Day 3
#
# Python doesn't provide much error checking out of the box. I spent a lot of time trying to access values in nested lists and dictionaries.
#
# Below is the working script that I created that just gave me back a specific value in the json object from Hubspot

# %%
from pprint import pprint
import urllib.request, json
import datetime

# Store api key value into variable
APIKEY_VALUE = "demo"

# concat query string with api key
APIKEY = "?hapikey=" + APIKEY_VALUE

# hs api end point stored to a variable
HS_API_URL = "http://api.hubapi.com"

thin_contact_list = []

def get_contacts():
    # First, we build the correct url
    xurl = "/contacts/v1/lists/all/contacts/all"
    url = HS_API_URL + xurl + APIKEY 
    # Now we use urllib to open the url and read it
    response = urllib.request.urlopen(url).read()
    all_contacts = json.loads(response)
    #return the contact data
    return all_contacts

def process_contacts(contact_list):
    new_contact_list = []
    
    #create a loop through contacts dict and store values to new dict
    for i in range(len(contacts['contacts'])):

        #store values needed to variables
        first_name= contacts['contacts'][i]['properties']['firstname']['value']
        last_name= contacts['contacts'][i]['properties']['lastname']['value']
        
        email = ''
        for identity in contacts['contacts'][i]['identity-profiles'][0]['identities']:
            if identity['type'] == 'EMAIL':
                email = identity['value']
        
        created_on= contacts['contacts'][i]['addedAt']
        last_login= contacts['contacts'][i]['identity-profiles'][0]['saved-at-timestamp']

        #added null values to blanks in fields
        if(first_name == ''):
         first_name = 'null'

        if(last_name == ''):
         last_name = 'null'

        if(email == ''):
         email = 'null@null.com'

        #created contact dict to go into db
        contact = {"firstname": first_name,
                   "lastname": last_name,
                   "email": email,
                   "createdon": created_on,
                   "lastlogin": last_login
                  }

        new_contact_list.append(contact)
    
    return new_contact_list
        
# Start processing logic
if __name__== "__main__":
    #invoke function to get data from api
    contacts = get_contacts()

    #process list of contacts
    thin_contact_list = process_contacts(contacts)
    
    print(thin_contact_list)
# Out:
# [{'firstname': 'kolokithas', 'lastname': 'Record11', 'email': 'new-email1@hubspot.com', 'createdon': 1456333855820, 'lastlogin': 1511397633819}, {'firstname': 'John', 'lastname': 'cruz', 'email': 'juanignaciosl-ded-05-578@test-org.com', 'createdon': 1456333839974, 'lastlogin': 1511413619107}, {'firstname': 'Updated', 'lastname': 'Record', 'email': 'new-email99@hubspot.com', 'createdon': 1456333849586, 'lastlogin': 1512081116948}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-587@test-org.com', 'createdon': 1456333869192, 'lastlogin': 1511401626850}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-588@test-org.com', 'createdon': 1456333873752, 'lastlogin': 1511414279605}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-594@test-org.com', 'createdon': 1456333895045, 'lastlogin': 1511417369152}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-597@test-org.com', 'createdon': 1456333905477, 'lastlogin': 1511387850983}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-589@test-org.com', 'createdon': 1456333876933, 'lastlogin': 1511406703625}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-590@test-org.com', 'createdon': 1456333879866, 'lastlogin': 1511406511747}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-593@test-org.com', 'createdon': 1456333891024, 'lastlogin': 1511394679428}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-592@test-org.com', 'createdon': 1456333886862, 'lastlogin': 1511406703629}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-595@test-org.com', 'createdon': 1456333898836, 'lastlogin': 1511412528538}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-596@test-org.com', 'createdon': 1456333902068, 'lastlogin': 1511387850985}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-598@test-org.com', 'createdon': 1456333909454, 'lastlogin': 1511417369155}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-599@test-org.com', 'createdon': 1456333912776, 'lastlogin': 1511417369158}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-600@test-org.com', 'createdon': 1456333916475, 'lastlogin': 1511412528539}, {'firstname': 'heloooo', 'lastname': 'world', 'email': 'juanignaciosl-ded-05-601@test-org.com', 'createdon': 1456333921007, 'lastlogin': 1511414279608}, {'firstname': 'null', 'lastname': 'null', 'email': 'null@null.com', 'createdon': 1456346615407, 'lastlogin': 1456346615407}, {'firstname': 'null', 'lastname': 'null', 'email': 'null@null.com', 'createdon': 1456346646707, 'lastlogin': 1456346646707}, {'firstname': 'Jeff', 'lastname': 'Taggart', 'email': 'jefftaggart@gmail.com', 'createdon': 1456348505362, 'lastlogin': 1511397633821}]

# %%
import psycopg2
import sys

print(thin_contact_list)

con = None

try:
     
    con = psycopg2.connect(database='hsbd', user='nat') 
    cur = con.cursor()
    cur.execute('SELECT version()')          
    ver = cur.fetchone()
    print (ver, "i can conncet")    
    
    for contact in thin_contact_list:
        cur.execute("INSERT INTO contacts(first_name, last_name, email) VALUES ('"+ contact['firstname'] + "','" + contact['lastname'] + "',' " + contact['email'] + "')")
        print('inserted')
        
    con.commit()

except psycopg2.DatabaseError as e:
    print ('Error %s' % e)    
    sys.exit(1)
    
    
finally:
    
    if con:
        con.close()
# Out:
# [{'firstname': 'kolokithas', 'lastname': 'Record11', 'email': 'new-email1@hubspot.com', 'createdon': 1456333855820, 'lastlogin': 1511397633819}, {'firstname': 'John', 'lastname': 'cruz', 'email': 'juanignaciosl-ded-05-578@test-org.com', 'createdon': 1456333839974, 'lastlogin': 1511413619107}, {'firstname': 'Updated', 'lastname': 'Record', 'email': 'new-email99@hubspot.com', 'createdon': 1456333849586, 'lastlogin': 1512081116948}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-587@test-org.com', 'createdon': 1456333869192, 'lastlogin': 1511401626850}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-588@test-org.com', 'createdon': 1456333873752, 'lastlogin': 1511414279605}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-594@test-org.com', 'createdon': 1456333895045, 'lastlogin': 1511417369152}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-597@test-org.com', 'createdon': 1456333905477, 'lastlogin': 1511387850983}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-589@test-org.com', 'createdon': 1456333876933, 'lastlogin': 1511406703625}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-590@test-org.com', 'createdon': 1456333879866, 'lastlogin': 1511406511747}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-593@test-org.com', 'createdon': 1456333891024, 'lastlogin': 1511394679428}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-592@test-org.com', 'createdon': 1456333886862, 'lastlogin': 1511406703629}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-595@test-org.com', 'createdon': 1456333898836, 'lastlogin': 1511412528538}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-596@test-org.com', 'createdon': 1456333902068, 'lastlogin': 1511387850985}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-598@test-org.com', 'createdon': 1456333909454, 'lastlogin': 1511417369155}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-599@test-org.com', 'createdon': 1456333912776, 'lastlogin': 1511417369158}, {'firstname': 'null', 'lastname': 'null', 'email': 'juanignaciosl-ded-05-600@test-org.com', 'createdon': 1456333916475, 'lastlogin': 1511412528539}, {'firstname': 'heloooo', 'lastname': 'world', 'email': 'juanignaciosl-ded-05-601@test-org.com', 'createdon': 1456333921007, 'lastlogin': 1511414279608}, {'firstname': 'null', 'lastname': 'null', 'email': 'null@null.com', 'createdon': 1456346615407, 'lastlogin': 1456346615407}, {'firstname': 'null', 'lastname': 'null', 'email': 'null@null.com', 'createdon': 1456346646707, 'lastlogin': 1456346646707}, {'firstname': 'Jeff', 'lastname': 'Taggart', 'email': 'jefftaggart@gmail.com', 'createdon': 1456348505362, 'lastlogin': 1511397633821}]
# ('PostgreSQL 9.6.6 on x86_64-apple-darwin13.4.0, compiled by clang version 4.0.1 (tags/RELEASE_401/final), 64-bit',) i can conncet
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted

# %% [markdown]
# ## Peer Feedback on Day 5
#
# After talking it over with a peer, I received the following feedback and decided to make these changes

# %% [markdown]
# ## Here are some overall notes on the skills I learned
# And perhaps some stream of consciousness notes about what I did, and other questions I might have
