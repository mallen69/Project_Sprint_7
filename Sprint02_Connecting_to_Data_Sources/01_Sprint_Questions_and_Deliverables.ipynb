# %% [markdown]
# # Sprint 2: Connecting to Data Sources

# %% [markdown]
# ## Final Deliverables
# |Author|Project Title|overview|repo|docs|
# |---|---|---|---|---|
# |Hunter Heavilin|Tables all the Way Down|[slides](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/01_Sprint_Presentations/Sprint02_Review_Presentation%20HH.pdf)|[repo](https://github.com/supersistence/Tables-All-The-Way-Down)|[docs](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/Hunter_Heaivilin.ipynb)|
# |Jon Honda|Connecting to Quandl|[slides](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/01_Sprint_Presentations/Sprint_Review_Presentation_honda.pdf)|[repo](TBD)|[docs](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/Jon_Honda.ipynb)|
# |Justine Espiritu|Importing Excel Data into SQLite Studio Database/Tables|[slides](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/01_Sprint_Presentations/VL_JE_Sprint_Review2_Presentation.pdf)|[repo](https://github.com/j-espiritu/Importing-Excel-Data-in-SQLite)|[docs](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/Justine_Espiritu.ipynb)|
# |Michael Allen|Write a Script in "R" to Connect to an "End of Sprint Survey" Created in Google Forms|[slides](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/01_Sprint_Presentations/R_Script_to_Read_Google_Sheet_Michael_Allen.pdf)|[repo](https://github.com/mallen69/Project_Sprint_2)|[docs](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/Michael_Allen.ipynb)|
# |Natalie Ramirez|Conneting a Data Source and Database using Python and PostgreSQL|[slides](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/01_Sprint_Presentations/Natalie_Ramirez_Sprint_2_Review_Presentation.pdf)|[repo](https://github.com/nat-nat33/data-source-ry)|[docs](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/Natalie_Ramirez.ipynb)|
# |Olina Cavedoni|TBD|[slides](TBD)|[repo](https://github.com/ocavedoni/Sprint2_PythonDroplet)|[docs](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/Olina_Cavedoni.ipynb)|
# |Runjini Murthy|ROI of an Oscar Win|[slides](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/01_Sprint_Presentations/Sprint_2_Review_Presentation_Runjini.pdf)|[repo](TBD)|[docs](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/Runjini_Murthy.ipynb)|
# |Sheuli Molla|TBD|[slides]()|[repo]()|[docs]()|
# |Tori Larson|SQLiteStudio & Data Types|[slides](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/01_Sprint_Presentations/VL_JE_Sprint_Review2_Presentation.pdf)|[repo](https://github.com/ToriLarson/ToriLarson_Sprint2)|[docs](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/Victoria_Larson.ipynb)|

# %% [markdown]
# ## Questions
#
# #### How do we store data?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
#
# #### How do we structure the data we store?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
#
# #### How do we access the data we store?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
#
# ## Key Concepts and Definitions
#
# - script
# - command line interface
# - concatenating data
# - relational data
# - join
# - key
# - SQL
# - SELECT
# - Database Server
# - Datastore
# - ODBC - Open Database Connectivity
# - API
# - Data Warehouse
# - Web Scraping
# - Parser
#
#
# ## Sprint 2 Gaps
#
# ### What is the SELECT Function in SQLite?
# - [Resource 1](https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint02_Connecting_to_Data_Sources/01_Sprint_Presentations/VL_JE_Sprint_Review2_Presentation.pdf): *Tori Larson* - refer to Slide 4:  The SELECT function returns a set of records from one or more tables. In the powerpoint example "SELECT LOCATION" prints all of the parking locations in the table "city_parking".
#
# ### I still don't quite understand XML and JSON.
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### What is a Datastore?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### What is a Data Warehouse?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### What is an ODBC?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### What is the difference between Webscraping & Parcing?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### Primary vs. Foreign Key?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### What is a Data Lake?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
#
# Gaps
# - SQL / SELECT
#     - Tori's project []
# - JSON / XML
#     - Runjini's projet
#     - Tori's project
# - Datastore
# - Data Warehouse
# - ODBC
# - Web Scraping / Parsers
#     - Hunters project
#     - Natalies Project
# - key (primary / foreign)
#     - Runjini's project
# - Data Lake
#
# Questions:
#
# - How did you do the connection to google Sheets?
#
# - How did you actually get the data into SQLite / What SQL Code was to import?
#
# - Web Scraping.
#
# - What is an SSH Key and should it be private/hidden?
#
# - How did you know what the endpoint was
#
# - If the script was up, if someone was trying to run it would it work?
# - How did you authenticate for google sheets?
# - What is INSERT in SQL?
# - How do I add a new column in SQL

# %% [markdown]
# ## Sprint Data Stories and Module Review
#
# *"Getting" the data you want to analyze means downloading it from websites, connecting to and querying databases, extracting it from HTML webpages, interfacing with APIs (Application Programmer Interfaces) importing and exporting files, and converting back and forth between data formats. Programming languages, databases, command line-based applications and graphical applications each have something to offer*
#
# |Data Journalist| Data Engineer | Statistical Modeler| Business Analyst |
# |:----------------|:----|:------------------|:----|
# |I need to construct datasets from web resources, so that I can investigate issues where data are not readily available| I need to understand the full technology operating system stack and ecosystem so that I can interact with tools| I need to understand basic scripting so that I can save repeatable analyses and work| I need to be able to connect to my corporate databases, APIs and data warehouses so that I can make use of available data resources|

# %% [markdown]
# ## Last Sprint
#
# ### If we have it in one format, should we be able to change it to any of the other formats?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### What is 'relational data'?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### What is 'assembly'?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### Is there a data equivalent to a literature review? Where you figure out what kind of data you need and is it part of this umbrella?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### JSON Data is a bigger file than CSV. In what situations is JSON "more efficient"?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### JSON and XML data have fields for every single entry. If all of your data is "good", why do you need all of that extra information, vs a CSV. And wouldn't that cause errors?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### How can we define big versus small data? By data quantity? By its complexity? Something else?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### Why do we need to have the line at the top of the xml file? What does that mean?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### How did you know to print out a line in python? How did you get there?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### What does RVEST do and what does it mean to scrape?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
#
# ### What does it mean that the data is structured? Structured data over the web?
# - [Resource 1](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
# - [Resource 2](): *Name of Cohort Member* Summary of Comment or Response
