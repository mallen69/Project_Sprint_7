# %% [markdown]
# ## 11/30/2017 Michael Allen Sprint 2
#
# #### Description Title: Write a Script in “R” to Connect to a “End of Sprint Survey” Created in Google Forms
#
# #### Description: Create an "End of Sprint Survey" in Google Forms and read the survey results in R.  And then create a script in R to automate (simplify) the process of reading it into R.
#
#
# ## Game Plan
# Here is my overall Game Plan:
#
# 1. Create "End of Sprint Survey" in Google Forms
#
# 2. Fill out the “Google Form” Multiple times to Create “Mock Data”
#
# 3. Analyze the Results in “Google Forms”
#
# 4. Create a Spreadsheet in “Google Sheets”
#
# 5. Use R to read the “Google Sheet”
#
# 6. Write a “Script” in R to Speed-up the Process of Reading a Google Sheet into “R”
#
# 7. View the (Survey) Data in R
#
#
# ### Skill Backlog User Story
# An overall User Story: As a [Technology Instructor] I need to [Understand the basics of Big Data] so that [I can show and convey it to others].
#
# ### Project Proposal Sprint 2 - (Using Bayesian Statistical Theory):
# As a Technology Instructor I need to get exposed to Google Forms and Google Sheets and create a Survey with Google Forms instead of SurveyMonkey (as there are limitations without a paid subscriptionn so that I am able to read the Google Form Survey data in R, and to understand a basic R script.
#
# I propose to create an "End of Sprint Survey" in Google Forms and begin to learn this tool as it is free to utilize.  I will then fill out the survey multiple times in order to generate mock data.  I'll look at the response data in Google Forms and then create/write the data to Google Sheets (essentially an automatic process).  In R I'll then write the code in order to read the Google Sheets.  Then I'll write a script in R in order to simply the read/viewing of the Google Sheet process in R.
#
#
# ### Five Pitches for the 11/29/2017 Session for Sprint Number 2
#
# *1. Since SurveyMonkey requires a subscription in order to export data (also to have more than ten questions) so instead create the "End of Sprint Survey" in Google Forms and to write a script to read the output in R.*
#
#     (The other four that was not chosen)
# 2. To write a script in R which cleans any field that is not filled out (currently gives a NA Value) so as not to mess up any calculations.
#
# 3. Take existing "End of Course Survey" data which is in Excel and begin to look at it in "R".
#
# 4. Take a previous Macro (Script) in Excel that my former Manager (Bosses Boss) wrote in order to help clean the data being exported from SurveyMonkey to Excel.
#
# 5. Write a script to take the values of the text:
# Strongly Agree, Agree, Disagree, Strongly Disagree
# And assign them numerical Values as below:
#
#     Strongly Agree = 40
#     Agree = 30
#     Disagree = 20
#     Strongly Disagree = 10
#
#
# ### Key Questions
# How do I access Google Docs/Forms in order to create a survey?
# How do I email or send the link to someone in order to fill it out.
# How do I read the results (responses) from the survey (generated) data.
# How do I create a Google Sheet.
# What does the Google Sheet look like.
# What commands are necessary to read the Google Sheet into R.
# How do I write a script in R.

# %% [markdown]
# ### Key Findings:
# #### Game Plan #1 & #2:
#
# 1. Create "End of Sprint Survey" in Google Forms
#
# How do I access Google Docs/Forms in order to create a survey.
# The following is how I found it.  Though there are other ways.
#
# ![](_mallen/Accessing_Google_Forms.jpg)
#
#
#
# ![](_mallen/Accessing_Google_Forms_II_also.jpg)
#
#
#
# ![](_mallen/Accessing_Google_Forms_III.jpg)
#
#
#
# ![](_mallen/Accessing_Google_Forms_V.jpg)
#
# #### The following are the eleven questions that I wrote up for the End of Sprint Survey:
# ![](_mallen/Google_Forms_Questions_1_2_3.jpg)
#
# ![](_mallen/Google_Forms_Questions_4_5_6.jpg)
#
# ![](_mallen/Google_Forms_Questions_7_8_9.jpg)
#
# ![](_mallen/Google_Forms_Question_9_10.jpg)
#
#
#
# #### This is one way of how you get to the Google Sheets after the Google Form/Google Sheet has been created.
# docs.google.com/
#
# Then search for surveys.  After finding it read the results.  Then create a spreadsheet - far right button. Then go to Google Sheets
#
# Then click the "Main Menu" (though it's not obvious) on the top left.
# ![](_mallen/Accessing_Google_Forms_VI.jpg)
#
#
#
# #### How do I email or send the link to someone in order to fill it out.
#
# ![](_mallen/Sending_Out_Training_Survey.jpg)
#
#
# ![](_mallen/Sending_Out_Training_Survey_by_email.jpg)
#
#
# #### Game Plan #3:
#
# #### How do I read the results (responses) from the survey (generated) data.
#
# ![](_mallen/Response_programming_experience.jpg)
#
# ![](_mallen/Response_Classroom.jpg)
#
#
# #### Game Plan #4:
# #### How do I create a Google Sheet.
#
# ![](_mallen/creating_spread_sheet_from_Google_Respones.jpg)
#
#
#
# #### What does the Google Sheet look like?
#
# ![](_mallen/Snap_shot_of_a_google_sheet.jpg)
#
#
# #### Game Plan #5:
# #### What commands (code) are necessary to read the Google Sheet into R?
#
# getwd() *gives me my working directory
#
# Install.packages(“googlesheets”)  *installs the necessary googlesheets library - this only needs to be done once.
#
# #### Which gave me this result:
#
#
# *Installing package into ‘C:/Users/micha/Documents/R/win-library/3.4’ (as ‘lib’ is unspecified) also installing the dependencies ‘bindr’, ‘rematch’, ‘tibble’, ‘assertthat’, ‘bindrcpp’, ‘glue’, ‘pkgconfig’, ‘rlang’, ‘BH’, ‘plogr’, ‘hms’, ‘tidyselect’, ‘cellranger’, ‘dplyr’, ‘purrr’, ‘readr’, ‘tidyr’, ‘xml2’
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/bindr_0.1.zip' Content type 'application/zip' length 14967 bytes (14 KB) downloaded 14 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/rematch_1.0.1.zip' Content type 'application/zip' length 14619 bytes (14 KB) downloaded 14 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/tibble_1.3.4.zip' Content type 'application/zip' length 675890 bytes (660 KB) downloaded 660 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/assertthat_0.2.0.zip' Content type 'application/zip' length 43876 bytes (42 KB) downloaded 42 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/bindrcpp_0.2.zip' Content type 'application/zip' length 639197 bytes (624 KB) downloaded 624 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/glue_1.2.0.zip' Content type 'application/zip' length 75945 bytes (74 KB) downloaded 74 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/pkgconfig_2.0.1.zip' Content type 'application/zip' length 20016 bytes (19 KB) downloaded 19 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/rlang_0.1.4.zip' Content type 'application/zip' length 465175 bytes (454 KB) downloaded 454 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/BH_1.65.0-1.zip' Content type 'application/zip' length 17006683 bytes (16.2 MB) downloaded 16.2 MB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/plogr_0.1-1.zip' Content type 'application/zip' length 17918 bytes (17 KB) downloaded 17 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/hms_0.4.0.zip' Content type 'application/zip' length 33288 bytes (32 KB) downloaded 32 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/tidyselect_0.2.3.zip' Content type 'application/zip' length 624406 bytes (609 KB) downloaded 609 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/cellranger_1.1.0.zip' Content type 'application/zip' length 75545 bytes (73 KB) downloaded 73 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/dplyr_0.7.4.zip' Content type 'application/zip' length 2883837 bytes (2.8 MB) downloaded 2.8 MB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/purrr_0.2.4.zip' Content type 'application/zip' length 243143 bytes (237 KB) downloaded 237 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/readr_1.1.1.zip' Content type 'application/zip' length 1272745 bytes (1.2 MB) downloaded 1.2 MB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/tidyr_0.7.2.zip' Content type 'application/zip' length 894490 bytes (873 KB) downloaded 873 KB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/xml2_1.1.1.zip' Content type 'application/zip' length 3529076 bytes (3.4 MB) downloaded 3.4 MB
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/3.4/googlesheets_0.2.2.zip' Content type 'application/zip' length 1631886 bytes (1.6 MB) downloaded 1.6 MB
# package ‘bindr’ successfully unpacked and MD5 sums checked package ‘rematch’ successfully unpacked and MD5 sums checked package ‘tibble’ successfully unpacked and MD5 sums checked package ‘assertthat’ successfully unpacked and MD5 sums checked package ‘bindrcpp’ successfully unpacked and MD5 sums checked package ‘glue’ successfully unpacked and MD5 sums checked package ‘pkgconfig’ successfully unpacked and MD5 sums checked package ‘rlang’ successfully unpacked and MD5 sums checked package ‘BH’ successfully unpacked and MD5 sums checked package ‘plogr’ successfully unpacked and MD5 sums checked package ‘hms’ successfully unpacked and MD5 sums checked package ‘tidyselect’ successfully unpacked and MD5 sums checked package ‘cellranger’ successfully unpacked and MD5 sums checked package ‘dplyr’ successfully unpacked and MD5 sums checked package ‘purrr’ successfully unpacked and MD5 sums checked package ‘readr’ successfully unpacked and MD5 sums checked package ‘tidyr’ successfully unpacked and MD5 sums checked package ‘xml2’ successfully unpacked and MD5 sums checked package ‘googlesheets’ successfully unpacked and MD5 sums checked
# The downloaded binary packages are in C:\Users\micha\AppData\Local\Temp\RtmpALotuU\downloaded_packages*
#
# library(googlesheets)  **this loads the googlesheet library in the working R program - this needs to be done every time for the R workspace that you are working in.*
#
# gs_ls() *this is the list of the various Google Sheets that I have access to.*
#
#
# *The name Sprint_2 is the variable name that I used to refer to the document (Google Sheet) that is being stored ont the Google Drive which has the Survey Data Results.*
#
# *Sprint_2_EOSS is the name of my Google Sheet and Responses refer to the answers given.  This is the format for the Google Sheet.  My naming convention is Essentially stands for the Second Sprint that we are currently working on and EOSS is acronym for End of Sprint Survey.  The name Sprint_2 is the variable name that I used to refer to the document (Google Sheet) that is being stored on the Google drive.*
#
#  Sprint_2 <- gs_title(“Sprint_2_EOSS (Responses)”)  *This reads into R the Google Sheet with the title of "Sprint_2_EOSS"*
#
#  gs_ws_ls(Sprint_2) *This lists which worksheets exist within the Google Sheet*
#
# Sprint_2 <- gs_read(ss=Sprint_2, ws = "Form Responses 1") *This "downloads" one of the Google Sheet using gs_read()*
# Sprint_2  *Finally reads (outputs) the Google Sheet data into R*
#
#
# ![](_mallen/Code_For_R_to_read_Google_Sheet.jpg)
#
#
# #### Game Plan #6 & #7:
# ##### R Scripting:
#
# https://cran.r-project.org/doc/contrib/Lemon-kickstart/kr_scrpt.html
#
# So what is an R script? An R script is simply a text file containing (almost) the same commands that you would enter on the command line of R. (almost) refers to the fact that if you are using sink() to send the output to a file, you will have to enclose some commands in print() to get the same output as on the command line. To run a script, let's say one with the name: /home/jim/psych/adoldrug/partyuse1.R you may either use: source("/home/jim/psych/adoldrug/partyuse1.R") on the command line of R OR R CMD BATCH /home/jim/psych/adoldrug/partyuse1.R Let's pause to note a little historical bifurcation that has caused almost as much strife as the question of exactly what the
# store the current directory
#
# initial.dir<-getwd()
# change to the new directory
#
# setwd("/home/jim/psych/risk/adol")
# load the necessary libraries
#
# library(nlme)
# set the output file
#
# sink("adolrisk03.out")
# load the dataset
#
# ...
# close the output file
#
# sink()
# unload the libraries
#
# detach("package:nlme")
# change back to the original directory
#
# setwd(initial.dir) First notice that the script stores the initial directory and changes to the directory where the data is, and where output will be generated. The libraries necessary for the analysis are then loaded. Finally, the output of the script is directed to a text file, producing a record of the analysis. Then comes the action. After the analysis has been completed, the output file is closed, the libraries are unloaded, and the directory is changed back to where the scripts reside. At this point, you may want to start another script or shut down R.
#
# Annotating the output file R's output can often be terse. Annotating it will make it much easier for someone unfamiliar with R or statistical analysis to understand.
#
# cat("\nMean risk-taking scores for all groups\n\n") brkdn(risk~group,adolrisk03.df) Here cat() is used to label a breakdown of means, leaving a blank line above and two below the label. Spacing the output with meaningful labels improves the appearance and comprehensibility.

# %% [markdown]
# ### My actual R Script is as Follows:
#
# getwd()
# library(googlesheets)
# gs_ls()
# Sprint_2 <-'https://docs.google.com/spreadsheets/d/1Oze5HnI8jEVtKvhwt2LbO42Ec5ErHI6_IArt3sS7HxY/edit#gid=319180982'
# Sprint_2 <- gs_title("Sprint_2_EOSS (Responses)")
# gs_ws_ls(Sprint_2)
# Sprint_2 <- gs_read(ss=Sprint_2, ws = "Form Responses 1")
# Sprint_2
# View(Sprint_2)
#
# *The actual steps are displayed here*
#
# ![](_mallen/Creating_a_R_Script.jpg)
#
# ![](_mallen/Creating_a_R_Script_II.jpg)

# %% [markdown]
# #### The Actual R Code and Results Running Step by Step:
#
# [Workspace loaded from ~/.RData]
#
# > getwd()
#
# [1] "C:/Users/micha/Documents"
#
# > library(googlesheets)
# Warning message:
# package ‘googlesheets’ was built under R version 3.4.2
#
# > gs_ls()
# Auto-refreshing stale OAuth token.
#
#  A tibble: 7 x 10
#                sheet_title        author  perm version             updated sheet_key
#                      <chr>         <chr> <chr>   <chr>              <dttm>     <chr>
# 1 Sprint_2_EOSS (Response… michael.nj.a…    rw     new 2017-12-06 22:51:36 1Oze5HnI…
# 2                    EOSSF michael.nj.a…    rw     new 2017-12-02 17:31:26 1QE2nlUv…
# 3 Newer End of Sprint Sur… michael.nj.a…    rw     new 2017-12-02 17:03:06 1RnCzH5u…
# 4 End of Sprint Survey (R… michael.nj.a…    rw     new 2017-12-02 03:17:54 1MTAfHE2…
# 5     End of Course Survey michael.nj.a…    rw     new 2017-11-30 04:53:11 1MM3nuCI…
# 6       Travel Comp'd Time jim.pellegri…    rw     new 2017-07-13 20:34:03 1CSgMLhq…
# 7 cobra arra billing mike… michael.nj.a…    rw     new 2010-02-08 00:00:27 1_n42isC…
#
#  with 4 more variables: ws_feed <chr>, alternate <chr>, self <chr>, alt_key <chr>
# Warning message:
# package ‘bindrcpp’ was built under R version 3.4.2
#
# > Sprint_2 <-'https://docs.google.com/spreadsheets/d/1Oze5HnI8jEVtKvhwt2LbO42Ec5ErHI6_IArt3sS7HxY/edit#gid=319180982'
#
# > Sprint_2 <- gs_title("Sprint_2_EOSS (Responses)")
# Sheet successfully identified: "Sprint_2_EOSS (Responses)"
#
# > gs_ws_ls(Sprint_2)
# [1] "Form Responses 1"
#
# > Sprint_2 <- gs_read(ss=Sprint_2, ws = "Form Responses 1")
# Accessing worksheet titled 'Form Responses 1'.
# Downloading: 320 B
# Parsed with column specification:
# cols(
#   Timestamp = col_character(),
#   Course = col_character(),
#   Experience = col_character(),
#   Instructor = col_character(),
#   Lecture = col_character(),
#   Responsive = col_character(),
#   Pace = col_character(),
#   Length = col_character(),
#   Portals = col_character(),
#   Sprints = col_character(),
#   Classroom = col_character(),
#   `Having fun` = col_character()
# )
#
# > Sprint_2
#  A tibble: 28 x 12
#             Timestamp           Course Experience    Instructor        Lecture     Responsive           Pace   Length        Portals
#                 <chr>            <chr>      <chr>         <chr>          <chr>          <chr>          <chr>    <chr>          <chr>
#  1 11/30/2017 8:12:27 Big Data Analyst         No Instructor #1       Disagree       Disagree          Agree    Agree          Agree
#  2  12/1/2017 8:12:27 Big Data Analyst Very litte Instructor #1       Disagree          Agree          Agree Disagree          Agree
#  3  12/2/2017 8:12:27 Big Data Analyst Very litte Instructor #1       Disagree          Agree          Agree Disagree          Agree
#  4  12/3/2017 8:12:27 Big Data Analyst        Yes Instructor #1 Strongly Agree          Agree          Agree    Agree       Disagree
#  5  12/3/2017 8:12:54 Big Data Analyst        Yes Instructor #1 Strongly Agree Strongly Agree Strongly Agree    Agree Strongly Agree
#  6  12/3/2017 8:15:01 Big Data Analyst         No Instructor #1          Agree          Agree          Agree    Agree       Disagree
#  7  12/3/2017 8:15:42 Big Data Analyst Very litte Instructor #1 Strongly Agree Strongly Agree          Agree Disagree          Agree
#  8 11/30/2017 8:12:27 Big Data Analyst         No Instructor #1       Disagree       Disagree          Agree    Agree          Agree
#  9  12/1/2017 8:12:27 Big Data Analyst Very litte Instructor #1       Disagree          Agree          Agree Disagree          Agree
# 10  12/2/2017 8:12:27 Big Data Analyst Very litte Instructor #1       Disagree          Agree          Agree Disagree          Agree
#  ... with 18 more rows, and 3 more variables: Sprints <chr>, Classroom <chr>, `Having fun` <chr>

# %% [markdown]
# #### This is the actual link to the Google Form "End of Sprint Survey":
# https://goo.gl/forms/bXkCkIaa0ZUTM7T72

# %% [markdown]
# ### Learning Summary:
# During Sprint #2 I have been getting more comfortable using our various support portals during the past two weeks (Jupyter Note Books, Slack, and GitHub).  In addition, started to work with GitBash.
#
# Then for the actual project, I learned how to access first Google Docs, then Google Forms for Survey creation.  I then learned how to send either by email or a URL link the ability for a student/learner to fill out the form.  Then saw how to read the results in Google Forms.  From there a simple Google Sheet creation can be accomplished so the data can be more like an Excel Spreadsheet.  Then to the heart of the task for the two weeks, and that was to utilize R to read the Google Sheet data.  After figuring out the various commands (days to do so) I learned how to write a script in R to simply the process.  And the final thing that I learned is you must be logged into Gmail on the proper email account for the R commands to work.
