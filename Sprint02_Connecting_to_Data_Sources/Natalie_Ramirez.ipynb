# %% [markdown]
# # Connecting Multiple Data Sources to SQL DB
# #### 11/29/17 | Natalie | Sprint 2
# #### Description
# This project connects multiple data sources with DevLeague student information for DevLeague and pulls data into one SQL database.
#
# ## Skill Backlog User Story
# As a the Director of Technology I need to identify errors and inconsistencies in the data so that I can develop solutions to address them, and possibly their source.
#
# ## Project Proposal
# Retrieve all existing student data from multiple data sources and place them in one central database using a Python script and PostgreSQL. Data is currently stored in Hubspot, Asana, and a google drive.
#
#
# ## Key Questions
# - How to access api data sources using python and postgreSQL.
#
# ## Key Findings
# - How to write a python scripts and execute from the command line, since I'm only taking data in at this step, I don't need to create a full application. A script should work fine.
#
# ## Gameplan
# Here is my overall approach
# 1. Determine what python libraries I can use to pull in data from an api.
# 2. Determine how to execute command line scripts in python.
# 3. Create a python script to grab data from hubspots api.
# 3. Determine how to create a postgres db in python.
# 4. Create script to connect a postgres db in python.
# 5. Understand how to grab data in python data structures and store in sql db.

# %% [markdown]
# ## Day 1 Work
#
# Initially, I was going to create a python application, however I realized that since I'm only taking data in, I don't need a huge framework or application to do so. I can just create a script that will pull data from any data source and store it to a database. My first step will just be to work with one data source (Hubspot's API) and just try to bring in the data and parse it.
#
# Below is the first script I wrote using my own generated Hubspot api key.

# %%
import urllib.request, json

# Store api key value into variable
APIKEY_VALUE = "my api key"

# concat query string with api key
APIKEY = "?hapikey=" + APIKEY_VALUE

#user id
usrid = "&userID=0000000"

# hs api end point stored to a variable
HS_API_URL = "http://api.hubapi.com"

def get_total_number_of_contacts():
    # First, we build the correct url
    xurl = "/contacts/v1/lists/all/contacts/all"
    url = HS_API_URL + xurl + APIKEY + usrid
    # Now we use urllib to open the url and read it
    response = urllib.request.urlopen(url).read()
    # print(response) to see what it looks like
    statistics = json.loads(response)
    # Finally, return all contacts in dict
    return statistics["contacts"]

print (get_total_number_of_contacts())
# Out:
# b'{"contacts":[],"has-more":false,"vid-offset":0}'
# []

# %% [markdown]
# ## Day 2 Work
# My api script to Hubspot works, however it gives me back an empty dataset with zero records in it. Tried using user id, however I still get 0 results. I may just need to use the demo api key to prototype a solution.
#
# Once I used the demo key, I was able to pull in the data from hubspot. Below is the script I created that just pulls in all the data.

# %%
from pprint import pprint
import urllib.request, json

# Store api key value into variable
APIKEY_VALUE = "demo"

# concat query string with api key
APIKEY = "?hapikey=" + APIKEY_VALUE

# hs api end point stored to a variable
HS_API_URL = "http://api.hubapi.com"

def get_contacts():
    # builds the correct url
    xurl = "/contacts/v1/lists/all/contacts/all"
    url = HS_API_URL + xurl + APIKEY 
    # Now we use urllib to open the url and read it
    response = urllib.request.urlopen(url).read()
    #loads to json obj to all_contacts variable
    all_contacts = json.loads(response)
    #return the contact data
    return all_contacts

# calls the function stores to variable
contacts = get_contacts()

# pretty print just the first name of a contact
pprint(contacts)
# Out:
# {'contacts': [{'addedAt': 1456333855820,
#                'canonical-vid': 860626,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333855819,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'c4324a6f-ef03-4250-a2a8-252536f4e443'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1502322131721,
#                                                       'type': 'EMAIL',
#                                                       'value': 'new-email1@hubspot.com'}],
#                                       'saved-at-timestamp': 1511397633819,
#                                       'vid': 860626}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOn7cz20o7R3IfSHqsbSB8cIdzbA8hfRP0_e8kEUQfxvLJA1LnAQkKVkcmtb842HYuoNQPMPENm_-jUrkmYjXtlX723ge1rVfkHedvt3CCOp5YUhYYOktpZDWMk4Z4axfyk5sdU',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOn7cz20o7R3IfSHqsbSB8cIdzbA8hfRP0_e8kEUQfxvLJA1LnAQkKVkcmtb842HYuoNQPMPENm_-jUrkmYjXtlX723ge1rVfkHedvt3CCOp5YUhYYOktpZDWMk4Z4axfyk5sdU/',
#                'properties': {'company': {'value': 'MadKudu'},
#                               'firstname': {'value': 'kolokithas'},
#                               'lastmodifieddate': {'value': '1511808703222'},
#                               'lastname': {'value': 'Record11'}},
#                'vid': 860626},
#               {'addedAt': 1456333839974,
#                'canonical-vid': 860674,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333839969,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '1d13913a-4b63-437e-9799-b900fe7d63c6'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333839969,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-578@test-org.com'}],
#                                       'saved-at-timestamp': 1511413619107,
#                                       'vid': 860674}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mPnm436miB6x2zsJm2PeYPZOti3GtLbjoT0EN-5nV0nAdwDbj-Pe9yolrvAjLzEKdx8Jn1enZEHBiLw311CR21hzCtHgfUyvX8BNm2Ccq9Sug3lC2UHB-McGNTc9fpnM3PlOE_g',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mPnm436miB6x2zsJm2PeYPZOti3GtLbjoT0EN-5nV0nAdwDbj-Pe9yolrvAjLzEKdx8Jn1enZEHBiLw311CR21hzCtHgfUyvX8BNm2Ccq9Sug3lC2UHB-McGNTc9fpnM3PlOE_g/',
#                'properties': {'company': {'value': 'MadKudu'},
#                               'firstname': {'value': 'John'},
#                               'lastmodifieddate': {'value': '1511807791583'},
#                               'lastname': {'value': 'cruz'}},
#                'vid': 860674},
#               {'addedAt': 1456333849586,
#                'canonical-vid': 860724,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333849582,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '33644ef6-0b8d-4b1e-ab1b-346e3a4773ae'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1512081116939,
#                                                       'type': 'EMAIL',
#                                                       'value': 'new-email99@hubspot.com'}],
#                                       'saved-at-timestamp': 1512081116948,
#                                       'vid': 860724}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mM-a-lsdCF5R_c84lA5bP5xXPvPrDQlcIKrvO6p_tZAqZqSMCxHdOrfx3mvRpq9NhlU83x__pgvQ805gySoXcrMTRKCalP-6xufObztiiRGlwvneKxtJTok0xm9NCMMiRCZdB42',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mM-a-lsdCF5R_c84lA5bP5xXPvPrDQlcIKrvO6p_tZAqZqSMCxHdOrfx3mvRpq9NhlU83x__pgvQ805gySoXcrMTRKCalP-6xufObztiiRGlwvneKxtJTok0xm9NCMMiRCZdB42/',
#                'properties': {'company': {'value': 'MadKudu'},
#                               'firstname': {'value': 'Updated'},
#                               'lastmodifieddate': {'value': '1512081140521'},
#                               'lastname': {'value': 'Record'}},
#                'vid': 860724},
#               {'addedAt': 1456333869192,
#                'canonical-vid': 860775,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333869190,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '8e77a1e2-a2f3-4700-ad16-2194118ea169'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333869201,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-587@test-org.com'}],
#                                       'saved-at-timestamp': 1511401626850,
#                                       'vid': 860775}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mNEJ00N_oo1iANvy7QLdI6IbMGq-XxbOZhrpTPl4NBZ0IvYw94l-lRg5bIBVeFytOYTL83rBrRNKagobefN7jyhsYBFD-Pl7aHgEVgp7x9uMyZJOuzxOcBUcnMIxYIArozU8_oh',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mNEJ00N_oo1iANvy7QLdI6IbMGq-XxbOZhrpTPl4NBZ0IvYw94l-lRg5bIBVeFytOYTL83rBrRNKagobefN7jyhsYBFD-Pl7aHgEVgp7x9uMyZJOuzxOcBUcnMIxYIArozU8_oh/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993245'},
#                               'lastname': {'value': ''}},
#                'vid': 860775},
#               {'addedAt': 1456333873752,
#                'canonical-vid': 860824,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333873749,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'afdfb6ba-167d-4483-b763-4c7d54061522'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333873748,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-588@test-org.com'}],
#                                       'saved-at-timestamp': 1511414279605,
#                                       'vid': 860824}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mNJ6Mn3upA-2yfmBU3MZ3xNHXLAkIjtCXJvqt9Ofx2umGjR99eZgDpBi4Va3XEZAHfopjoQ_D4bt7Yv7y_HKKAZUdIzQtlhAoLUrGHf7RppBGfbQJOQdr8kJ3iUiOHsNuUeQAic',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mNJ6Mn3upA-2yfmBU3MZ3xNHXLAkIjtCXJvqt9Ofx2umGjR99eZgDpBi4Va3XEZAHfopjoQ_D4bt7Yv7y_HKKAZUdIzQtlhAoLUrGHf7RppBGfbQJOQdr8kJ3iUiOHsNuUeQAic/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985312'},
#                               'lastname': {'value': ''}},
#                'vid': 860824},
#               {'addedAt': 1456333895045,
#                'canonical-vid': 860826,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333895033,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'ed60d869-a96d-48a4-9434-6e00c8e70b02'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333894997,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-594@test-org.com'}],
#                                       'saved-at-timestamp': 1511417369152,
#                                       'vid': 860826}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mNyQWgT1w4ik_mg_ka8hNrrCht4B_sntl_zhHhJomQQRj2ygAd4OCAbKD89BLNtS-SWLfY71xyX-5NyuTOn8ILqDhqmh97temV4fEge-TsLr7XknPsExme3T71BDsArXD9zCOQC',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mNyQWgT1w4ik_mg_ka8hNrrCht4B_sntl_zhHhJomQQRj2ygAd4OCAbKD89BLNtS-SWLfY71xyX-5NyuTOn8ILqDhqmh97temV4fEge-TsLr7XknPsExme3T71BDsArXD9zCOQC/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168984918'},
#                               'lastname': {'value': ''}},
#                'vid': 860826},
#               {'addedAt': 1456333905477,
#                'canonical-vid': 860827,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333905475,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'bb7d2d4c-e2b6-4a7c-a109-e0c623a2eea8'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333905475,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-597@test-org.com'}],
#                                       'saved-at-timestamp': 1511387850983,
#                                       'vid': 860827}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mNGB4FEYpaJeaEtyJgl_53EYBtVVrZnj5WzE2_qM1kM0FAitVCsx7304foESr3KeZoWDUHSGcNwyn3WrQHQofECAEiBQOWxZEDIwS86NR2Vb3QfETE0PjfRqrHkuK_q0x5AtEJ4',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mNGB4FEYpaJeaEtyJgl_53EYBtVVrZnj5WzE2_qM1kM0FAitVCsx7304foESr3KeZoWDUHSGcNwyn3WrQHQofECAEiBQOWxZEDIwS86NR2Vb3QfETE0PjfRqrHkuK_q0x5AtEJ4/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985223'},
#                               'lastname': {'value': ''}},
#                'vid': 860827},
#               {'addedAt': 1456333876933,
#                'canonical-vid': 860874,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333876930,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'a40b38e3-a6e1-4589-937b-0b0bac1e77b5'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333876932,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-589@test-org.com'}],
#                                       'saved-at-timestamp': 1511406703625,
#                                       'vid': 860874}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOJlDyLOsHfYNbabZDjH0qAnO92-sMNc076oFwd2COj3-45nKUldJ3ge6IyXWhAuXfR1wTB9GW1vBZ9k2aIBXyCzdMyhZoWQDZVoc8YwDa_bwFBSacLyvzvRjnJLDqm2UuLChkI',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOJlDyLOsHfYNbabZDjH0qAnO92-sMNc076oFwd2COj3-45nKUldJ3ge6IyXWhAuXfR1wTB9GW1vBZ9k2aIBXyCzdMyhZoWQDZVoc8YwDa_bwFBSacLyvzvRjnJLDqm2UuLChkI/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168986341'},
#                               'lastname': {'value': ''}},
#                'vid': 860874},
#               {'addedAt': 1456333879866,
#                'canonical-vid': 860924,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333879862,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '6c9c08c2-9ca6-4c9b-b29a-7573abeb2bc9'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333879859,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-590@test-org.com'}],
#                                       'saved-at-timestamp': 1511406511747,
#                                       'vid': 860924}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOZvcmvIZjYOaJWFZpxNfzu197_5o2Snw9qSrIMU17u_5iB5nBBnPIk7d2Ihg-z6bBQaqJV7NBs-m0POzhI9WjCh0ESP7J6ooFhpiJVibkdc2f3MtYGXW__S9WzO8SzcrF9Ir7x',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOZvcmvIZjYOaJWFZpxNfzu197_5o2Snw9qSrIMU17u_5iB5nBBnPIk7d2Ihg-z6bBQaqJV7NBs-m0POzhI9WjCh0ESP7J6ooFhpiJVibkdc2f3MtYGXW__S9WzO8SzcrF9Ir7x/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993245'},
#                               'lastname': {'value': ''}},
#                'vid': 860924},
#               {'addedAt': 1456333891024,
#                'canonical-vid': 860925,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333891023,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'af8028c1-643e-4b09-98a2-a722443f96fa'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333891019,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-593@test-org.com'}],
#                                       'saved-at-timestamp': 1511394679428,
#                                       'vid': 860925}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mN9zcj69-Fn2xW8JKc9_yJ6qkiIFPE030AtvigixalkBikjxb3ur6Fs6mdV3f9_9k8pYSI2OUkLXgUQW7b4Zil4XOVWxZo3BtnNgTX84ZNshPjtsiUzpamKjMHmNmXhGv1Dz9zX',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mN9zcj69-Fn2xW8JKc9_yJ6qkiIFPE030AtvigixalkBikjxb3ur6Fs6mdV3f9_9k8pYSI2OUkLXgUQW7b4Zil4XOVWxZo3BtnNgTX84ZNshPjtsiUzpamKjMHmNmXhGv1Dz9zX/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993208'},
#                               'lastname': {'value': ''}},
#                'vid': 860925},
#               {'addedAt': 1456333886862,
#                'canonical-vid': 860974,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333886858,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '30beee07-69d6-4bb5-abd3-7dce8e2fdfcb'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333886845,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-592@test-org.com'}],
#                                       'saved-at-timestamp': 1511406703629,
#                                       'vid': 860974}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mMnyj6ZpONmevdUvmjvoicJjm58Qqch8vOBFpHjJTvBjFtNMJMWTBUl6JYVrE4Swv6eRK4iPEr05njBV-QHka54flxUeLZF8mDLJwq5gvizCilsFIcWbJmm5qemsqWkxkAmAqD9',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mMnyj6ZpONmevdUvmjvoicJjm58Qqch8vOBFpHjJTvBjFtNMJMWTBUl6JYVrE4Swv6eRK4iPEr05njBV-QHka54flxUeLZF8mDLJwq5gvizCilsFIcWbJmm5qemsqWkxkAmAqD9/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985313'},
#                               'lastname': {'value': ''}},
#                'vid': 860974},
#               {'addedAt': 1456333898836,
#                'canonical-vid': 861024,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333898833,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '8569af4e-9a43-410d-bbd8-06b70627a860'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333898816,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-595@test-org.com'}],
#                                       'saved-at-timestamp': 1511412528538,
#                                       'vid': 861024}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mNWrHRR9gvxNvuPNYTuZxw0Rc8bLYvVBrqH1ds4X6BUgRiwS08y96gLIXIiH7Mbx-awWhyfjSi9Cafvq8A748y9thjHDOVQ-DxI2twschL2v4328QoiH_EBmiP4UqO1Fk1ZdwBU',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mNWrHRR9gvxNvuPNYTuZxw0Rc8bLYvVBrqH1ds4X6BUgRiwS08y96gLIXIiH7Mbx-awWhyfjSi9Cafvq8A748y9thjHDOVQ-DxI2twschL2v4328QoiH_EBmiP4UqO1Fk1ZdwBU/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985402'},
#                               'lastname': {'value': ''}},
#                'vid': 861024},
#               {'addedAt': 1456333902068,
#                'canonical-vid': 861074,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333902065,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '7c3b72b9-9546-496e-b36c-e0d78915ccd7'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333902053,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-596@test-org.com'}],
#                                       'saved-at-timestamp': 1511387850985,
#                                       'vid': 861074}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mPIzECCzJgooarqg1ds8qUECeUjyZEhMI4jZPQsdZo81xv8CcKOlLsPSxaYjoMMtkDZzreJwS8qWCJEhaXwuvcAUh-SdCjsiDCxQ05dNPO0Ji4Rb4_Gk6XmpQFkdI0nwvhSUySW',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mPIzECCzJgooarqg1ds8qUECeUjyZEhMI4jZPQsdZo81xv8CcKOlLsPSxaYjoMMtkDZzreJwS8qWCJEhaXwuvcAUh-SdCjsiDCxQ05dNPO0Ji4Rb4_Gk6XmpQFkdI0nwvhSUySW/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168985462'},
#                               'lastname': {'value': ''}},
#                'vid': 861074},
#               {'addedAt': 1456333909454,
#                'canonical-vid': 861124,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333909451,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '6efbeed0-3ae5-4f5d-bf1c-4a66b70aadb1'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333909440,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-598@test-org.com'}],
#                                       'saved-at-timestamp': 1511417369155,
#                                       'vid': 861124}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mPXRzFd6RX6J7bZcHs2wLEj9AA22Fx5MUD54V--7FvF5Z7glxj3aiMArsoIEsHyms0vOmVZruM7Z26_SiFW8ym_rvyYO3FiWh0QAHYue5xlyKCGeJGeHbPr34eP3rK-8wDu4JGx',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mPXRzFd6RX6J7bZcHs2wLEj9AA22Fx5MUD54V--7FvF5Z7glxj3aiMArsoIEsHyms0vOmVZruM7Z26_SiFW8ym_rvyYO3FiWh0QAHYue5xlyKCGeJGeHbPr34eP3rK-8wDu4JGx/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993149'},
#                               'lastname': {'value': ''}},
#                'vid': 861124},
#               {'addedAt': 1456333912776,
#                'canonical-vid': 861125,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333912775,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'aef91226-9c9f-41cf-9ec8-087e86425a3c'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333912774,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-599@test-org.com'}],
#                                       'saved-at-timestamp': 1511417369158,
#                                       'vid': 861125}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOyt9AwK4VkLkyImaP3Ii9DW-PQYHKG4IRvHNXAg8558TDRqPozl3Y8sfjY1zjMA0ShtBOVeVj6jvnquzJjjVs2iLACmy_fJzP9YvKoP57NA3BrL_S5zZTEGkTAWcNXZGKRXd9j',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOyt9AwK4VkLkyImaP3Ii9DW-PQYHKG4IRvHNXAg8558TDRqPozl3Y8sfjY1zjMA0ShtBOVeVj6jvnquzJjjVs2iLACmy_fJzP9YvKoP57NA3BrL_S5zZTEGkTAWcNXZGKRXd9j/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993299'},
#                               'lastname': {'value': ''}},
#                'vid': 861125},
#               {'addedAt': 1456333916475,
#                'canonical-vid': 861126,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333916475,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'ea55e82f-9430-442a-a587-89e9f72c1be5'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333916472,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-600@test-org.com'}],
#                                       'saved-at-timestamp': 1511412528539,
#                                       'vid': 861126}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mMb08rjqoqF_0OL4qt3adyjiib0TnuwXUihJx3iJF1x5VXKlPogoUBqJpNzYGndvTe_kv08_MhyXk1lq-Wkb7OjBYheG4qOlTDWGNo28vkuRuKjxLfSgjYV7JpnWsKxxSVoZ6hu',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mMb08rjqoqF_0OL4qt3adyjiib0TnuwXUihJx3iJF1x5VXKlPogoUBqJpNzYGndvTe_kv08_MhyXk1lq-Wkb7OjBYheG4qOlTDWGNo28vkuRuKjxLfSgjYV7JpnWsKxxSVoZ6hu/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1508168993221'},
#                               'lastname': {'value': ''}},
#                'vid': 861126},
#               {'addedAt': 1456333921007,
#                'canonical-vid': 861127,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456333921006,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'e8d18c0a-2f60-4264-a03b-bc2a899ac922'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456333921003,
#                                                       'type': 'EMAIL',
#                                                       'value': 'juanignaciosl-ded-05-601@test-org.com'}],
#                                       'saved-at-timestamp': 1511414279608,
#                                       'vid': 861127}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOkQAfI2hKNQc5EUVDVuO7w3lP-DksTwnf6VVpF3Xjy1xkXSl20scVOhgLKgCQPaxBvr5VX3Vm72vrOyAaE-ewiXLhSbFtXcHTeiy2Lf-w9SSIb9OaU3HqxDKJxnzo0rJ8fatNv',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOkQAfI2hKNQc5EUVDVuO7w3lP-DksTwnf6VVpF3Xjy1xkXSl20scVOhgLKgCQPaxBvr5VX3Vm72vrOyAaE-ewiXLhSbFtXcHTeiy2Lf-w9SSIb9OaU3HqxDKJxnzo0rJ8fatNv/',
#                'properties': {'company': {'value': 'MadKudu'},
#                               'firstname': {'value': 'heloooo'},
#                               'lastmodifieddate': {'value': '1511808702486'},
#                               'lastname': {'value': 'world'}},
#                'vid': 861127},
#               {'addedAt': 1456346615407,
#                'canonical-vid': 861324,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456346615403,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '019c059a-5ea8-474a-83c9-09df44d7ba6a'}],
#                                       'saved-at-timestamp': 1456346615407,
#                                       'vid': 861324}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mPXdCj1mONzsZTGYxuFDxkntWZK31oSVjdJDmsPMguTRz4IAS9hy0jjBvTAmv6jCgD2joLz00Rt8AzLzqcKDLfWBJ3ii_vUCeOv1wg5rsblUW8CLdA4UMTaxQSiFyK3w3lyQxjd',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mPXdCj1mONzsZTGYxuFDxkntWZK31oSVjdJDmsPMguTRz4IAS9hy0jjBvTAmv6jCgD2joLz00Rt8AzLzqcKDLfWBJ3ii_vUCeOv1wg5rsblUW8CLdA4UMTaxQSiFyK3w3lyQxjd/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1506640548059'},
#                               'lastname': {'value': ''}},
#                'vid': 861324},
#               {'addedAt': 1456346646707,
#                'canonical-vid': 861374,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456346646597,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '38af330f-84cd-4f98-84e7-17b3e1bf45bd'}],
#                                       'saved-at-timestamp': 1456346646707,
#                                       'vid': 861374}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mOr20kXy10iuAg9W_mVyL3lxLpMcCDT8UCmNLi23wsa8LIYRplmC4P8pObhu-XEZb3-Mn1pRJ_xs4Oqgcm0nUeHajQp3FIwjcKZV_r5w2HURUx1Z46A7Ds9_Ic_ODEefCzAwteA',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mOr20kXy10iuAg9W_mVyL3lxLpMcCDT8UCmNLi23wsa8LIYRplmC4P8pObhu-XEZb3-Mn1pRJ_xs4Oqgcm0nUeHajQp3FIwjcKZV_r5w2HURUx1Z46A7Ds9_Ic_ODEefCzAwteA/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': ''},
#                               'lastmodifieddate': {'value': '1506607498918'},
#                               'lastname': {'value': ''}},
#                'vid': 861374},
#               {'addedAt': 1456348505362,
#                'canonical-vid': 861424,
#                'form-submissions': [],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1456348505357,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '90e35407-95bf-493f-9558-a37b86d179da'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1456348505349,
#                                                       'type': 'EMAIL',
#                                                       'value': 'jefftaggart@gmail.com'}],
#                                       'saved-at-timestamp': 1511397633821,
#                                       'vid': 861424}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 62515,
#                'profile-token': 'AO_T-mN4D1YPecH1xaU5jC_fzBH6xRiy0TSWpm5UMbGBCsJsEGtSlHxXSm-UYKRmNnklwTMw_Rv7sNiDXSm8b1PP_8hlVSeUe6_IGzNFKW35YKeE8OIhFMK5MNpWXQm_dZmXBTx92whg',
#                'profile-url': 'https://app.hubspot.com/contacts/62515/lists/public/contact/_AO_T-mN4D1YPecH1xaU5jC_fzBH6xRiy0TSWpm5UMbGBCsJsEGtSlHxXSm-UYKRmNnklwTMw_Rv7sNiDXSm8b1PP_8hlVSeUe6_IGzNFKW35YKeE8OIhFMK5MNpWXQm_dZmXBTx92whg/',
#                'properties': {'company': {'value': 'MadKudu '},
#                               'firstname': {'value': 'Jeff'},
#                               'lastmodifieddate': {'value': '1507664534064'},
#                               'lastname': {'value': 'Taggart'}},
#                'vid': 861424}],
#  'has-more': True,
#  'vid-offset': 861424}

# %% [markdown]
# ## Day 3
#
# Python doesn't provide much error checking out of the box. I spent a lot of time trying to figure out how access values in python data structures, in this case - nested lists and dictionaries.
#
# Below is the working script that I created that just gave me back a specific value (first name) in the json object pulled from Hubspot.

# %%
from pprint import pprint
import urllib.request, json

# Store api key value into variable
APIKEY_VALUE = "demo"

# concat query string with api key
APIKEY = "?hapikey=" + APIKEY_VALUE

# hs api end point stored to a variable
HS_API_URL = "http://api.hubapi.com"

def get_contacts():
    # builds the correct url
    xurl = "/contacts/v1/lists/all/contacts/all"
    url = HS_API_URL + xurl + APIKEY 
    # Now we use urllib to open the url and read it
    response = urllib.request.urlopen(url).read()
    #loads to json obj to all_contacts variable
    all_contacts = json.loads(response)
    #return the contact data
    return all_contacts

# calls the function stores to variable
contacts = get_contacts()

##pretty print just the first name in a contact record
pprint(contacts['contacts'][0]['properties']['firstname']['value'])
# Out:
# 'kolokithas'

# %% [markdown]
# ## Day 4
#
# Time to create my database! I installed postgreSQL through brew in my terminal and created a database through the command line with myself as a user and protected password. Once I had that set up I had to create my data model. I went through and selected data points I wanted from all the data I was collecting.
#
# I then realized for speed, I would use a GUI to create my data model and set up my tables. I installed Postico and created a **contacts** table for the data I wanted based on what my company needs for reporting.

# %% [markdown]
# ## Day 5
#
# Now that I have an idea of how to access values, I need to iterate through all of the contacts and pull in only those values and create a script that puts that data into my postgreSQL db.
#
# After pulling in specific values, I found a lot of missing values in certain fields. For the purposes of this project, I wanted complete data. I had to create some logic that filled in blank fields with values so that I could create a complete list of data to insert into the db.
#
# Below is my script for structuring all of my data into a new "thin" or clean list.
#
# Libraries Used:
# - **pprint** for pretty printing json objects so I can easily see where the values were in the data structure.
# - **urllib.request** to open api url and read it.
# - **json** to load data in json format.

# %%
from pprint import pprint
import urllib.request, json

# Store api key value into variable
APIKEY_VALUE = "demo"

# concat api query string with api key
APIKEY = "?hapikey=" + APIKEY_VALUE

# hs api end point stored to a variable
HS_API_URL = "http://api.hubapi.com"

thin_contact_list = []

def get_contacts():
    # builds the correct url
    xurl = "/contacts/v1/lists/all/contacts/all"
    url = HS_API_URL + xurl + APIKEY 
    # Now we use urllib to open the url and read it
    response = urllib.request.urlopen(url).read()
    #loads to json obj to all_contacts variable
    all_contacts = json.loads(response)
    #return the contact data
    return all_contacts

def process_contacts(contact_list):
    new_contact_list = []
    
    #create a loop through contacts dict and store values to new list
    for i in range(len(contacts['contacts'])):

        #store values needed to variables
        first_name= contacts['contacts'][i]['properties']['firstname']['value']
        last_name= contacts['contacts'][i]['properties']['lastname']['value']
        
        email = ''
        for identity in contacts['contacts'][i]['identity-profiles'][0]['identities']:
            if identity['type'] == 'EMAIL':
                email = identity['value']
        
        created_on= contacts['contacts'][i]['addedAt']
        last_login= contacts['contacts'][i]['identity-profiles'][0]['saved-at-timestamp']

        #added mock values to blanks in fields
        if(first_name == ''):
         first_name = 'Amanda'

        if(last_name == ''):
         last_name = 'Miranda'

        if(email == ''):
         email = 'unicorn@aweseomeco.com'

        #created contact dict to go into db
        contact = {"firstname": first_name,
                   "lastname": last_name,
                   "email": email,
                   "createdon": created_on,
                   "lastlogin": last_login
                  }

        new_contact_list.append(contact)
    
    return new_contact_list
        
# Start processing logic
if __name__== "__main__":
    #invoke function to get data from api
    contacts = get_contacts()
    #process list of contacts
    thin_contact_list = process_contacts(contacts)
    
    print(thin_contact_list)
# Out:
# [{'firstname': 'kolokithas', 'lastname': 'Record11', 'email': 'new-email1@hubspot.com', 'createdon': 1456333855820, 'lastlogin': 1511397633819}, {'firstname': 'John', 'lastname': 'cruz', 'email': 'juanignaciosl-ded-05-578@test-org.com', 'createdon': 1456333839974, 'lastlogin': 1511413619107}, {'firstname': 'Updated', 'lastname': 'Record', 'email': 'new-email99@hubspot.com', 'createdon': 1456333849586, 'lastlogin': 1512081116948}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-587@test-org.com', 'createdon': 1456333869192, 'lastlogin': 1511401626850}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-588@test-org.com', 'createdon': 1456333873752, 'lastlogin': 1511414279605}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-594@test-org.com', 'createdon': 1456333895045, 'lastlogin': 1511417369152}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-597@test-org.com', 'createdon': 1456333905477, 'lastlogin': 1511387850983}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-589@test-org.com', 'createdon': 1456333876933, 'lastlogin': 1511406703625}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-590@test-org.com', 'createdon': 1456333879866, 'lastlogin': 1511406511747}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-593@test-org.com', 'createdon': 1456333891024, 'lastlogin': 1511394679428}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-592@test-org.com', 'createdon': 1456333886862, 'lastlogin': 1511406703629}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-595@test-org.com', 'createdon': 1456333898836, 'lastlogin': 1511412528538}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-596@test-org.com', 'createdon': 1456333902068, 'lastlogin': 1511387850985}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-598@test-org.com', 'createdon': 1456333909454, 'lastlogin': 1511417369155}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-599@test-org.com', 'createdon': 1456333912776, 'lastlogin': 1511417369158}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'juanignaciosl-ded-05-600@test-org.com', 'createdon': 1456333916475, 'lastlogin': 1511412528539}, {'firstname': 'heloooo', 'lastname': 'world', 'email': 'juanignaciosl-ded-05-601@test-org.com', 'createdon': 1456333921007, 'lastlogin': 1511414279608}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'unicorn@aweseomeco.com', 'createdon': 1456346615407, 'lastlogin': 1456346615407}, {'firstname': 'Amanda', 'lastname': 'Miranda', 'email': 'unicorn@aweseomeco.com', 'createdon': 1456346646707, 'lastlogin': 1456346646707}, {'firstname': 'Jeff', 'lastname': 'Taggart', 'email': 'jefftaggart@gmail.com', 'createdon': 1456348505362, 'lastlogin': 1511397633821}]

# %% [markdown]
# ## Day 5 Continued...
#
# Now that I have a thin list of data, I needed to create my script to insert data into a database. This was the surprisingly easiest part of the whole project.
#
# Below is the script I created to insert data into my sql db. This script will only work for localhost connection to db.
#
# Libraries used:
# - **psycopg2** used to allow my python script to talk to postgres in one connection session. Pretty easy to follow.
# - **sys**

# %%
import psycopg2
import sys

# print to see if you have access to the clean new list of contact data
# print(thin_contact_list)

# start with no connection
con = None

# try to connect
try:
    # adapter to connect to postgres db 
    con = psycopg2.connect(database='hsbd', user='nat') 
    # allows python code to execute sql commands
    cur = con.cursor()
    # execute method that process sql commands in db
    cur.execute('SELECT version()')          
    # error check connection to db
    ver = cur.fetchone()
    print (ver, "i can conncet")    
    
    # loop through clean list and insert to db
    for contact in thin_contact_list:
        cur.execute("INSERT INTO contacts(first_name, last_name, email) VALUES ('"+ contact['firstname'] + "','" + contact['lastname'] + "',' " + contact['email'] + "')")
        # error check print to see if each record was inserted
        print('inserted')
    
    # commit everything in this session to db
    con.commit()

# exception error handling for failed connection    
except psycopg2.DatabaseError as e:
    print ('Error %s' % e)    
    sys.exit(1)
    

# closes session to db after everything runs    
finally:
    
    if con:
        con.close()
# Out:
# ('PostgreSQL 9.6.6 on x86_64-apple-darwin13.4.0, compiled by clang version 4.0.1 (tags/RELEASE_401/final), 64-bit',) i can conncet
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted

# %% [markdown]
# ## Peer Feedback on Day 5
#
# After talking it over with a peer, I received the following feedback and decided to make these changes

# %% [markdown]
# ## Here are some overall notes on the skills I learned
# And perhaps some stream of consciousness notes about what I did, and other questions I might have
