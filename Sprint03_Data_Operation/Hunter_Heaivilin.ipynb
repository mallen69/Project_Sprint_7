# %% [markdown]
# # Data Operation Sprint Journal for Hunter Heaivilin

# %% [markdown]
# ---
# ## DAY 1: Tuesday (Week 1)
# ### What I Expect to Learn
# * How loops work in R
# * How to write a **for** loop in R
# * The basics of data types in R (e.g., vector, list, matrix, data frame, tibble, etc)
# *  *Replace with a summary of what you hope to accomplish with this project and how it fits into your overall roadmap. This includes key questions such as things you want to find out and definitions you want to establish and clarify.*
#
#
#
# ****
# ### Project References
#
# - [How to write the first for loop in R](https://www.r-bloggers.com/how-to-write-the-first-for-loop-in-r/)
# - [A Tutorial on Loops in R - Usage and Alternatives](https://www.datacamp.com/community/tutorials/tutorial-on-loops-in-r)
# - [Loops in R](https://swcarpentry.github.io/r-novice-inflammation/15-supp-loops-in-depth/)
# - [R for Data Science: Iteration](http://r4ds.had.co.nz/iteration.html)
# - [Introduction to version control using git](https://nicercode.github.io/git/)
# - [Webscraping in R](https://rpubs.com/ryanthomas/webscraping-with-rvest)
#
# ****
#
# ### Project Pitch
# - Use R to scrape tables of data about various crops from thousands of webpages at a website. Once scraped the data will need to be added to a single data frame and output into a csv or other widelt accessible format.
#
# - Stretch Goal 1: Scrape a metadata matrix with multiple uses for each crop, add the crop key to each use, and compile all uses of all crops into a data frame.
# - Stretch Goal 2: Run the scrape/append process in paralell to speed up processing time
#
#
# ****
# ### What I Got Done
#
# 1. Started setting up Git within RStudio for more streamlined version tracking. [This tutorial](https://nicercode.github.io/git/) was a big help.
# 2. Completed the [Intro to SQL for Data Science](https://www.datacamp.com/courses/intro-to-sql-for-data-science) tutorial on [DataCamp](datacamp.com).

# %% [markdown]
# #### Framing project notes:
#
# Before you engage in structured analysis, you often just want to “see” the data. This can mean pre-viewing a subset of it, summarizing the columns/attributes/features, sorting or reorganizing it and otherwise finding ways to immerse yourself in your data. Again, each data tool has something to offer, and our objective is to develop a good sense of the utilities available to you.
# Tools: R, Python, Command Line | Pre-reqs: git, Jupyter Notebooks, some programming
#
# As a data engineer, I need to understand the programming basics of automation so that I can implement algorithms and develop tools that work efficiently (also big o notation, computability and complexity, sorting and searching algorithms
#
#
# ... I need to filter, search, and remove features from my data set so that I can conduct targeted investigations
#
#  I need to understand the programming basics of automation so that I can develop tools that work efficiently (also big o notation, computability and complexity, sorting and searching algorithms)
#
#  ...I need to understand the programming basics so that I can implement algorithms

# %% [markdown]
# ---
# ## DAY 2: Wednesday (Week 1)
# ### Pitch Feedback
# *Solemn nods*
#
# ### Prototype Notes
# Rejigged my **for** loop somewhat.
# From this:
#
#
#
# > ~~~~
# > # Grab URL set and read entire list of crop datasheet urls into a variable
# > urllists <- read.csv("/Users/hunterheaivilin/GitHub/Data-Operations/datasheeturl.csv")
#
# > # Create variable of a few of the urls (*remove [1:3,] to use entire list*)
# > webpages <- tibble(urllists[1:3,])
#
# > # for loop to move through through the url list
# > for(i in 1:nrow(webpages)) {
# >   url <- toString(webpages[i,1])
# >   html <- read_html(url) # read URLs html into a 'html' variable
# > ~~~~
#
#
# into this:
# >~~~~
# ># Read entire list of crop datasheet urls into a variable
# >urls <- read_lines("/Users/hunterheaivilin/GitHub/Data-Operations/datasheeturl.csv")
#
# >myDataFrame <- read.csv("/Users/hunterheaivilin/GitHub/Tables-All-The-Way-Down/ecocrop_colnames.csv", header=TRUE, >stringsAsFactors=FALSE)
#
# ># for loop to move through through the url list
# >for(i in (urls[2:8])) {
#   html <- read_html(i)
# >~~~~
#
# ### Pair Show & Tell Comments
# NULL
#
# ### Proposed Plan: Key Milestones by Day
#
# ##### Day 2 (Wed Week 1):
# - [x] Develop Project Proposal
# - [x] Roadmap Update
# - [x] Get a version of the scrape running
# - [x] Push Docs
# - [x] Repo
#
#
# ##### Day 3 (Thu Week 1):
# - [] Make sure the long variable list is either comment annotated or rename variable to communicate what data is being stored
#     - Go from c1 <- i to either a) c1 <- i #Crop Code or b) cropcode <- i
# - [] Get the Uses table scraper script functioning and added to a new master use list with crop codes
# - [] Add a function progress bar to the primary table scraper to be able to view percent completion
# - [] Push docs / repo
#
# ##### Day 4 (Tue Week 2):
# - - [] Make sure the long variable list is either comment annotated or rename variable to communicate what data is being stored
#     - Go from c1 <- i to either a) c1 <- i #Crop Code or b) cropcode <- i
# - [] Add a function progress bar to the primary table scraper to be able to view percent completion
# - Update readme
# - Push docs / repo
#
# ##### Day 5 (Wed Week 2):
# - Project highlights
# - Identify question or cohort knowledge gap for sprint review
# - Develop Topic Project + Presentation
# - Push Repo / docs / Presentation
#
# ### Project Definition and README.MD Discussion
# *This is a discussion of how this project will fit into my overall roadmap. I will update my roadmap with the following project definition*
#
# *I will focus my project Repo's README.MD on the same topic, but with this additional detail.*

# %% [markdown]
# ---
# ## DAY 3: Friday (Week 1)
# Skipped class, but worked on my own.
#
# #### Setup for Repo and Documentation Push
# - Setup my repo
#
# #### Repo File Strategy Discussion
# *How I will present my repo files for clarity and demonstration*
#
# #### Work towards milestone 1: Get the Uses table scraper script functioning!
# - Used a new function, bind_rows to add the list of uses and crop code to a new master use list
#
#
# #### Work towards milestone 2: Get the View crop url list and scraper script functioning!
# Made some good headway, but hit an error related to clashing column names.
#
# >Error in match.names(clabs, names(xi)) :
# > names do not match previous names

# %% [markdown]
# ---
# ## DAY 4: Tuesday (Week 2)
#
# #### Work in Progress Feedback
# - Knowing more about the data structures I'm using will be helpful to understand the errors I hit goign forward.
# It is possible that I could create poorly funcitoning data outputs if I dont have a clear sense of the input parameters for a given data structure type.
#
#
# #### Work towards milestone 2: Get the View crop url list and scraper script functioning!
# RE:
# >Error in match.names(clabs, names(xi)) :
# > names do not match previous names
#
#
# I reworked the output compendium of cell scrapes from
#
# >  vewcrop <- c (Ecocrop_code,...)
#
# to
#
# >  vewcrop <- list (Ecocrop_code, ...)
#
# and that fixed the issue.
# ___
# Ran the code and it made it most of the way through the url list, but then stopped and spit out this error:
# > Error in open.connection(x, "rb") : HTTP error 500.
#
# which was related to
#
# >~~~~
# >Warning message:
# >closing unused connection 3 (http://ecocrop.fao.org/ecocrop/srv/en/cropView?id=17648)
# >~~~~
# Apparently that single webpage, and possibly others, has some issues. So I used an internal **if** statement to check the url status from within the **for** loop. See handy [tutorial](https://stackoverflow.com/questions/45733802/r-scraping-skip-html-error-500-in-loop).
#
#
# >~~~~
# >library(httr
# >for(i in (urls2)) {
# >    r = GET(i)
# >    status = status_code(r)
# >    if(status != 500){
# >~~~~
#
# #### Work towards milestone 3: Create a progress bar
#
# *Work I did towards Milestone *

# %% [markdown]
# ---
#
# ## DAY 5: Wednesday (Week 2)
#
# ### Project Highlights: The things I am most excited about in my project
# Me
# -
# -
# -
#
# Peer Identified
#
# -
# -
# -
#
# ### Peer Repo Feedback
#
# *Here are the changes I am making to my repo structure for additional clarity*
# -
# -
# -

# %% [markdown]
# ## Day 6: Thursday (Week 2)
# ---
#
# #### Things I didn't get to
# *Here are some ideas that I didn't get to implement, but wanted to. I will be adding these to my roadmap table entry for this sprint as well.*
# - Combine the 3 scripts into fewer, for ease of use by others
