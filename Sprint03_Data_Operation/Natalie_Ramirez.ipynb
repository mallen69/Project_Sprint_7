# %% [markdown]
# # Data Operations - Sprint Journal for Natalie Ramirez

# %% [markdown]
# ---
# ## DAY 1: Tuesday (Week 1)
# ### What I Expect to Learn
#
# I want to learn how to automate the process of exporting aggregating data into a readable file to a designated folder in google drive. I hope to determine which tools best fit the needs of my data analysis.
#
# Key Questions:
# - What are the differences between tables and dataframes?
# - What are the differences between lists and arrays?
# - If my data is already modeled and in my database how am I going to companre an external data source for duplicates? Will I have to aggregate data all in one table or will I have another data dump table that just has everything and use that to compare?
#
# ### Project References
# - [RAM Cloud Project](https://ramcloud.atlassian.net/wiki/spaces/RAM/pages/6848531/Data+Operations)
# - [Comparing two or more data frames and find rows that appear in more than one data frame, or rows that appear only in one data frame.](http://www.cookbook-r.com/Manipulating_data/Comparing_data_frames/)
# - [Comparing matching data structures in Tableau](http://kb.tableau.com/articles/howto/comparing-matching-and-non-matching-records-across-blended-data-sources)
#
# ### Project Pitch
# - In this sprint I will compare data from different data sources for duplicate records in R and then upload unique records to a PostgreSQL database.
# - This project will help my aggregate, normalize, and structure data using data operations.

# %% [markdown]
# ---
# ## DAY 2: Wednesday (Week 1)
# ### Pitch Feedback
# - Use R to compare records.
# - Make sure to normalize data to create data model.
#
# ### Prototype Notes
# *Results from prototype experiments, snippets of code, things I tried *
#
# ### Pair Show & Tell Comments
# *Comments from prototype discussion*
# - Can use the cookbook-r as resource
# - Can complete datacamp R intro course
# - Can also try to remove duplicates straight in SQL.
#
# ### Proposed Plan: Key Milestones by Day
#
# ##### Day 2 (Wed Week 1):
# - Develop Project Proposal
# - Push Docs / Repo / Roadmap Update
#
# ##### Day 3 (Thu Week 1):
# - Normalize Data
# - Generate Data Model
# - Create Dups Script
# - Push docs / repo
#
# ##### Day 4 (Tue Week 2):
# - Fix Python Script to collect new data
# - Update Python Script to insert data into SQL Database
# - Push docs / repo
#
# ##### Day 5 (Wed Week 2):
# - Project highlights
# - Identify question or cohort knowledge gap for sprint review
# - Develop Topic Project + Presentation
# - Push Repo / docs / Presentation
#
# ### Project Definition and README.MD Discussion
# *This is a discussion of how this project will fit into my overall roadmap. I will update my roadmap with the following project definition*
#
# *I will focus my project Repo's README.MD on the same topic, but with this additional detail.*

# %% [markdown]
# ---
# ## DAY 3: Thursday (Week 1)
#
# #### Setup for Repo and Documentation Push
# *Setup and testing I did to make sure my repo and documentation were ready to push at the end of the day*
#
# #### Repo File Strategy Discussion
# *How I will present my repo files for clarity and demonstration*
#
# #### Work towards milestone 1
# Collected all possible data points needed to collect from data sources.
#
# #### Work towards milestone 2
# Created list of tables needed to create in PostgreSQL db.
#
# #### Work towards milestone 3
# Created UML with data model for this project.

# %% [markdown]
# ---
# ## DAY 4: Tuesday (Week 2)
#
# #### Work in Progress Feedback
# *Feedback and ideas from my work in progress presentation *
#
# #### Work towards milestone 1
# Update script to collect only data I want to insert into PostgreSQL database.

# %%
from pprint import pprint
import urllib.request, json

# Store api key value into variable
APIKEY_VALUE = "c6ba6fa8-84c5-40d3-a30e-8d6d414a21c7"

# concat api query string with api key
APIKEY = "?hapikey=" + APIKEY_VALUE

# hs api end point stored to a variable
HS_API_URL = "http://api.hubapi.com"

thin_contact_list = []

def get_contacts():
    # builds the correct url
    xurl = "/contacts/v1/lists/all/contacts/all"
    url = HS_API_URL + xurl + APIKEY 
    # Now we use urllib to open the url and read it
    response = urllib.request.urlopen(url).read()
    # print("response", response)
    # loads to json obj to all_contacts variable
    all_contacts = json.loads(response)
    # return the contact data
    return all_contacts

def process_contacts(contact_list):
    new_contact_list = []
    
    #create a loop through contacts dict and store values to new list
    for i in range(len(contacts['contacts'])):

        #store values needed to variables
        first_name= contacts['contacts'][i]['properties']['firstname']['value']
        last_name= contacts['contacts'][i]['properties']['lastname']['value']
        
        email = ''
        for identity in contacts['contacts'][i]['identity-profiles'][0]['identities']:
            if identity['type'] == 'EMAIL':
                email = identity['value']
        
        created_on= contacts['contacts'][i]['addedAt']
        last_login= contacts['contacts'][i]['identity-profiles'][0]['saved-at-timestamp']

        #added mock values to blanks in fields
        if(first_name == ''):
         first_name = 'Amanda'

        if(last_name == ''):
         last_name = 'Miranda'

        if(email == ''):
         email = 'unicorn@aweseomeco.com'

        #created contact dict to go into db
        contact = {"firstname": first_name,
                   "lastname": last_name,
                   "email": email,
                   "createdon": created_on,
                   "lastlogin": last_login
                  }

        new_contact_list.append(contact)
    
    return new_contact_list
        
contacts = get_contacts()
#process list of contacts
# thin_contact_list = process_contacts(contacts)
    
pprint(contacts)
# Out:
# {'contacts': [{'addedAt': 1509002991527,
#                'canonical-vid': 3351,
#                'form-submissions': [{'conversion-id': '3a3584c0-5562-46fd-8de6-fb5f1f2c000c',
#                                      'form-id': '57f532b3-f2a2-44ee-ae45-52e5f19e78a1',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Cyber Security '
#                                                    'Professional',
#                                      'page-url': 'https://www.devleague.com/tracks/view/cyber-security-professional',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1509302829895,
#                                      'title': 'Cyber Security Curriculum '
#                                               'Download  lead flow (June 28, '
#                                               '2017 4:30:56 PM)'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1498837252122,
#                                                       'type': 'TAG_ID',
#                                                       'value': 'messages-a20bbaca6cb92bca938fe3d32134c5f3'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1509002990734,
#                                                       'type': 'EMAIL',
#                                                       'value': 'caseyaf@hawaii.edu'},
#                                                      {'timestamp': 1509002991431,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '5ddf2044-36ab-49dc-a816-48e41e2ab9c5'}],
#                                       'saved-at-timestamp': 1509002991433,
#                                       'vid': 3351}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mM2RexlHqnCScEEPjFRUdWnwgOAMSJpjQ-68eTT23EK2FR5h6jRCwhzVzJsBOTODOp7NetiC9DMhNjcxMlAYIg86hPGO48wYWtajiyUgPEnIMlyVdqbmv6vZ8wIK_WUI3ekLTZO',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mM2RexlHqnCScEEPjFRUdWnwgOAMSJpjQ-68eTT23EK2FR5h6jRCwhzVzJsBOTODOp7NetiC9DMhNjcxMlAYIg86hPGO48wYWtajiyUgPEnIMlyVdqbmv6vZ8wIK_WUI3ekLTZO/',
#                'properties': {'firstname': {'value': 'Casey'},
#                               'lastmodifieddate': {'value': '1510003042472'},
#                               'lastname': {'value': 'Fukuda'}},
#                'vid': 3351},
#               {'addedAt': 1494787683399,
#                'canonical-vid': 8451,
#                'form-submissions': [{'conversion-id': '1c95f4a9-f624-49cb-a42c-44077901c659',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Join The '
#                                                    'Movement. Learn to Code in '
#                                                    'Hawaii!',
#                                      'page-url': 'http://www.devleague.com/companies',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1494787680837,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1494787683359,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '86c1dbf8-59ed-4747-bebd-b287bbfef677'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1494787680837,
#                                                       'type': 'EMAIL',
#                                                       'value': 'iwata.jni@gmail.com'}],
#                                       'saved-at-timestamp': 1511403228521,
#                                       'vid': 8451}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mMx_sYRpV31M3pghh9ayYk7Cizo34vm2RgP_nNqfFL13XRpqY_HTFlKPSJySzGrAf8Vd3EfIBrlxz2h6dHt5XUFe3rP7bvm5PIUQ5lnjbS3LHGPnNyvpAKbLhHa7yW9EG3TVcd1',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mMx_sYRpV31M3pghh9ayYk7Cizo34vm2RgP_nNqfFL13XRpqY_HTFlKPSJySzGrAf8Vd3EfIBrlxz2h6dHt5XUFe3rP7bvm5PIUQ5lnjbS3LHGPnNyvpAKbLhHa7yW9EG3TVcd1/',
#                'properties': {'firstname': {'value': 'Jordan'},
#                               'lastmodifieddate': {'value': '1509591661114'},
#                               'lastname': {'value': 'Ikaika'}},
#                'vid': 8451},
#               {'addedAt': 1494806783007,
#                'canonical-vid': 9651,
#                'form-submissions': [{'conversion-id': '72e1a870-e9c5-45df-a111-68921c99c59d',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Join The '
#                                                    'Movement. Learn to Code in '
#                                                    'Hawaii!',
#                                      'page-url': 'http://www.devleague.com/funding',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1494806780750,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1494806782959,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'f772c921-eda2-4ab1-9931-54d7c21472e8'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1494806780750,
#                                                       'type': 'EMAIL',
#                                                       'value': 'emilyha17@gmail.com'}],
#                                       'saved-at-timestamp': 1511416795072,
#                                       'vid': 9651}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mOE7FHGHBUt-8cSdYVbiewzNNW99nn8ZtwqQR1ikJ1FABYeZ2gcThLT0Ax6EhZkzjyj_keyj5L1pLEwY28OTh4fQgoV27K0ZhoECGTScrJFjG7wumBTaGX7KNR8oHP0LWZta4Ma',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mOE7FHGHBUt-8cSdYVbiewzNNW99nn8ZtwqQR1ikJ1FABYeZ2gcThLT0Ax6EhZkzjyj_keyj5L1pLEwY28OTh4fQgoV27K0ZhoECGTScrJFjG7wumBTaGX7KNR8oHP0LWZta4Ma/',
#                'properties': {'firstname': {'value': 'Emily'},
#                               'lastmodifieddate': {'value': '1509597649504'}},
#                'vid': 9651},
#               {'addedAt': 1494819734767,
#                'canonical-vid': 10651,
#                'form-submissions': [{'conversion-id': 'c2aadf81-aadc-417f-977a-df2d7be94303',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Join The '
#                                                    'Movement. Learn to Code in '
#                                                    'Hawaii!',
#                                      'page-url': 'http://www.devleague.com/tracks/view/big-data-analyst',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1494819733353,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1494819734730,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '515a6df4-4f43-4fdb-9d41-6f291dbf8fbd'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1494819733353,
#                                                       'type': 'EMAIL',
#                                                       'value': 'aschaefers@staradvertiser.com'}],
#                                       'saved-at-timestamp': 1511421990928,
#                                       'vid': 10651}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mNMN85IWdh11HkkCa8Hme5M-eD-1-KDPzasIVvXqClGRCyQbCZuIWTgfTEwztOPQ4EM9zeDUaLlCcj60pPSQx8dscnWh4eFxtMizyoJzaZvNQt0JQqDZXznGwS-j2Vf1WkFfa1R',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mNMN85IWdh11HkkCa8Hme5M-eD-1-KDPzasIVvXqClGRCyQbCZuIWTgfTEwztOPQ4EM9zeDUaLlCcj60pPSQx8dscnWh4eFxtMizyoJzaZvNQt0JQqDZXznGwS-j2Vf1WkFfa1R/',
#                'properties': {'firstname': {'value': 'Allison'},
#                               'lastmodifieddate': {'value': '1509575173381'},
#                               'lastname': {'value': 'Schaefers'}},
#                'vid': 10651},
#               {'addedAt': 1510433765283,
#                'canonical-vid': 11201,
#                'form-submissions': [{'conversion-id': 'd9757bc1-40f5-4c18-8436-e8be924bdff5',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Enterprise '
#                                                    'Software Developer',
#                                      'page-url': 'https://www.devleague.com/tracks/view/enterprise-software-developer',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1510433763228,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1499664871422,
#                                                       'type': 'TAG_ID',
#                                                       'value': 'messages-a8a5f0ba1022951ec0ba77ed90023199'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1510433763228,
#                                                       'type': 'EMAIL',
#                                                       'value': 'amwawe@gmail.com'},
#                                                      {'timestamp': 1510433765239,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'e9353973-1b5a-48d7-b78a-77f9088f25a6'}],
#                                       'saved-at-timestamp': 1510433765243,
#                                       'vid': 11201}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mMs8uIZ5_5FrVbD0tIFi6cti4hc_tTf2xmVykwxpoPY0xvh9oxsVxetvSJQXwLU73QdPywAWWz03ED2MDJksrHUMeRVAxPqRQI6ndjIRTMTRixZxKAv1RAx-l4Opq_nOAcdDlDl',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mMs8uIZ5_5FrVbD0tIFi6cti4hc_tTf2xmVykwxpoPY0xvh9oxsVxetvSJQXwLU73QdPywAWWz03ED2MDJksrHUMeRVAxPqRQI6ndjIRTMTRixZxKAv1RAx-l4Opq_nOAcdDlDl/',
#                'properties': {'firstname': {'value': 'Antony'},
#                               'lastmodifieddate': {'value': '1511990031117'}},
#                'vid': 11201},
#               {'addedAt': 1494873407023,
#                'canonical-vid': 11901,
#                'form-submissions': [{'conversion-id': 'ff45f671-39a4-4f56-9a2a-82ef72b51a83',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Join The '
#                                                    'Movement. Learn to Code in '
#                                                    'Hawaii!',
#                                      'page-url': 'http://www.devleague.com/tracks/view/javascript-web-engineer',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1494873404516,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1494873406963,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'eb4121a5-76e1-4c37-aaab-4c8f5f066681'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1494873404516,
#                                                       'type': 'EMAIL',
#                                                       'value': 'leejwg.3@gmail.com'}],
#                                       'saved-at-timestamp': 1511382573703,
#                                       'vid': 11901}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mMgcFaB_D5qB8TTIa9YIg7x6mSz-J30_Z9JPB5ca917_BNShyzM5TPN9s6-WuWO9jc2HluBQEwRXm-djqRIP3uaYrcOf98Baylc3yzBtIxXXJoub2E78eLI8wMvCAMAXM7hfrY9',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mMgcFaB_D5qB8TTIa9YIg7x6mSz-J30_Z9JPB5ca917_BNShyzM5TPN9s6-WuWO9jc2HluBQEwRXm-djqRIP3uaYrcOf98Baylc3yzBtIxXXJoub2E78eLI8wMvCAMAXM7hfrY9/',
#                'properties': {'firstname': {'value': 'Justin'},
#                               'lastmodifieddate': {'value': '1512595915416'},
#                               'lastname': {'value': 'Lee'}},
#                'vid': 11901},
#               {'addedAt': 1499392303409,
#                'canonical-vid': 12951,
#                'form-submissions': [{'conversion-id': '91fd9512-df4b-4f47-80dc-087dd7712cb0',
#                                      'form-id': 'bded335b-33cc-4a93-b478-6ba51a9db786',
#                                      'form-type': 'CAPTURED',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Cyber Security '
#                                                    'Professional',
#                                      'page-url': 'http://localhost:3000/tracks/view/cyber-security-professional',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1499392972995,
#                                      'title': '#hubspot-form'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1499392303376,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '45dae3c1-088c-4498-9c13-bdc1c1387480'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1499392972995,
#                                                       'type': 'EMAIL',
#                                                       'value': 'afsd@j.com'}],
#                                       'saved-at-timestamp': 1511403228524,
#                                       'vid': 12951}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mMf1MyYD7vG2KX7lOsL9QSfVmabnX4ByHRw8BEJvwD9Gv3z20UBRrkKXD6bu2DIp34xttD-EiaxvnYqWOdh7_iCjFbPRoa81onNBFnP5E9V80NcXOn9zdwpk87C7Dqfj0wWTbDM',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mMf1MyYD7vG2KX7lOsL9QSfVmabnX4ByHRw8BEJvwD9Gv3z20UBRrkKXD6bu2DIp34xttD-EiaxvnYqWOdh7_iCjFbPRoa81onNBFnP5E9V80NcXOn9zdwpk87C7Dqfj0wWTbDM/',
#                'properties': {'firstname': {'value': 'acdf'},
#                               'lastmodifieddate': {'value': '1509591661091'}},
#                'vid': 12951},
#               {'addedAt': 1498972703240,
#                'canonical-vid': 14551,
#                'form-submissions': [{'conversion-id': '8df5833e-cd1f-4a76-8d78-74975272b143',
#                                      'form-id': '57f532b3-f2a2-44ee-ae45-52e5f19e78a1',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Cyber Security '
#                                                    'Professional',
#                                      'page-url': 'https://www.devleague.com/tracks/view/cyber-security-professional',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1513291946152,
#                                      'title': 'Cyber Security Curriculum '
#                                               'Download  lead flow (June 28, '
#                                               '2017 4:30:56 PM)'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1498972703208,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '660c3570-b067-4116-8632-76ec01e509a7'},
#                                                      {'timestamp': 1498972790094,
#                                                       'type': 'TAG_ID',
#                                                       'value': 'messages-e52e1bbe845f6d7902a6127ae077da8c'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1498972701574,
#                                                       'type': 'EMAIL',
#                                                       'value': 'shang.ong82@gmail.com'}],
#                                       'saved-at-timestamp': 1511403228526,
#                                       'vid': 14551}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mOycvt_xYHg_8yHNmoyEasJd6spdVlphaB2zFFGRsgRkuxflDIR42FgZYS8kRQAYlrmkbB660C3qessGeAqvRWvy1uY2MKL426kG9dBzJHMxaQmPJ4vy_O06iewQFQqFYFaL1Hz',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mOycvt_xYHg_8yHNmoyEasJd6spdVlphaB2zFFGRsgRkuxflDIR42FgZYS8kRQAYlrmkbB660C3qessGeAqvRWvy1uY2MKL426kG9dBzJHMxaQmPJ4vy_O06iewQFQqFYFaL1Hz/',
#                'properties': {'firstname': {'value': 'Shang'},
#                               'lastmodifieddate': {'value': '1513741873043'},
#                               'lastname': {'value': 'Ong'}},
#                'vid': 14551},
#               {'addedAt': 1496706590663,
#                'canonical-vid': 16701,
#                'form-submissions': [{'conversion-id': '2b956a23-c7dd-4c39-a7b9-9bd805ade6fc',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Enrollment '
#                                                    'Application Form',
#                                      'page-url': 'https://application.devleague.com/enroll/#javascript-web-engineer-august-2017-full-time',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1496706589308,
#                                      'title': 'Lead flow: Initial general '
#                                               'information inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1496706590610,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '730d1ad5-4d6f-443f-9591-838f68bb1ed5'},
#                                                      {'timestamp': 1499836281945,
#                                                       'type': 'TAG_ID',
#                                                       'value': 'messages-a67191c306c854e6a1c72fd3fd17925c'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1496706589308,
#                                                       'type': 'EMAIL',
#                                                       'value': 'ericrickyallenpeters@gmail.com'}],
#                                       'saved-at-timestamp': 1511423667173,
#                                       'vid': 16701}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mM1HTyn6fQWGDp4KjXYLwGkfS1QhxL0IoBgw9qUdhcxuikP0AmZQa8AOBSq7a8o3kwqdXdaohsXZQucRxNOPk0AwL0S8yAPme7BQ5wFIo4Vk_utu0rEMZ46iDcfzE_t5E5uaiv-',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mM1HTyn6fQWGDp4KjXYLwGkfS1QhxL0IoBgw9qUdhcxuikP0AmZQa8AOBSq7a8o3kwqdXdaohsXZQucRxNOPk0AwL0S8yAPme7BQ5wFIo4Vk_utu0rEMZ46iDcfzE_t5E5uaiv-/',
#                'properties': {'firstname': {'value': 'Ricky'},
#                               'lastmodifieddate': {'value': '1512595948238'},
#                               'lastname': {'value': 'Peters'}},
#                'vid': 16701},
#               {'addedAt': 1495248067392,
#                'canonical-vid': 17601,
#                'form-submissions': [{'conversion-id': '1518d8c2-8909-4b0f-b7d7-88664868191f',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Join The '
#                                                    'Movement. Learn to Code in '
#                                                    'Hawaii!',
#                                      'page-url': 'http://www.devleague.com/',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495248065824,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495248067350,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '0fbc0926-3ea1-44d1-8306-8b10bd1c1217'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495248065824,
#                                                       'type': 'EMAIL',
#                                                       'value': 'ramcharan.yadav.rte@gmail.com'}],
#                                       'saved-at-timestamp': 1511403058096,
#                                       'vid': 17601}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mM8uDObp40HpG1jOUfzVbJXN3w-sbzgIa5cosdJJjjZ3qXgxQZNxJYzavupi-YRYEvH6mES5sCDOF1xApMNoj3uZpKtT3vHJVCurlqOdOKFZMevYgVvnwPO8pLTAQL__Pv3Rq-c',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mM8uDObp40HpG1jOUfzVbJXN3w-sbzgIa5cosdJJjjZ3qXgxQZNxJYzavupi-YRYEvH6mES5sCDOF1xApMNoj3uZpKtT3vHJVCurlqOdOKFZMevYgVvnwPO8pLTAQL__Pv3Rq-c/',
#                'properties': {'firstname': {'value': 'Ramcharan'},
#                               'lastmodifieddate': {'value': '1509603934325'}},
#                'vid': 17601},
#               {'addedAt': 1495044727797,
#                'canonical-vid': 18301,
#                'form-submissions': [{'conversion-id': '9eb36688-d302-4c02-92be-52fa50a37fe4',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Join The '
#                                                    'Movement. Learn to Code in '
#                                                    'Hawaii!',
#                                      'page-url': 'http://www.devleague.com/',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495044723191,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495044727756,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'bdb59842-d7d9-4ee1-8249-eca8a9aecd05'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495044723191,
#                                                       'type': 'EMAIL',
#                                                       'value': 'ellisa678@gmail.com'}],
#                                       'saved-at-timestamp': 1511417624787,
#                                       'vid': 18301}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mN2GCALFk252HD746KgduNn0-Smogu7bxJe-7d3iNnbLsQibM70iQto1ew6r9MdQhj0QwFCghfBhg7IULs04bnOj7hlvXHfDaCVjqLPWRTblLh0ey8YGQit0ZgvUloNJd0FiOlg',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mN2GCALFk252HD746KgduNn0-Smogu7bxJe-7d3iNnbLsQibM70iQto1ew6r9MdQhj0QwFCghfBhg7IULs04bnOj7hlvXHfDaCVjqLPWRTblLh0ey8YGQit0ZgvUloNJd0FiOlg/',
#                'properties': {'firstname': {'value': 'Ellisa'},
#                               'lastmodifieddate': {'value': '1509583474275'}},
#                'vid': 18301},
#               {'addedAt': 1495097408068,
#                'canonical-vid': 19851,
#                'form-submissions': [{'conversion-id': 'ce36b82a-8663-4db9-a177-5fd1976dd8ae',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Join The '
#                                                    'Movement. Learn to Code in '
#                                                    'Hawaii!',
#                                      'page-url': 'http://www.devleague.com/faq',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495097405219,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495097408033,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '26832cf4-6da2-4d51-9f56-29e184df69e3'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495097405219,
#                                                       'type': 'EMAIL',
#                                                       'value': 'michaelc511@gmail.com'}],
#                                       'saved-at-timestamp': 1511400856746,
#                                       'vid': 19851}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mOagSiHjc9ph-nwaS4qx5ds1F5VL7DICXg0Vjcxcxgog7pnQ4D7EKq3m7udd8u-c62Ox-2M3q9KqwnVtOnlSyLvW42Sm3OOBY4FZIZrWSoAmi01Oya8Y_zsetpahqHS3Wju1r9c',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mOagSiHjc9ph-nwaS4qx5ds1F5VL7DICXg0Vjcxcxgog7pnQ4D7EKq3m7udd8u-c62Ox-2M3q9KqwnVtOnlSyLvW42Sm3OOBY4FZIZrWSoAmi01Oya8Y_zsetpahqHS3Wju1r9c/',
#                'properties': {'firstname': {'value': 'Michael'},
#                               'lastmodifieddate': {'value': '1509602405218'},
#                               'lastname': {'value': 'Chang'}},
#                'vid': 19851},
#               {'addedAt': 1495617042457,
#                'canonical-vid': 22201,
#                'form-submissions': [{'conversion-id': '4eabe499-f54c-4f6d-b767-a02b925ba786',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Enterprise '
#                                                    'Software Developer',
#                                      'page-url': 'http://www.devleague.com/tracks/view/enterprise-software-developer',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495617039721,
#                                      'title': 'Lead flow: Initial general '
#                                               'information inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495617042321,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '27e750d8-59ab-4d5b-9099-05f0acb31c44'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495617039721,
#                                                       'type': 'EMAIL',
#                                                       'value': 'mishra.tanisha1@gmail.com'}],
#                                       'saved-at-timestamp': 1511384896692,
#                                       'vid': 22201}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mPd2zb3XupyyKWATGQqJWNhLnBbYNyrWaMhAvPL5zdYdqsAnWn1NguI3KSHrBJcmAtub3vZ1pyIQfR5V5BnIWlBZ_ecNzxJqgcLAe4Z0CID8I4Fl5anP5_0S--AlJPjLklvxxYb',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mPd2zb3XupyyKWATGQqJWNhLnBbYNyrWaMhAvPL5zdYdqsAnWn1NguI3KSHrBJcmAtub3vZ1pyIQfR5V5BnIWlBZ_ecNzxJqgcLAe4Z0CID8I4Fl5anP5_0S--AlJPjLklvxxYb/',
#                'properties': {'lastmodifieddate': {'value': '1509559818356'}},
#                'vid': 22201},
#               {'addedAt': 1495359632920,
#                'canonical-vid': 27901,
#                'form-submissions': [{'conversion-id': 'c0955c18-b35e-4b7d-b587-869f5c551e7a',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Cyber Security '
#                                                    'Professional',
#                                      'page-url': 'http://www.devleague.com/tracks/view/cyber-security-professional',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495359632154,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495359632870,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'dcb32f2f-4e55-4e04-a07c-a8692696bf05'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495359632154,
#                                                       'type': 'EMAIL',
#                                                       'value': 'kanakigrl@hotmail.com'}],
#                                       'saved-at-timestamp': 1511417624789,
#                                       'vid': 27901}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mNvVtVtVK_aEE1o2_UlaZGUgmtiqTg6N1JGsDjpqCm0zVmpAd-P6yw0kamEogxrfOzVhDvQ3OwuB7il_UiFOgU7bgJ2bgKYs4vXmOo9T2JZ3eWQuNZf-avnrXwCGejpPV014K3z',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mNvVtVtVK_aEE1o2_UlaZGUgmtiqTg6N1JGsDjpqCm0zVmpAd-P6yw0kamEogxrfOzVhDvQ3OwuB7il_UiFOgU7bgJ2bgKYs4vXmOo9T2JZ3eWQuNZf-avnrXwCGejpPV014K3z/',
#                'properties': {'lastmodifieddate': {'value': '1509583474303'}},
#                'vid': 27901},
#               {'addedAt': 1495365574439,
#                'canonical-vid': 28051,
#                'form-submissions': [{'conversion-id': '64a4a106-b68f-4acd-bae3-bf471449d639',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Join The '
#                                                    'Movement. Learn to Code in '
#                                                    'Hawaii!',
#                                      'page-url': 'http://www.devleague.com/careers',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495365571880,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495365574387,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '292208a7-c330-4e46-94d6-853c260e7901'},
#                                                      {'timestamp': 1499297962744,
#                                                       'type': 'TAG_ID',
#                                                       'value': 'messages-1ffe5028aae1c07d4f8e9fb6b27e90a3'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495365571880,
#                                                       'type': 'EMAIL',
#                                                       'value': 'kaley.kriminger@gmail.com'}],
#                                       'saved-at-timestamp': 1511389638629,
#                                       'vid': 28051}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mPA-Flp5xUjZ6lADTNb4BNi9iqoLulI8HVSwb0gMOZoefvBupO7_4jxU2psYWSMCflmCwlsrFprzQF4JdYd4byBR65ETEOESKx7vFC4kJkhk9qFeJxWfwjVVQ0-_7E6jAnuX6Jh',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mPA-Flp5xUjZ6lADTNb4BNi9iqoLulI8HVSwb0gMOZoefvBupO7_4jxU2psYWSMCflmCwlsrFprzQF4JdYd4byBR65ETEOESKx7vFC4kJkhk9qFeJxWfwjVVQ0-_7E6jAnuX6Jh/',
#                'properties': {'firstname': {'value': 'Kaley'},
#                               'lastmodifieddate': {'value': '1512595954895'},
#                               'lastname': {'value': 'Kriminger'}},
#                'vid': 28051},
#               {'addedAt': 1495370196909,
#                'canonical-vid': 28201,
#                'form-submissions': [{'conversion-id': '46642f17-b061-4ac6-a069-45e6410d7b7e',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Enrollment '
#                                                    'Application Form',
#                                      'page-url': 'https://application.devleague.com/enroll/#big-data-analyst-aug-2017',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495370195817,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495370196866,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'dc528f57-f11e-45ae-bd1c-a0a4dcd141f2'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495370195817,
#                                                       'type': 'EMAIL',
#                                                       'value': 'vazquez.gerry@gmail.com'}],
#                                       'saved-at-timestamp': 1511389638639,
#                                       'vid': 28201}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mNjH9PvvBrM8BvEM4NzWGKrVcCnBNbRfsZPcqmWwIKdEVOXgEfzGM3xCgl-W6xB2xdldcck5cZAl_1Ff52fTsA-x_JdmpNgVqcB0m0wb-6EGm7gbBPjNoIkaSp5PO8tl3MTGaD6',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mNjH9PvvBrM8BvEM4NzWGKrVcCnBNbRfsZPcqmWwIKdEVOXgEfzGM3xCgl-W6xB2xdldcck5cZAl_1Ff52fTsA-x_JdmpNgVqcB0m0wb-6EGm7gbBPjNoIkaSp5PO8tl3MTGaD6/',
#                'properties': {'firstname': {'value': 'Gerry'},
#                               'lastmodifieddate': {'value': '1509565220931'},
#                               'lastname': {'value': 'Vasquez'}},
#                'vid': 28201},
#               {'addedAt': 1495438552407,
#                'canonical-vid': 29701,
#                'form-submissions': [{'conversion-id': '18070abf-3770-46cb-9b7d-1e649aafe20b',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Cyber Security '
#                                                    'Professional',
#                                      'page-url': 'http://www.devleague.com/tracks/view/cyber-security-professional',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495438551718,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495438552364,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '148689ac-af8f-443b-a911-17a46faf97aa'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495438551718,
#                                                       'type': 'EMAIL',
#                                                       'value': 'randy1075@icloud.com'}],
#                                       'saved-at-timestamp': 1511390020069,
#                                       'vid': 29701}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mN3i5FbhAJoryfPNU4YNaC8HV96kKgVS6UaMyG4UZAJD21YbHZM3jNaarg5aeLhPQgYdmOjozE10qqbi4WH44qi3GDPrRsBgc78iRk1SCA6-69jn_6SOyqp7FgFYyWM1fhRHWhB',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mN3i5FbhAJoryfPNU4YNaC8HV96kKgVS6UaMyG4UZAJD21YbHZM3jNaarg5aeLhPQgYdmOjozE10qqbi4WH44qi3GDPrRsBgc78iRk1SCA6-69jn_6SOyqp7FgFYyWM1fhRHWhB/',
#                'properties': {'firstname': {'value': 'Randy'},
#                               'lastmodifieddate': {'value': '1513099005337'},
#                               'lastname': {'value': 'Nitahara'}},
#                'vid': 29701},
#               {'addedAt': 1496445016832,
#                'canonical-vid': 30351,
#                'form-submissions': [{'conversion-id': 'ff2af705-b3f6-40fb-98dd-05155241b6e5',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Enrollment '
#                                                    'Application Form',
#                                      'page-url': 'https://application.devleague.com/enroll/#enterprise-software-developer-sept-2017',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1496445014140,
#                                      'title': 'Lead flow: Initial general '
#                                               'information inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1496445016790,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '5a152e89-4868-4f9c-8538-6eff54bd8d1d'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1496445014140,
#                                                       'type': 'EMAIL',
#                                                       'value': 'meeshell.kim@gmail.com'}],
#                                       'saved-at-timestamp': 1511410882705,
#                                       'vid': 30351}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mOMZb_hADg3-SZHPXgjjJ3DKstmJCO-ZJtZJDDHIOZa8TDyID8c6WUxgjSOKA8E6_63_ZDTxJTNcgl9Aex_zqgOBkNKzEuXjqfCcdXSMNZr7k3QT6Q_Wr1JD2gXlto6VT6ZbIQQ',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mOMZb_hADg3-SZHPXgjjJ3DKstmJCO-ZJtZJDDHIOZa8TDyID8c6WUxgjSOKA8E6_63_ZDTxJTNcgl9Aex_zqgOBkNKzEuXjqfCcdXSMNZr7k3QT6Q_Wr1JD2gXlto6VT6ZbIQQ/',
#                'properties': {'firstname': {'value': 'Michelle'},
#                               'lastmodifieddate': {'value': '1509582192286'},
#                               'lastname': {'value': 'Kim'}},
#                'vid': 30351},
#               {'addedAt': 1495487164135,
#                'canonical-vid': 30801,
#                'form-submissions': [{'conversion-id': '89d148ef-d1eb-4977-9673-e4cba13c75f8',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | DevLeague Prep',
#                                      'page-url': 'http://www.devleague.com/tracks/view/devleague-prep',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495487161833,
#                                      'title': 'Initial general information '
#                                               'inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495487164033,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': '6adb2541-270b-413c-9e7c-7ba5a3f53e3d'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495487161833,
#                                                       'type': 'EMAIL',
#                                                       'value': 'tlctups@hawaii.rr.com'}],
#                                       'saved-at-timestamp': 1511403228530,
#                                       'vid': 30801}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mOVXWtccy90FA0Q_mgRZ2Rj5Fm4oN7l5lrqPeeSgnVzz2czDwf-T3ionf39YXk_8n4GC0_hB3XrPzV9sndSfY7cf6AwdadkksHDgAIBvq6OGn8lMv6JEBhe9f5mfetMPderq_Z9',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mOVXWtccy90FA0Q_mgRZ2Rj5Fm4oN7l5lrqPeeSgnVzz2czDwf-T3ionf39YXk_8n4GC0_hB3XrPzV9sndSfY7cf6AwdadkksHDgAIBvq6OGn8lMv6JEBhe9f5mfetMPderq_Z9/',
#                'properties': {'firstname': {'value': 'Sheri'},
#                               'lastmodifieddate': {'value': '1509591661098'},
#                               'lastname': {'value': 'Higashionna'}},
#                'vid': 30801},
#               {'addedAt': 1495845295990,
#                'canonical-vid': 32651,
#                'form-submissions': [{'conversion-id': 'cde9d034-db3c-44fd-bd9f-02a8d272ba36',
#                                      'form-id': '4e2a0106-4e3a-432e-9f68-fbe584ffbf5c',
#                                      'form-type': 'FLOW',
#                                      'meta-data': [],
#                                      'page-title': 'DevLeague | Enrollment '
#                                                    'Application Form',
#                                      'page-url': 'https://application.devleague.com/enroll/#cyber-security-specialist-july-2017',
#                                      'portal-id': 3344155,
#                                      'timestamp': 1495845292154,
#                                      'title': 'Lead flow: Initial general '
#                                               'information inquiry'}],
#                'identity-profiles': [{'deleted-changed-timestamp': 0,
#                                       'identities': [{'timestamp': 1495845295947,
#                                                       'type': 'LEAD_GUID',
#                                                       'value': 'd646fa9f-3659-4d97-9e4e-1276e4a0bfd0'},
#                                                      {'is-primary': True,
#                                                       'timestamp': 1495845292154,
#                                                       'type': 'EMAIL',
#                                                       'value': 'nkobashigawa@hawaii.rr.com'}],
#                                       'saved-at-timestamp': 1511382573705,
#                                       'vid': 32651}],
#                'is-contact': True,
#                'merge-audits': [],
#                'merged-vids': [],
#                'portal-id': 3344155,
#                'profile-token': 'AO_T-mM88wUPF3gsstoEfTNHZ5ZbXp_GcaTOuRADt0D335ssJwSZyqVzTylPiESYJHC-J9ChoNCoBsrZysR8cGSa6_h74f7pNuvX9jvT60ADTsj4EW9E529Q67b8KSWaahMs631UHTiw',
#                'profile-url': 'https://app.hubspot.com/contacts/3344155/lists/public/contact/_AO_T-mM88wUPF3gsstoEfTNHZ5ZbXp_GcaTOuRADt0D335ssJwSZyqVzTylPiESYJHC-J9ChoNCoBsrZysR8cGSa6_h74f7pNuvX9jvT60ADTsj4EW9E529Q67b8KSWaahMs631UHTiw/',
#                'properties': {'lastmodifieddate': {'value': '1509556225325'}},
#                'vid': 32651}],
#  'has-more': True,
#  'vid-offset': 32651}

# %% [markdown]
# #### Work towards milestone 2
# Update script to insert data into PostgreSQl database.

# %% [markdown]
# #### Work towards milestone 3
# Push up both project documentation and portfolio repo documentation.

# %% [markdown]
# ---
#
# ## DAY 5: Wednesday (Week 2)
#
# ### Project Highlights: The things I am most excited about in my project
# Me
# -
# -
# -
#
# Peer Identified
#
# -
# -
# -
#
# ### Peer Repo Feedback
#
# *Here are the changes I am making to my repo structure for additional clarity*
# -
# -
# -

# %% [markdown]
# ## Day 6: Thursday (Week 2)
# ---
#
# #### Things I didn't get to
# *Here are some ideas that I didn't get to implement, but wanted to. I will be adding these to my roadmap table entry for this sprint as well.
