# %% [markdown]
# # Data Manipulation Sprint Journal for Tori Larson

# %% [markdown]
# ---
# ## DAY 1: Tuesday (Week 1)
# ### What I Expect to Learn
# * Originally I wanted to gain a better understand of SQL because that was the program I was more comfortable in, I then wanted to spend maybe a day in R just to get my toes wet and see how similar it was to SQL. After some research and being forced into R I learned that there is a lot more I want to learn when it comes to R. A lot of the information I learned was a lot of fun and I would like to become more proficient in R.
#
# ### Project References
# - https://blog.hubspot.com/marketing/sql-tutorial-introduction
#     - This website had more explanations on different functions that you can run in SQL. I thought that was interesting and helpful.
# - https://data36.com/sql-for-data-analysis-tutorial-beginners/
#     - This website is going to help me figure out what to do with my data and upload it in an effective way.
#     - https://data36.com/sql-where-clause-tutorial-beginners-ep2/
#         - Learn about the "WHERE clause"
# - https://www.statmethods.net/r-tutorial/index.html
#     - I want to see what I can do with the information in not only SQL but also see why its valuable to know about R.
# -
#
# ### Project Pitch
# - My idea for my project is to take HART data and import it into SQL, I was really interested in SQL last time I worked with it so I wanted to expand upon what I learned. I dont really know whats in the data set so the goal would be just to manipulate the data and organize it in a way that is readable, may come up with a few questions to ask along the way so i can use multiple SQL query functions. I would like to use SQL for the first day and then for the second day move into R and see what is possible in R that maybe wasnt in SQL, or even use the same query functionsm but just in R.
# - This relates to the sprint because I will be manipulating data through SQL and R. Im hope that after this project I will know which functions to use in order to get answers for different sets of data as well as being more fluent in both SQL and R.

# %% [markdown]
# ---
# ## DAY 2: Wednesday (Week 1)
# ### Pitch Feedback
# *Since I did not have data yet it was hard to see what I would be working with. But, Runjini and I talked about the differences between SQL and R and why we thought it would be uselful to use both of them. We both came to the concensus that we would rather work in SQL than R. *
#
# ### Prototype Notes
# *Results from prototype experiments, snippets of code, things I tried *
#
# During Prototyping -
#
# Upload the data
# Run some queries to see what kind of data is usable.
#
# ### Pair Show & Tell Comments
# *Comments from prototype discussion*
#
# *These comments lead into plan development. Key considerations for me and my partner:  Do I have a plan? Is my plan feasible?*
#
# ### Proposed Plan: Key Milestones by Day
#
# ##### Day 2 (Wed Week 1):
# - Develop Project Proposal
# - Push Docs / Repo / Roadmap Update
#
# ##### Day 3 (Thu Week 1):
# - Finish researching scripts
# - finish half of R in datacamp.
# - *milestone X...* <-TBD
# - Update project documentation
# - Push docs / repo
#
# ##### Day 4 (Tue Week 2):
# - Work in R and learn more about elements in a data.frame.
# - continue updating project documentation - stay on top of it!
# - *milestone X+3* <- TBD
# - Push docs / repo
#
# ##### Day 5 (Wed Week 2):
# - Project highlights
# - Identify question or cohort knowledge gap for sprint review
# - Develop Topic Project + Presentation
# - Push Repo / docs / Presentation
#
# ### Project Definition and README.MD Discussion
# *This is a discussion of how this project will fit into my overall roadmap. I will update my roadmap with the following project definition*
#
# *I will focus my project Repo's README.MD on the same topic, but with this additional detail.*

# %% [markdown]
# ---
# ## DAY 3: Thursday (Week 1)
#
#
# #### Repo File Strategy Discussion
# *I presented some of the things I learned to the class including learning how to run a histogram. I ended up running a histogram for "Head per Household" for people who took the survery. It was interesting to see the information in a different way than I had seen it previously*

# %% [markdown]
# Here is the code for the histogram:

# %% [markdown]
# hist(HART_survey$ADULTS.IN.HH_Code)
#
# This is what it printed

# %% [markdown]
# ![histogram]("_torilarson/Histogram.jpeg")

# %% [markdown]
# #### Milestone 1 - Finish research scripts
# *Finally understanding the importance of scripts. sort of. putting all of the code I am running in R in my script so that i dont forget it. kind of like project documentation*
#
# #### Milestone 2 - Finish half of R in data camp
# *I started R in data camp but certainly did not finish half of it.*
# *Here are some things I learned*:
#
#     1. Basic data types
#         - Numerics(decimals) - 4.5
#         - Integers (Natural Numbers) - 4
#         - Logical (boolean) - True, False
#         - Characters (text or string) - "word"
#
#     2. Vectors!
#         - In R you create a vector with a combination function "c()"
#         - A vector is a sequence of data elements of the same basic type. Here is a vector containing three numeric values 2, 3 and 5. A boolean vector would contain: True, False, True - or something similar.
#
# #### Ran some fuctions in R
# Learned how to run frequecy's

# %% [markdown]
# #### How many woman took the survey
# > FemaleTotal <- sum(HART_survey$GENDER_Text == 'Female')
#
# > print(FemaleTotal)
#
# [1] 13974

# %% [markdown]
# #### How many men took the survey
# > MaleTotal <- sum(HART_survey$GENDER_Text == 'Male')
#
# > print(MaleTotal)
#
# [1] 12272

# %% [markdown]
# *Work I did towards Milestone *
#
# ##### Day 3 (Thu Week 1):
# - Finish researching scripts
#     - learned why scripts are so important since R deletes your work as you go and it is good to keep notes in your scripts so you know what to do later on.
# - finish half of R in datacamp.
#     - I started on some stuff in data camp but ended up spending the rest of the evening learning from Ben about vectors and dataframes. Opened up alot of questions about different operators in R.
# - Update project documentation
# - Push docs / repo

# %% [markdown]
# ---
# ## DAY 4: Tuesday (Week 2)
#
# #### Feedback from Ben
# *Create all of the files that you can save: *
# - Rscript - done
# - .RDATA - done
# - .CSV - done
#
# Look up:
# **Variable** - Named storage that our programs can manipulate.
# **Function** - A set of statements organized together to perfrom a specific task.
# **Data Type** -
#
# **Element**
#
# **SHOW PICTURE**
#
# v <- TRUE
# print(class(v))
#
# https://www.tutorialspoint.com/r/r_variables.htm
#
# #### Work in R and learn more about elements in a data.frame.
# - Researched more about vectors as well as types of operators in R.
# -
# -
# -
#
#
# #### continue updating project documentation - stay on top of it!
# *Work I did towards Milestone *
#
# #### Work towards milestone 3
# *Work I did towards Milestone *
#
# #### - Push docs / repo
# *Work I did towards Milestone *
#
#
# - *milestone X+3* <- TBD

# %% [markdown]
# ---
#
# ## DAY 5: Wednesday (Week 2)
#
# ### Project Highlights: The things I am most excited about in my project
# Me
# -
# -
# -
#
# Peer Identified
#
# -
# -
# -
#
# ### Peer Repo Feedback
#
# *Here are the changes I am making to my repo structure for additional clarity*
# -
# -
# -

# %% [markdown]
# ## Day 6: Thursday (Week 2)
# ---
#
# #### Things I didn't get to
# *Here are some ideas that I didn't get to implement, but wanted to. I will be adding these to my roadmap table entry for this sprint as well.

# %% [markdown]
# # Notes:
#
#
# ## Key Questions
# - What do I do with data loaded in SQL?
#         - How do I view it?
#         - How do I change it?
#         - How do I operate on it?
# - What do I do with data loaded in R?
#         - How do I view it?
#         - How do I change it?
#         - How do I operate on it?
# - What do I do with Data loaded in Python?
#         - How do I view it?
#         - How do I change it?
#         - How do I operate on it?
#
# ## Key Concepts
# - Data Types
# - Data Structures
# - Objects
# - Primitives
# - Literals
# - Data Type Coersion
# - Headers / Factors / Keys
# - Operations / Operators / Functions / Methods
# - Array access
# - Loops
# - Maps
#
#
# ### SQL - This is the full set of what you need to know if SQL.
# - SELECT
#         - *, MIN(), MAX(), COUNT(), AVG(), SUM()
#         - AS
#         - FROM <- designate which table
#         - WHERE (= , <>, >, <. >=, <=, BETWEEN, LIKE, IN, NOT, AND, OR, NULL, %, _) <- limit or select the sub set https://data36.com/sql-where-clause-tutorial-beginners-ep2/
#         - ORDER BY (ASC | DESC)
#         - LIMIT
#         - JOIN (ON, INNER, LEFT, RIGHT, OUTER) <- combine tables together
#         - UNION <- how you combine tables together, (pasting rows together)
#         - GROUP BY <- example: station ID
#         - HAVING
#         - INTO <- putting into temp tables? (you cannot do SELECT INTO in SQLite - Use INSERT INTO instead!)
#
# - UPDATE (SET)
# - DELETE
# - INSERT INTO (VALUES)
# - CREATE DATABASE
# - ALTER DATABASE
# - CREATE TABLE
# - ALTER TABLE
# - DROP TABLE
# - CREATE INDEX
# - DROP INDEX <- Uniqueness
#     - When is a good time to use an Index?
#         - Phonebook example?
#
# ### R
# Introduction: the typical way that you would do what SQL does in programming language without a language. The tools you have at your disposal are list or array datatype -
# #### R in a Nutshell
# - https://github.com/devleague/BigDataAnalyst_Library/blob/master/books/rinanutshell.pdf
# - Chapters
#         - 5 (overview of language - browse)
#         - 6 (syntax - literals, strings, variables, operators, loops)
#         - 7 (data objects - vectors / lists)
#         - 11 (saving, loading, and editing data)
#         - 12 (preparing Data)
#
# #### Objects and Data Types
# - Vectors (integer, double, complex, character, logical, raw) <- all objects are vectors (a list-like object)
# Vectors all have to have the same data type
# Can
#     |---|---|---|
#     |lion| Tiger| Bear|
#     |5|6|7|
#     |True|False|True|
#
#  Cannot
#
#     |---|---|---|
#     |1.2| Tiger| Bear|
#     |5.6|6|lion|
#     |True|Bear|True|
#
#
# - Lists
# - Data Frames
# - Tibbles <- like a table that says whats coming - an updated version of the dataframe.
# - Other (Matrices / Arrays / Factors)
#
# #### Programming
# - blocks (curly braces) <- groups of functionalities.
# - functions (return values, arguments, anonymous)
# - loops (repeat / while / for)
# - control flow (if /else)
# - index notation (brackets [] - INTEGER/LOGICAL, double brackets[[]], named $ )
#
# #### Reading and Writing Data
# - save() saving to .RData files
# - read.table() / read.csv, etc
# - readLines()
# - write.table()
# - RODBC / DBI (RMySQL, RSQLite, RPostgreSQL)
#
# #### Important Functions / Tools
# - c(): combine, creating vectors <- will see a lot, combining each vector.
# - paste(): concatenating <- squishes lists together
# - typeof() / class() <- what it is you are working with
# - length() <- need to know how much you need to loop
# - list(): creating lists <- like C to vector
# - list(key=value) <- header in html?
# - rbind(), cbind(): combining data structures by row or column <- meant to take the same number of rows and squish them together
# - merge(): joining by field
# - transform() / stack() / unstack() <- change the shape of your data.
# - apply() / lapply(): applying a function to all elements of a collection <-
# - plyr
# - binning: grouping data
# - subset(): selecting a specific part of your data
# - tapply() / aggregate(): functions to summarize vectors
# - sort() / order()
# - duplicated()
#
# ### Python
#
# #### Mathematical Python
# - https://github.com/devleague/BigDataAnalyst_Library/blob/master/books/mathematical_python.pdf
# - Chapters
#     - 2 Overview of the Python Language
# - Quickstart to Numpy https://docs.scipy.org/doc/numpy/user/quickstart.html
# - 10 minutes to Pandas http://pandas.pydata.org/pandas-docs/stable/10min.html
#
# #### Objects and Data Types
# - int / long, float / decimal, str,
# - list / array (append, insert, delete, count, index, reverse, sort)
# - tuple, set
# - dict <- key value pair
# - ndarray / numpy.array (.ndim / .shape / .size / .dtype)
# - Series / DataFrame (creation by dict of key: column header, value: series-like
#
# #### Programming
# - methods
# - slices
# - indenting and whitespace for blocks
# - list comprehensions
# - control flow (if, elif, else
# - loops (while, for in)
# - function (def, return, lambda)
#
# #### Reading and Writing Data <-- things to look out for that are different.
# - open()
# - file.write() / file.close()
# - file.read()
# - file.seek()
# - df.to_csv (writing to csv)
# - df.to_excel
# - pd.read_csv
# - pd.read_excel
# - df.to_hdf (python style data saving to .h5 extension)
# - pd.read_hdf
#
#
# #### Important Functions / Tools
# - help() / dir(): inspect and get information about objects, attributes, methods
# - print
# - libaries
#          - urllib (connecting / parsing)
#          - json
#          - pickle (serializing objects)
#          - sqlite
# - DataFrames
#         - df.head()
#         - df.tail()
#         - df.index()
#         - df.columns()
#         - df.values()
#         - df.describe()
#         - df.sort_index / df.sort_values
#         - [] / .at / .loc / .iloc
#         - boolean indexing
#         - df.isin
#         - df.apply
#         - df.concat
#         - df.merge (join by field)
#         - df.append
#         - df.groupby
#         - df.stack / df.unstack
#         - pd.pivot_table

# %%
runjini 
- sql queries
- re-replicate in r 
could not run like statement in R 
    - walk through side by side query 
    - query for oak in R
    
shueli 
- usgs soils data 
- functions to read a file and table 
- geo data frames
- fucntion - index that finds label based information.
