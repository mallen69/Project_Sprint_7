# %% [markdown]
# '''
# OBJECTIVES:
# 1. Build WRS system
# 2. Build Structural BMP Solution evaluator
# 3. Identify minimum BMP solution front for:
#    individual facilities
#    facilities w/in departments
#    facilities w/in city
# '''

# %%
'''
Define basic SQLAlchemy items:
    declarative base object
    connection object
    session object
    DB tables
'''
#SQLAlchemy library items:
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String
from sqlalchemy import update, insert
from sqlalchemy import and_ #used in query.filter() to joing multiple where clauses
from sqlalchemy import ForeignKey
from sqlalchemy.orm import relationship #http://docs.sqlalchemy.org/en/latest/orm/basic_relationships.html#relationship-patterns
from sqlalchemy import inspect

from SQLA_Base import Base #module containing declarative_base
from SQLA_conn_man import session, engine #module handling db and connection creation 

#Table definitions as SQLA classes: 
from SQLA_DB_base_bmp_feasibility_test_definitions import Base_BMP_Feasibility_Test_Definitions
from SQLA_DB_base_bmps import Base_BMPs
from SQLA_DB_expressions import Expressions
from SQLA_DB_facility_chars import Facility_Chars
from SQLA_DB_facility_monthly_rain import Facility_Monthly_Rain
from SQLA_DB_facility_risks import Facility_Risks
from SQLA_DB_facility_type_has_nel import Facility_Type_Has_NEL
from SQLA_DB_facility_types import Facility_Types
from SQLA_DB_feasibility_test_questions import Feasibility_Test_Questions
from SQLA_DB_pollutant_removal_rates import Pollutant_Removal_Rates
from SQLA_DB_wrs_pollutant_risks import WRS_Pollutant_Risks
Base.metadata.create_all(engine, checkfirst=True) #create SQLA classes

'''
Dictionary of "SQLAlchemy where clause lambda functions" that importCSV uses to test record uniqueness.
used as the where clause in sqlalchemy queries, updates and deletes 
Form:
    TableName:Lambda Function
    
    TableName is the table name we want to define uniqueness test for
    Lambda Function can take on any form but must be made to evaluate the CSV row passed as a dictionary (CSVRowDict in this explanation):
        CSVRowDict: {FieldName:CSVColValue, DBTableFieldName:CSVColValue...} 
            Where: DBTableFieldName is the name of the field associated with the value at CSVColValue on the current row
               CSVColValue: a value in the CSV's current row+column corresponding to the DBTableFieldName 
        *this assumes that field names are unique across table. if not, then method fails (maybe need to extend method?)
        
e.g.: lambda myRowVal: Base.metadata.tables['people'].c['name'] == CSVRowDict['name']
        using lambda function in query will search for CSVRowDict's value for 'name' in the table people, field name 
if table has no record uniqueness requirement, then enter: TableName:False
'''
unqTests = {
    'facility_chars': lambda CSVRowDict: Base.metadata.tables['facility_chars'].c['Fac_Name'] == CSVRowDict['Fac_Name'],
    'facility_monthly_rain': False, #DB schema does not impose uniqueness on records in this table
    'facility_type_has_nel': False,
    'facility_risks': False,
    'facility_types': lambda CSVRowDict: Base.metadata.tables['facility_types'].c['Fac_Type'] == CSVRowDict['Fac_Type'],
    'wrs_pollutant_risks': False #DB schema does not impose uniqueness on records in this table
}

import SQLA_main as SQLA_main #import main SQLAlchemy functions

# %%
'''
Define other custom modules

'''
import expression as Expr
import importSpecial as importSpecial #special import functions are defined here
import importCSV as importCSV #generic CSV importer ****IMPORTANT NOTE: function assumes csv in the utf-8-sig file format. weird things happen if its not in this format!!!

# %%
#import feasibillity questions, build feasibility expressions
importSpecial.importFeasibilityQuestionsCSV('Input_Files\\feasibility_test_questions.csv') 

#import base bmp information including:
  #1. imports definitions for cip costs, o&m costs, and BMP sizing to the expressions table
  #2. imports pollutant removal rates into pollutant_removal_rates table
  #3. creates a record in the base_bmps table using (1) and (2)
  #4. feasibility tests
importSpecial.importBaseBMPsCSV('Input_Files\\bmp_lego_piece.csv') 

#IMPORT BASIC FACILITY CHARS:
print ('\nImporting facility characteristics:')
importCSV.importCSV('Input_Files\\facility_chars.csv', unqTests)

#IMPORT FACILITY RAINFALL EXTRACTED FROM http://rainfall.geography.hawaii.edu/downloads.html
print ('\nImporting Facility Rainfall Data:')
importCSV.importCSV('Input_Files\\FacilityRainfallData.csv', unqTests)

#IMPORT EFFLUENT LIMITS FOR FACILITY TYPES: (either by Priority Based Plan, Table 3 or as City operational assignment)
print ('\nImporting Facility Type Has Effluent Limits:') #import into wrs_pollutant_risks table
importCSV.importCSV('Input_Files\\nel_exists_facility_types.csv', unqTests)

#IMPORT NEL CLASSIFICATION DATA
print ('\nImporting NEL Classes')


#IMPORT FACILITY RISKS:
print ('\nImporting Facility Risks:')
#for future implementation:
#will insert fac risk and update existing_fac_char_id in Facility_chars table. this process thus creates
#dead records. a more sophisticated approach using sophisticated lambda function in unqTests would fix this
importCSV.importCSV('Input_Files\\facility_risks.csv', unqTests)


session.commit()
# Out:
# Reading csv for import to Feasibility Questions
#
# Reading csv record: Feas-1
# Adding to variable dictionary: OFFSITE_SD_Exist
#
# Reading csv record: Feas-2
# Adding to variable dictionary: GW_Risk
#
# Reading csv record: Feas-3
# Adding to variable dictionary: GW_Risk
#
# Reading csv record: Feas-4
# Adding to variable dictionary: Soil_Type
#
# Reading csv record: Feas-5
# Adding to variable dictionary: Soil_Type
#
# Reading csv record: Feas-6
# Adding to variable dictionary: Soil_Type
#
# Reading csv record: Feas-7
# Adding to variable dictionary: Count_CB
#
# Reading csv record: Feas-8
# Adding to variable dictionary: Runoff_Type
#
# Reading csv record: Feas-9
# Adding to variable dictionary: TFMR_Exist
#
# Reading csv record: Feas-10
# Adding to variable dictionary: DS_SS_Exist
#
# Reading csv record: Feas-11
# Adding to variable dictionary: Fac_Slope
#
# Reading csv record: Feas-12
# Adding to variable dictionary: Can_Add_SD
#
# Reading csv record: Feas-13
# Adding to variable dictionary: Pave_Area
# Adding to variable dictionary: BMP_Size(base_bmps~bmp_size_expression_id~bmp_name)
#
# Reading csv record: Feas-14
# Adding to variable dictionary: Unpave_Area
# Adding to variable dictionary: BMP_Size(base_bmps~bmp_size_expression_id~bmp_name)
#
# Reading csv record: Feas-15
# Adding to variable dictionary: Pave_Area
# Adding to variable dictionary: Det_Size(base_bmps~bmp_size_expression_id~bmp_name)
#
# Reading csv record: Feas-16
# Adding to variable dictionary: EM_Area
#
# Reading csv record: Feas-17
# Adding to variable dictionary: Dmg_Pave
#
# Reading csv record: Feas-18
# Adding to variable dictionary: Fac_Type
#
# Reading csv record: Feas-19
# Adding to variable dictionary: FP_100_Year
#
# Reading csv record: Feas-20
# Adding to variable dictionary: Runoff_Type
#
# Reading csv record: Feas-21
# Adding to variable dictionary: Ex_Struct_BMP
# Reading csv for import to base bmp tables
#
# Reading csv record: Hydrodynamic Separation
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 1
# Removed:  4  old feasibility test defs for the base bmp
# Added feasibility test def as record:  197
# Added feasibility test def as record:  198
# Added feasibility test def as record:  199
# Added feasibility test def as record:  200
#
# Reading csv record: Enhanced Media Filtration (Replaceable Cartridge)
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 2
# Removed:  4  old feasibility test defs for the base bmp
# Added feasibility test def as record:  201
# Added feasibility test def as record:  202
# Added feasibility test def as record:  203
# Added feasibility test def as record:  204
#
# Reading csv record: Biofiltration (Vault)
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 3
# Removed:  4  old feasibility test defs for the base bmp
# Added feasibility test def as record:  205
# Added feasibility test def as record:  206
# Added feasibility test def as record:  207
# Added feasibility test def as record:  208
#
# Reading csv record: Media Filtration (Pressure)
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 4
# Removed:  4  old feasibility test defs for the base bmp
# Added feasibility test def as record:  209
# Added feasibility test def as record:  210
# Added feasibility test def as record:  211
# Added feasibility test def as record:  212
#
# Reading csv record: Bioinfiltration / Bioretention
# Adding to variable dictionary: WQV
# Adding to variable dictionary: BMP_Size(base_bmps~bmp_size_expression_id~bmp_name)
# Adding to variable dictionary: WQV
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 5
# Removed:  8  old feasibility test defs for the base bmp
# Added feasibility test def as record:  213
# Added feasibility test def as record:  214
# Added feasibility test def as record:  215
# Added feasibility test def as record:  216
# Added feasibility test def as record:  217
# Added feasibility test def as record:  218
# Added feasibility test def as record:  219
# Added feasibility test def as record:  220
#
# Reading csv record: Inlet Insert Unit
# Adding to variable dictionary: Count_CB
# Adding to variable dictionary: Count_CB
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 6
# Removed:  1  old feasibility test defs for the base bmp
# Added feasibility test def as record:  221
#
# Reading csv record: Sand Filtration
# Adding to variable dictionary: WQV
# Adding to variable dictionary: WQV
# Adding to variable dictionary: WQV
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 7
# Removed:  4  old feasibility test defs for the base bmp
# Added feasibility test def as record:  222
# Added feasibility test def as record:  223
# Added feasibility test def as record:  224
# Added feasibility test def as record:  225
#
# Reading csv record: Coagulation Enhanced Treatment
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 8
# Removed:  4  old feasibility test defs for the base bmp
# Added feasibility test def as record:  226
# Added feasibility test def as record:  227
# Added feasibility test def as record:  228
# Added feasibility test def as record:  229
#
# Reading csv record: Roofing
# Adding to variable dictionary: BMP_Size(base_bmps~bmp_size_expression_id~bmp_name)
# Adding to variable dictionary: EM_Area
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 9
# Removed:  1  old feasibility test defs for the base bmp
# Added feasibility test def as record:  230
#
# Reading csv record: Paving and Curbing
# Adding to variable dictionary: BMP_Size(base_bmps~bmp_size_expression_id~bmp_name)
# Adding to variable dictionary: Dmg_Pave
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 10
# Removed:  1  old feasibility test defs for the base bmp
# Added feasibility test def as record:  231
#
# Reading csv record: Oil and Water Separators
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Adding to variable dictionary: WQFR
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 11
# Removed:  5  old feasibility test defs for the base bmp
# Added feasibility test def as record:  232
# Added feasibility test def as record:  233
# Added feasibility test def as record:  234
# Added feasibility test def as record:  235
# Added feasibility test def as record:  236
#
# Reading csv record: Vegetative Swales
# Adding to variable dictionary: WQV
# Adding to variable dictionary: BMP_Size(base_bmps~bmp_size_expression_id~bmp_name)
# Adding to variable dictionary: Drainage_Area_Acres
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 12
# Removed:  6  old feasibility test defs for the base bmp
# Added feasibility test def as record:  237
# Added feasibility test def as record:  238
# Added feasibility test def as record:  239
# Added feasibility test def as record:  240
# Added feasibility test def as record:  241
# Added feasibility test def as record:  242
#
# Reading csv record: Detention
# Adding to variable dictionary: WQV
# Adding to variable dictionary: WQV
# Adding to variable dictionary: WQV
# Reading pollutant removal rate info...
# Linking feasibility tests w/ base bmp: 13
# Removed:  3  old feasibility test defs for the base bmp
# Added feasibility test def as record:  243
# Added feasibility test def as record:  244
# Added feasibility test def as record:  245
#
# Importing facility characteristics:
# importing data in CSV rows...
# {'Fac_Name': 'Kalihi-Palama Bus & Paratransit Facility', 'Fac_Add': '611 and 811 Middle Street \nHonolulu, Hawaii 96819', 'Fac_TMK': '(1) 1-2-015:006, (1) 1-2-016-006:007, (1) 1-2-018-003, 009, 011', 'GW_Risk': 'High', 'Fac_Area': '24.6671258', 'Bldg_Area': '206538', 'Pave_Area': '867962', 'Imperv': '1', 'Tm': '2.4', 'Runoff_Coeff': '0.9', 'Length': '403', 'Char_Ground': 'Paved', 'Fac_Slope': '0.014888337', 'TC': '7.5', 'CF': '2.5', 'Q_Peak': '133.2024793', 'WQV': '85064.58333', 'Des_Storm_Depth': '1', 'Runoff_Coeff2': '0.95', 'Imperv2': '1', 'Fac_Area2': '24.6671258', 'WQFR': '13.32024793', 'Runoff_Coeff3': '0.9', 'WQ_Intensity': '0.4', 'Fac_Area3': '24.6671258', 'OP_Shutdown': '0', 'Soil_Type': 'Quarry', 'FP_100_Year': 'Partial', 'Num_Ind_DP': '3', 'Runoff_Type': 'Catch Basin to Piped Outlet', 'Ex_Struct_BMP': 'OWS', 'Count_Pipe': '0', 'Count_Sheet': '0', 'Count_CB': '3', 'Count_Chan': '0', 'Count_DS': '0', 'Count_TD': '0', 'OFFSITE_SD_Exist': 'Yes', 'Dmg_Pave': '0', 'TFMR_Exist': 'Yes', 'DS_SS_Exist': 'Yes', 'Can_Add_SD': 'Yes', 'Unpave_Area': '0', 'EM_Area': '200', 'Drainage_Area_Acres': '96000'}
# {'Fac_Type': 'Bus Maintenance Facility'}
# {'Fac_Name': 'Pearl City Bus Facility', 'Fac_Add': '1200 Waimano Home Road \nPearl City, Hawaii 96782', 'Fac_TMK': '(1) 9-7-024:047', 'GW_Risk': 'High', 'Fac_Area': '24.04299816', 'Bldg_Area': '122654', 'Pave_Area': '854990', 'Imperv': '0.933478339', 'Tm': '2.4', 'Runoff_Coeff': '0.9', 'Length': '687', 'Char_Ground': 'Paved', 'Fac_Slope': '0.02238806', 'TC': '7.5', 'CF': '1.7', 'Q_Peak': '88.28588926', 'WQV': '77687.10417', 'Des_Storm_Depth': '1', 'Runoff_Coeff2': '0.890130505', 'Imperv2': '0.933478339', 'Fac_Area2': '24.04299816', 'WQFR': '12.98321901', 'Runoff_Coeff3': '0.9', 'WQ_Intensity': '0.4', 'Fac_Area3': '24.04299816', 'OP_Shutdown': '0', 'Soil_Type': 'Silty Clay Loam', 'FP_100_Year': 'Undetermined', 'Num_Ind_DP': '2', 'Runoff_Type': 'Catch Basin to Piped Outlet', 'Ex_Struct_BMP': 'OWS', 'Count_Pipe': '0', 'Count_Sheet': '0', 'Count_CB': '2', 'Count_Chan': '0', 'Count_DS': '0', 'Count_TD': '0', 'OFFSITE_SD_Exist': 'No', 'Dmg_Pave': '1', 'TFMR_Exist': 'No', 'DS_SS_Exist': 'No', 'Can_Add_SD': 'No', 'Unpave_Area': '500', 'EM_Area': '1000', 'Drainage_Area_Acres': '22500'}
# {'Fac_Type': 'Bus Maintenance Facility'}
# imported records in  2  rows
# associating records...
#
# Importing Facility Rainfall Data:
# importing data in CSV rows...
# {'Fac_Name': 'Kailua Wastewater Treatment Plant'}
# {'Fac_Name': 'Wahiawa Wastewater Treatment Plant'}
# {'Fac_Name': 'Waianae Wastewater Treatment Plant'}
# {'Fac_Name': 'Honouliuli Wastewater Treatment Plant'}
# {'Fac_Name': 'Sand Island Wastewater Treatment Plant'}
# {'Fac_Name': 'Paalaa Kai Wastewater Treatment Plant'}
# {'Fac_Name': 'Waimanalo Wastewater Treatment Plant'}
# {'Fac_Name': 'Kahuku Wastewater Treatment Plant'}
# {'Fac_Name': 'Kalaheo Closed Sanitary Landfill'}
# {'Fac_Name': 'Waipahu Closed Sanitary Landfill'}
# {'Fac_Name': 'Waianae Closed Sanitary Landfill'}
# {'Fac_Name': 'Kapaa Closed Sanitary Landfill'}
# {'Fac_Name': 'Kawailoa Closed Sanitary Landfill'}
# {'Fac_Name': 'Waikiki Fire Station'}
# {'Fac_Name': 'Pearl City Fire Station'}
# {'Fac_Name': 'Kapolei Police Station'}
# {'Fac_Name': 'Kalihi Police Station'}
# {'Fac_Name': 'Kahuku Police Station'}
# {'Fac_Name': 'Mokulele Fire Station and Training Center'}
# {'Fac_Name': 'Kaneohe Police Station'}
# {'Fac_Name': 'Kaneohe Fire Station'}
# {'Fac_Name': 'Alapai Police Station'}
# {'Fac_Name': 'Kailua Police Station'}
# {'Fac_Name': 'Mililani-Mauka Fire Station'}
# {'Fac_Name': 'Kalihi-Uka Fire Station'}
# {'Fac_Name': 'Nuuanu Fire Station'}
# {'Fac_Name': 'Waiau Fire Station'}
# {'Fac_Name': 'Kapolei Fire Station'}
# {'Fac_Name': 'Pearl City Police Station'}
# {'Fac_Name': 'Central Fire Station'}
# {'Fac_Name': 'Olomana Fire Station'}
# {'Fac_Name': 'Waipahu Vehicle Maintenance Shop'}
# {'Fac_Name': 'Sunset Beach Fire Station'}
# {'Fac_Name': 'Waikele Fire Station'}
# {'Fac_Name': 'Wahiawa Fire Station'}
# {'Fac_Name': 'Manoa Fire Station'}
# {'Fac_Name': 'Wahiawa Police Station'}
# {'Fac_Name': 'Makiki Fire Station'}
# {'Fac_Name': 'Waianae Police Station'}
# {'Fac_Name': 'Waimanalo Fire Station'}
# {'Fac_Name': 'Wailupe Fire Station'}
# {'Fac_Name': 'Waipahu Training Academy'}
# {'Fac_Name': 'Kaimuki Fire Station'}
# {'Fac_Name': 'Kaaawa Fire Station'}
# {'Fac_Name': 'Moanalua Fire Station'}
# {'Fac_Name': 'Kakaako Fire Station and Main Complex'}
# {'Fac_Name': 'McCully (-Moiliili) Fire Station'}
# {'Fac_Name': 'Pawaa Fire Station'}
# {'Fac_Name': 'Waialua Fire Station'}
# {'Fac_Name': 'Kahaluu Fire Station'}
# {'Fac_Name': 'Kuakini Fire Station'}
# {'Fac_Name': 'East Kapolei Fire Station'}
# {'Fac_Name': 'Kahuku Fire Station'}
# {'Fac_Name': 'Palolo Fire Station'}
# {'Fac_Name': 'Makakilo Fire Station'}
# {'Fac_Name': 'Aiea Fire Station'}
# {'Fac_Name': 'Kailua Fire Station'}
# {'Fac_Name': 'Kalihi-Kai Fire Station'}
# {'Fac_Name': 'Waianae Fire Station'}
# {'Fac_Name': 'Waipahu Fire Station'}
# {'Fac_Name': 'Waterfront Fire Station'}
# {'Fac_Name': 'Aircraft One Fire Station'}
# {'Fac_Name': 'Ewa Beach Fire Station'}
# {'Fac_Name': 'Mililani Fire Station'}
# {'Fac_Name': 'Aikahi Fire Station'}
# {'Fac_Name': 'Kalihi Fire Station'}
# {'Fac_Name': 'Nanakuli Fire Station'}
# {'Fac_Name': 'Hauula Fire Station'}
# {'Fac_Name': 'Hawaii-Kai Fire Station'}
# {'Fac_Name': 'Kalihi-Palama Bus & Paratransit Facility'}
# {'Fac_Name': 'Pearl City Bus Facility'}
# {'Fac_Name': 'Halawa (AES) Corporation Yard'}
# {'Fac_Name': 'Halawa (DRM) Corporation Yard'}
# {'Fac_Name': 'Halawa (CSM) Baseyard (Corporation Yard)'}
# {'Fac_Name': 'Manana (PBEM) Corporation Yard'}
# {'Fac_Name': 'Kokea (PBEM) Corporation Yard'}
# {'Fac_Name': 'Kaneohe Corporation Yard'}
# {'Fac_Name': 'Kapaa (AES) Corporation Yard'}
# {'Fac_Name': 'Manana (DPR-MSS) Corporation Yard'}
# {'Fac_Name': 'Manana (DTS) Corporation Yard'}
# {'Fac_Name': 'Waialua Corporation & Refuse Collection Yard'}
# {'Fac_Name': 'Laie Corporation & Refuse Collection Yard'}
# {'Fac_Name': 'Pearl City (AES) Corporation Yard'}
# {'Fac_Name': 'Kailua Corporation Yard'}
# {'Fac_Name': 'Kapolei Corporation Yard'}
# {'Fac_Name': 'Wahiawa Corporation & Refuse Collection Yard'}
# {'Fac_Name': 'Sand Island Dewatering Facility'}
# {'Fac_Name': 'Pearl City (DRM) Corporation Yard'}
# {'Fac_Name': 'Ahuimanu Dewatering Facility'}
# {'Fac_Name': 'Keehi Refuse Transfer Station'}
# {'Fac_Name': 'Wahiawa Refuse Convenience Center'}
# {'Fac_Name': 'Waimanalo Refuse Convenience Center'}
# {'Fac_Name': 'Kapaa Refuse Transfer Station'}
# {'Fac_Name': 'Laie Refuse Convenience Center'}
# {'Fac_Name': 'Pearl City Refuse Collection Yard'}
# {'Fac_Name': 'Kawailoa Refuse Transfer Station'}
# {'Fac_Name': 'Honolulu Refuse Collection Yard'}
# {'Fac_Name': 'Kapaa Refuse Collection Yard'}
# {'Fac_Name': 'Waianae Refuse Collection Yard'}
# {'Fac_Name': 'Ewa Refuse Convenience Center'}
# {'Fac_Name': 'Waipahu Refuse Convenience Center'}
# {'Fac_Name': 'Waianae Refuse Convenience Center'}
# {'Fac_Name': 'Pali Golf Course'}
# {'Fac_Name': 'Ala Wai Golf Course'}
# {'Fac_Name': 'Ewa Villages Golf Course'}
# {'Fac_Name': 'Ted Makalena Golf Course'}
# {'Fac_Name': 'West Loch Golf Course'}
# {'Fac_Name': 'Kahuku Golf Course'}
# {'Fac_Name': 'Kapiolani District (Regional) Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Ala Moana Regional Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Neal S. Blaisdell Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Kualoa Regional Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Central Oahu Regional Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Keehi Lagoon Park Maintenance Baseyard'}
# {'Fac_Name': 'Waikiki Shell'}
# {'Fac_Name': 'Wahiawa Botanical Garden'}
# {'Fac_Name': 'Ala Puumalu Community Park'}
# {'Fac_Name': 'Ala Wai Community Park'}
# {'Fac_Name': 'Kaneohe District Park'}
# {'Fac_Name': 'Manoa Valley District Park'}
# {'Fac_Name': 'Salt Lake District Park'}
# {'Fac_Name': 'Hoomaluhia Botanical Garden'}
# {'Fac_Name': 'Koko Head Regional Park (Uka) (including Maintenance Baseyard)'}
# {'Fac_Name': 'Foster Botanical Garden'}
# {'Fac_Name': 'Halawa District Park'}
# {'Fac_Name': 'Mililani District Park'}
# {'Fac_Name': 'West Loch Shoreline Park'}
# {'Fac_Name': 'Hanauma Bay Nature Preserve'}
# {'Fac_Name': 'Koko Crater Botanical Garden'}
# {'Fac_Name': 'Makiki District Park'}
# {'Fac_Name': 'Palolo District Park'}
# {'Fac_Name': 'Wahiawa District Park'}
# {'Fac_Name': 'Aiea District Park'}
# {'Fac_Name': 'Kailua District Park'}
# {'Fac_Name': 'Kaimuki Community Park'}
# {'Fac_Name': 'Kalakaua District Park'}
# {'Fac_Name': 'Kalihi Valley District Park'}
# {'Fac_Name': 'McCully District Park'}
# {'Fac_Name': 'Moanalua District Park'}
# {'Fac_Name': 'Nanakuli District Park'}
# {'Fac_Name': 'Queen Kapiolani Garden'}
# {'Fac_Name': 'Waimanalo District Park'}
# {'Fac_Name': 'Waipahu District Park'}
# {'Fac_Name': 'Booth District Park'}
# {'Fac_Name': 'Kilauea District Park'}
# {'Fac_Name': 'Lanakila District Park'}
# {'Fac_Name': 'Makakilo Community Park'}
# {'Fac_Name': 'Pearl City District Park'}
# {'Fac_Name': 'Kaiaka Bay Beach Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Petrie Community Park'}
# {'Fac_Name': 'Puunui District Park'}
# {'Fac_Name': 'Waianae District Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Beachwalk Pump Station'}
# {'Fac_Name': 'Maunawili Estates Pump Station'}
# {'Fac_Name': 'Alii Bluffs Pump Station'}
# {'Fac_Name': 'Fort DeRussy Pump Station'}
# {'Fac_Name': 'Hart Street Pump Station'}
# {'Fac_Name': 'Heeia Pump Station'}
# {'Fac_Name': 'Homelani Pump Station'}
# {'Fac_Name': 'Kahaluu Pump Station'}
# {'Fac_Name': 'Kailua Road Pump Station'}
# {'Fac_Name': 'Kukanono Pump Station'}
# {'Fac_Name': 'Laenani Pump Station'}
# {'Fac_Name': 'Maunawili Park Pump Station'}
# {'Fac_Name': 'Mililani Pump Station'}
# {'Fac_Name': 'Miomio Pump Station'}
# {'Fac_Name': 'Pacific Palisades Pump Station'}
# {'Fac_Name': 'Pearl City Pump Station'}
# {'Fac_Name': 'Punawai Pump Station'}
# {'Fac_Name': 'Halawa Pump Station'}
# {'Fac_Name': 'Kailua Heights Pump Station'}
# {'Fac_Name': 'Kamehameha Highway (Keehi Lagoon) Pump Station'}
# {'Fac_Name': 'Kunia Pump Station'}
# {'Fac_Name': 'Waiawa Industrial Park Pump Station'}
# {'Fac_Name': 'Waikapoki Pump Station'}
# {'Fac_Name': 'Waimalu Pump Station'}
# {'Fac_Name': 'Waipahu Wastewater Pump Station'}
# {'Fac_Name': 'West Loch Fairways Pump Station'}
# {'Fac_Name': 'Kahawai Stream Pump Station'}
# {'Fac_Name': 'Aala Pump Station'}
# {'Fac_Name': 'Ala Moana #1 and #2 Pump Station'}
# {'Fac_Name': 'Alala Point Pump Station'}
# {'Fac_Name': 'Coconut Grove Pump Station'}
# {'Fac_Name': 'Grandview Pump Station'}
# {'Fac_Name': 'Halekou Pump Station'}
# {'Fac_Name': 'Lakeview Circle Pump Station'}
# {'Fac_Name': 'Niu Valley Pump Station'}
# {'Fac_Name': 'Ewa Beach Pump Station'}
# {'Fac_Name': 'Kahanahou Pump Station'}
# {'Fac_Name': 'Kaneohe Bay #1 Pump Station'}
# {'Fac_Name': 'Kaneohe Bay #2 Pump Station'}
# {'Fac_Name': 'Kaneohe Bay #4 Pump Station'}
# {'Fac_Name': 'Kaneohe Effluent Pump Station'}
# {'Fac_Name': 'Kemoo Farm Pump Station'}
# {'Fac_Name': 'Laie Wastewater Pump Station'}
# {'Fac_Name': 'Moana Park Pump Station'}
# {'Fac_Name': 'Nakula Pump Station'}
# {'Fac_Name': 'Ohai Place Pump Station'}
# {'Fac_Name': 'Sand Island Industrial Park Pump Station'}
# {'Fac_Name': 'Uwalu Pump Station'}
# {'Fac_Name': 'Waikalua Pump Station'}
# {'Fac_Name': 'Waipio Pump Station'}
# {'Fac_Name': 'Aliamanu #1 Pump Station'}
# {'Fac_Name': 'Aliamanu #2 Pump Station'}
# {'Fac_Name': 'Awa Street Pump Station'}
# {'Fac_Name': 'Enchanted Lake Pump Station'}
# {'Fac_Name': 'Kahala Pump Station'}
# {'Fac_Name': 'Kahaluu Housing Pump Station'}
# {'Fac_Name': 'Kaneohe Bay #3 Pump Station'}
# {'Fac_Name': 'Kaneohe Bay #5 Pump Station'}
# {'Fac_Name': 'Lualualei Pump Station'}
# {'Fac_Name': 'Makakilo Pump Station'}
# {'Fac_Name': 'Nanakuli Pump Station'}
# {'Fac_Name': 'Paiko Drive Pump Station'}
# {'Fac_Name': 'Public Baths Pump Station'}
# {'Fac_Name': 'West Beach #1 Pump Station'}
# {'Fac_Name': 'West Beach #2 Pump Station'}
# {'Fac_Name': 'West Loch Estates Pump Station'}
# {'Fac_Name': 'Kapolei Business Park Wastewater Pump Station'}
# {'Fac_Name': 'Kuliouou Pump Station'}
# {'Fac_Name': 'Waipio Peninsula Soccer Complex (including Maintenance Baseyard)'}
# {'Fac_Name': 'Honolulu Zoo'}
# {'Fac_Name': 'Airport Vehicle Maintenance Yard'}
# {'Fac_Name': 'Kaneohe Wastewater Preliminary Treatment Facility'}
# {'Fac_Name': 'Neal Blaisdell Center'}
# {'Fac_Name': 'Nuuanu Nursery'}
# {'Fac_Name': 'Ahuimanu Pre-Treatment Facility'}
# {'Fac_Name': 'Umi Street (AES) Fueling Facility'}
# {'Fac_Name': 'Waipahu Tree Farm'}
# {'Fac_Name': 'Auahi Coning Yard'}
# {'Fac_Name': 'Kaneohe Community/Senior Center'}
# {'Fac_Name': 'Kaneohe Community/Senior Center'}
# {'Fac_Name': 'Laie Water Reclamation Facility'}
# {'Fac_Name': 'Whitmore Pre-Treatment Facility'}
# {'Fac_Name': 'Chinatown Clean Team'}
# {'Fac_Name': 'Evidence Warehouse'}
# {'Fac_Name': 'Puu Manawahua Radio Site'}
# {'Fac_Name': 'Waimanalo Ridge Radio Site'}
# imported records in  238  rows
# associating records...
#
# Importing Facility Type Has Effluent Limits:
# importing data in CSV rows...
# {'Fac_Type': 'FPS'}
# {'Fac_Type': 'WWTP'}
# {'Fac_Type': 'Bus Maintenance Facility'}
# {'Fac_Type': 'RTS'}
# {'Fac_Type': 'CY'}
# {'Fac_Type': 'OTH'}
# {'Fac_Type': 'CSL'}
# {'Fac_Type': 'GC'}
# imported records in  8  rows
# associating records...
#
# Importing Facility Risks:
# importing data in CSV rows...
# {'Fac_Name': 'Honouliuli Wastewater Treatment Plant'}
# {'Fac_Name': 'Sand Island Wastewater Treatment Plant'}
# {'Fac_Name': 'Kalihi-Palama Bus & Paratransit Facility'}
# {'Fac_Name': 'Keehi Refuse Transfer Station'}
# {'Fac_Name': 'Kailua Wastewater Treatment Plant'}
# {'Fac_Name': 'Waianae Wastewater Treatment Plant'}
# {'Fac_Name': 'Halawa (DRM) Corporation Yard'}
# {'Fac_Name': 'Kapolei Corporation Yard'}
# {'Fac_Name': 'Pearl City Bus Facility'}
# {'Fac_Name': 'Kaneohe Corporation Yard'}
# {'Fac_Name': 'Waipahu Vehicle Maintenance Shop'}
# {'Fac_Name': 'Waipahu Training Academy'}
# {'Fac_Name': 'Waialua Corporation & Refuse Collection Yard'}
# {'Fac_Name': 'Kalaheo Closed Sanitary Landfill'}
# {'Fac_Name': 'Halawa (AES) Corporation Yard'}
# {'Fac_Name': 'Manana (PBEM) Corporation Yard'}
# {'Fac_Name': 'Manana (DPR-MSS) Corporation Yard'}
# {'Fac_Name': 'Pearl City Refuse Collection Yard'}
# {'Fac_Name': 'Laie Refuse Convenience Center'}
# {'Fac_Name': 'Wahiawa Corporation & Refuse Collection Yard'}
# {'Fac_Name': 'Halawa (CSM) Baseyard (Corporation Yard)'}
# {'Fac_Name': 'Kailua Corporation Yard'}
# {'Fac_Name': 'Waianae Closed Sanitary Landfill'}
# {'Fac_Name': 'Kapaa Closed Sanitary Landfill'}
# {'Fac_Name': 'Wahiawa Wastewater Treatment Plant'}
# {'Fac_Name': 'Wahiawa Refuse Convenience Center'}
# {'Fac_Name': 'Laie Corporation & Refuse Collection Yard'}
# {'Fac_Name': 'Honolulu Refuse Collection Yard'}
# {'Fac_Name': 'Waimanalo Refuse Convenience Center'}
# {'Fac_Name': 'Waipahu Closed Sanitary Landfill'}
# {'Fac_Name': 'Kokea (PBEM) Corporation Yard'}
# {'Fac_Name': 'Waipahu Fire Station'}
# {'Fac_Name': 'Mililani-Mauka Fire Station'}
# {'Fac_Name': 'Pali Golf Course'}
# {'Fac_Name': 'Kapaa Refuse Transfer Station'}
# {'Fac_Name': 'Kapaa (AES) Corporation Yard'}
# {'Fac_Name': 'Wahiawa Police Station'}
# {'Fac_Name': 'Pearl City (DRM) Corporation Yard'}
# {'Fac_Name': 'Waipahu Refuse Convenience Center'}
# {'Fac_Name': 'Umi Street (AES) Fueling Facility'}
# {'Fac_Name': 'Kapolei Fire Station'}
# {'Fac_Name': 'Manana (DTS) Corporation Yard'}
# {'Fac_Name': 'Kapaa Refuse Collection Yard'}
# {'Fac_Name': 'Kaneohe Police Station'}
# {'Fac_Name': 'Pearl City (AES) Corporation Yard'}
# {'Fac_Name': 'Kapolei Police Station'}
# {'Fac_Name': 'Ahuimanu Dewatering Facility'}
# {'Fac_Name': 'Sand Island Dewatering Facility'}
# {'Fac_Name': 'Waianae Police Station'}
# {'Fac_Name': 'Kaneohe Fire Station'}
# {'Fac_Name': 'Kawailoa Refuse Transfer Station'}
# {'Fac_Name': 'Kawailoa Closed Sanitary Landfill'}
# {'Fac_Name': 'Manoa Fire Station'}
# {'Fac_Name': 'Palolo Fire Station'}
# {'Fac_Name': 'Olomana Fire Station'}
# {'Fac_Name': 'Wahiawa Fire Station'}
# {'Fac_Name': 'Ala Wai Golf Course'}
# {'Fac_Name': 'Kahuku Police Station'}
# {'Fac_Name': 'Makiki Fire Station'}
# {'Fac_Name': 'Pawaa Fire Station'}
# {'Fac_Name': 'Alapai Police Station'}
# {'Fac_Name': 'McCully (-Moiliili) Fire Station'}
# {'Fac_Name': 'Waianae Refuse Convenience Center'}
# {'Fac_Name': 'Kahaluu Fire Station'}
# {'Fac_Name': 'Waikiki Fire Station'}
# {'Fac_Name': 'Ewa Refuse Convenience Center'}
# {'Fac_Name': 'Waianae Refuse Collection Yard'}
# {'Fac_Name': 'East Kapolei Fire Station'}
# {'Fac_Name': 'Nuuanu Fire Station'}
# {'Fac_Name': 'Kalihi-Uka Fire Station'}
# {'Fac_Name': 'Kaaawa Fire Station'}
# {'Fac_Name': 'Waiau Fire Station'}
# {'Fac_Name': 'Kailua Police Station'}
# {'Fac_Name': 'Pearl City Fire Station'}
# {'Fac_Name': 'Kalihi Fire Station'}
# {'Fac_Name': 'Aiea Fire Station'}
# {'Fac_Name': 'Moanalua Fire Station'}
# {'Fac_Name': 'Ted Makalena Golf Course'}
# {'Fac_Name': 'Kuakini Fire Station'}
# {'Fac_Name': 'Wailupe Fire Station'}
# {'Fac_Name': 'Central Fire Station'}
# {'Fac_Name': 'Aikahi Fire Station'}
# {'Fac_Name': 'Kalihi Police Station'}
# {'Fac_Name': 'Pearl City Police Station'}
# {'Fac_Name': 'Kaimuki Fire Station'}
# {'Fac_Name': 'Sunset Beach Fire Station'}
# {'Fac_Name': 'Waianae Fire Station'}
# {'Fac_Name': 'Kalihi-Kai Fire Station'}
# {'Fac_Name': 'Hauula Fire Station'}
# {'Fac_Name': 'Mokulele Fire Station and Training Center'}
# {'Fac_Name': 'Kahuku Fire Station'}
# {'Fac_Name': 'Waikele Fire Station'}
# {'Fac_Name': 'Waimanalo Fire Station'}
# {'Fac_Name': 'Waialua Fire Station'}
# {'Fac_Name': 'Makakilo Fire Station'}
# {'Fac_Name': 'Kailua Fire Station'}
# {'Fac_Name': 'Mililani Fire Station'}
# {'Fac_Name': 'Hawaii-Kai Fire Station'}
# {'Fac_Name': 'West Loch Golf Course'}
# {'Fac_Name': 'Aircraft One Fire Station'}
# {'Fac_Name': 'Kakaako Fire Station and Main Complex'}
# {'Fac_Name': 'Nanakuli Fire Station'}
# {'Fac_Name': 'Ewa Villages Golf Course'}
# {'Fac_Name': 'Ewa Beach Fire Station'}
# {'Fac_Name': 'Central Oahu Regional Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Puu Manawahua Radio Site'}
# {'Fac_Name': 'Waimanalo Ridge Radio Site'}
# {'Fac_Name': 'Kaneohe Wastewater Preliminary Treatment Facility'}
# {'Fac_Name': 'Waipahu Wastewater Pump Station'}
# {'Fac_Name': 'Laie Water Reclamation Facility'}
# {'Fac_Name': 'Manoa Valley District Park'}
# {'Fac_Name': 'Laie Wastewater Pump Station'}
# {'Fac_Name': 'Grandview Pump Station'}
# {'Fac_Name': 'Waimanalo Wastewater Treatment Plant'}
# {'Fac_Name': 'Kaneohe Community/Senior Center'}
# {'Fac_Name': 'Nakula Pump Station'}
# {'Fac_Name': 'Kaneohe Effluent Pump Station'}
# {'Fac_Name': 'Wahiawa Botanical Garden'}
# {'Fac_Name': 'Whitmore Pre-Treatment Facility'}
# {'Fac_Name': 'Uwalu Pump Station'}
# {'Fac_Name': 'Wahiawa District Park'}
# {'Fac_Name': 'Kaneohe Bay #2 Pump Station'}
# {'Fac_Name': 'Ohai Place Pump Station'}
# {'Fac_Name': 'Coconut Grove Pump Station'}
# {'Fac_Name': 'Lakeview Circle Pump Station'}
# {'Fac_Name': 'Homelani Pump Station'}
# {'Fac_Name': 'Kemoo Farm Pump Station'}
# {'Fac_Name': 'Makiki District Park'}
# {'Fac_Name': 'Kaimuki Community Park'}
# {'Fac_Name': 'Ala Wai Community Park'}
# {'Fac_Name': 'Beachwalk Pump Station'}
# {'Fac_Name': 'Fort DeRussy Pump Station'}
# {'Fac_Name': 'Moana Park Pump Station'}
# {'Fac_Name': 'Auahi Coning Yard'}
# {'Fac_Name': 'Nuuanu Nursery'}
# {'Fac_Name': 'Evidence Warehouse'}
# {'Fac_Name': 'Kaneohe District Park'}
# {'Fac_Name': 'Kahaluu Housing Pump Station'}
# {'Fac_Name': 'Punawai Pump Station'}
# {'Fac_Name': 'Waikapoki Pump Station'}
# {'Fac_Name': 'Booth District Park'}
# {'Fac_Name': 'Kahanahou Pump Station'}
# {'Fac_Name': 'Kalihi Valley District Park'}
# {'Fac_Name': 'Halawa District Park'}
# {'Fac_Name': 'Kaneohe Bay #3 Pump Station'}
# {'Fac_Name': 'Kaneohe Bay #4 Pump Station'}
# {'Fac_Name': 'Kaneohe Bay #5 Pump Station'}
# {'Fac_Name': 'Kahawai Stream Pump Station'}
# {'Fac_Name': 'Ala Puumalu Community Park'}
# {'Fac_Name': 'Lanakila District Park'}
# {'Fac_Name': 'Moanalua District Park'}
# {'Fac_Name': 'Aiea District Park'}
# {'Fac_Name': 'Pacific Palisades Pump Station'}
# {'Fac_Name': 'Kailua Heights Pump Station'}
# {'Fac_Name': 'Waipio Pump Station'}
# {'Fac_Name': 'Mililani District Park'}
# {'Fac_Name': 'Kalakaua District Park'}
# {'Fac_Name': 'Foster Botanical Garden'}
# {'Fac_Name': 'Waimalu Pump Station'}
# {'Fac_Name': 'Chinatown Clean Team'}
# {'Fac_Name': 'Salt Lake District Park'}
# {'Fac_Name': 'Paalaa Kai Wastewater Treatment Plant'}
# {'Fac_Name': 'Halawa Pump Station'}
# {'Fac_Name': 'Mililani Pump Station'}
# {'Fac_Name': 'Waipahu Tree Farm'}
# {'Fac_Name': 'Awa Street Pump Station'}
# {'Fac_Name': 'Kamehameha Highway (Keehi Lagoon) Pump Station'}
# {'Fac_Name': 'Hart Street Pump Station'}
# {'Fac_Name': 'Aliamanu #2 Pump Station'}
# {'Fac_Name': 'Aliamanu #1 Pump Station'}
# {'Fac_Name': 'West Loch Shoreline Park'}
# {'Fac_Name': 'Waiawa Industrial Park Pump Station'}
# {'Fac_Name': 'Hanauma Bay Nature Preserve'}
# {'Fac_Name': 'Pearl City Pump Station'}
# {'Fac_Name': 'Sand Island Industrial Park Pump Station'}
# {'Fac_Name': 'Public Baths Pump Station'}
# {'Fac_Name': 'Kapiolani Nursery'}
# {'Fac_Name': 'Kunia Pump Station'}
# {'Fac_Name': 'West Loch Estates Pump Station'}
# {'Fac_Name': 'West Loch Fairways Pump Station'}
# {'Fac_Name': 'Neal Blaisdell Center'}
# {'Fac_Name': 'Homeland Security Division Storage Facility'}
# {'Fac_Name': 'Puunui District Park'}
# {'Fac_Name': 'Waimanalo District Park'}
# {'Fac_Name': 'Kahuku Wastewater Treatment Plant'}
# {'Fac_Name': 'Kailua District Park'}
# {'Fac_Name': 'Enchanted Lake Pump Station'}
# {'Fac_Name': 'Kuliouou Pump Station'}
# {'Fac_Name': 'Alala Point Pump Station'}
# {'Fac_Name': 'Pearl City District Park'}
# {'Fac_Name': 'Niu Valley Pump Station'}
# {'Fac_Name': 'Aala Pump Station'}
# {'Fac_Name': 'Makakilo Community Park'}
# {'Fac_Name': 'Paiko Drive Pump Station'}
# {'Fac_Name': 'Koko Crater Botanical Garden'}
# {'Fac_Name': 'Petrie Community Park'}
# {'Fac_Name': 'Kilauea District Park'}
# {'Fac_Name': 'Nanakuli District Park'}
# {'Fac_Name': 'Kahala Pump Station'}
# {'Fac_Name': 'Ala Moana #1 and #2 Pump Station'}
# {'Fac_Name': 'Makakilo Pump Station'}
# {'Fac_Name': 'Waipahu District Park'}
# {'Fac_Name': 'Nanakuli Pump Station'}
# {'Fac_Name': 'Lualualei Pump Station'}
# {'Fac_Name': 'West Beach #1 Pump Station'}
# {'Fac_Name': 'West Beach #2 Pump Station'}
# {'Fac_Name': 'Kapolei Business Park Wastewater Pump Station'}
# {'Fac_Name': 'Ewa Beach Pump Station'}
# {'Fac_Name': 'Halekou Pump Station'}
# {'Fac_Name': 'Waikalua Pump Station'}
# {'Fac_Name': 'Maunawili Estates Pump Station'}
# {'Fac_Name': 'Palolo District Park'}
# {'Fac_Name': 'Kaneohe Bay #1 Pump Station'}
# {'Fac_Name': 'Maunawili Park Pump Station'}
# {'Fac_Name': 'Kukanono Pump Station'}
# {'Fac_Name': 'Hoomaluhia Botanical Garden'}
# {'Fac_Name': 'Kahaluu Pump Station'}
# {'Fac_Name': 'Queen Kapiolani Garden'}
# {'Fac_Name': 'Airport Vehicle Maintenance Yard'}
# {'Fac_Name': 'Ala Moana Regional Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'McCully District Park'}
# {'Fac_Name': 'Ahuimanu Pre-Treatment Facility'}
# {'Fac_Name': 'Laenani Pump Station'}
# {'Fac_Name': 'Alii Bluffs Pump Station'}
# {'Fac_Name': 'Heeia Pump Station'}
# {'Fac_Name': 'Miomio Pump Station'}
# {'Fac_Name': 'Kailua Road Pump Station'}
# {'Fac_Name': 'Kualoa Regional Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Waipio Peninsula Soccer Complex (including Maintenance Baseyard)'}
# {'Fac_Name': 'Kapiolani District (Regional) Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Neal S. Blaisdell Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Keehi Lagoon Park Maintenance Baseyard'}
# {'Fac_Name': 'Honolulu Zoo'}
# {'Fac_Name': 'Waikiki Shell'}
# {'Fac_Name': 'Kahuku Golf Course'}
# {'Fac_Name': 'Waianae District Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Kaiaka Bay Beach Park (including Maintenance Baseyard)'}
# {'Fac_Name': 'Koko Head Regional Park (Uka) (including Maintenance Baseyard)'}
# imported records in  238  rows
# associating records...

# %%
session.close()
engine.dispose()
