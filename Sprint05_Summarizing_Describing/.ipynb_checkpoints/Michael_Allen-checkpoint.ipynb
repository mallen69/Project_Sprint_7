# %% [markdown]
# # US Contagious Diseases Sprint #5 Michael Allen

# %% [markdown]
# ---
# ## DAY 1: Tuesday (Week 1)
# ### What I Expect to Learn
# * I expect to be able to learn new R commands and open my mind to other ways of analyzing a dataset as I will be using a different dataset this Sprint from any of the other Sprints.*
#
# ### Project References
# - *https://stackoverflow.com/questions/4215154/count-unique-values*
# - *https://stackoverflow.com/questions/13013231/how-can-i-divide-one-column-of-a-data-frame-through-another*
# - *https://www.computerworld.com/article/2486425/business-intelligence/business-intelligence-4-data-wrangling-tasks-in-r-for-advanced-beginners.html*
# - *https://stackoverflow.com/questions/3445590/how-to-extract-a-subset-of-a-data-frame-based-on-a-condition-involving-a-field*
# - *https://www.sheffield.ac.uk/polopoly_fs/1.536444!/file/MASH_2way_ANOVA_in_R.pdf*
# - *http://www.sthda.com/english/wiki/one-way-anova-test-in-r
#
#
# ### No Project Pitched on Tuesday

# %% [markdown]
# ---
# ## DAY 2: Wednesday (Week 1)
# ### Pitch Feedback
# *Ben stated that he thought it best that I work with a new dataset for this Sprint - then the tools and such that I learn by looking at a new dataset will most likely help me more with my End of Course Survey Data Set for which I have been focused *
#
# ### Prototype Notes: Items that I want to learn this Sprint:
# * In R, how to:
# * Determine how many different diseases there are without scrowling through thousands of lines of code:
# * Write a Script to Calculate the Disease per State by the Highest Percentage Sick*
# * Calculate the Specific disease per State by the Highest Percentage Sick*
# * Calculate the mean for each disease by the Highest per state.*
# * Using the entire dataset, first create a boxplot to determine the spread of the data*
# * Determine how to do statistical significance across the entire dataset with ANOVA Calculations*
#
# ### Unexpected things that I learned
# * An unexpected thing that I learned already working with a new data set is the filter command in R Studio which is very useful for getting a quick feel of the data by narrowing down the dataset a bit during the exploratory phase*
#
# * Can quickly find the highest sick percentage after calculating the actual percentage
# * After quite a bit of iterations Ben helped me figure out the final bit of code so that I could calculate the top disease per State (by the highest percentage_sick)*
#
#
# ### Results from prototype experiments, snippets of code, things I tried throughout the first week*
# *The code below gives me my answers my first question*
# *unique(sick$disease)*
# *Hepatitis A  Measles Mumps  Pertussis  Polio  Rubella  Smallpox*
#
# *Here is a start of the code to get the percentage of the population that had a particular disease.  It added a new column called percentage_sick*
# *sick <- transform(sick, percentage_sick = count / population)*
#
# *And some various other fun facts:*
#
# *#If I wanted to know the highest year in the dataset
# *highest_year <- max(sick$year)
#
# *#If I wanted to know the highest counts of diseases in the dataset
# *highest_count <- max(sick$count)
#
# *#If I wanted to know the highest percentage_sick that is found in the data set.
# *#Also needed to do the na.rm=True in order for it to work
#
# *highest_percentage_sick <- max(sick$percentage_sick, na.rm = TRUE)
#
#
# ### Pair Show & Tell Comments
# *Comments from prototype discussion*
#
# *These comments lead into plan development. Key considerations for me and my partner:  Do I have a plan? Is my plan feasible?*
#
# ### Proposed Plan: Key Milestones by Day
#
# ##### Day 2 (Wed Week 1):
# - Develop Project Proposal which is above.
# -
#
# ##### Day 3 (Thu Week 1): The Actual code of my Script so far.
# #The start of working with the US Contagious Diseases
#
# #Setting my working Directory in order to be in the folder where the US_Contagious_Diseases is.
# setwd("C:/Users/micha/Desktop/DevLeague Begins Nov 7 2017/Project_Sprint_5/")
#
# #Loading libraries and reading the CSV file "us_contagious_diseases into R.
#
# #Loading the library dplyr in order for the
# library(dplyr)
#
# #Loading the library ggplot2
# library(ggplot2)
#
# #Loading the library plyr in order to use the ddply() function
# library("plyr")
#
#
# #Creating the variable "sick" to represent the ""us_contagious_diseases.csv""
# #which was pulled from the Internet
# sick <- read.csv("us_contagious_diseases.csv")
#
# #calculating the percentage of people that are sick for that particular disease per the population
# sick <- transform(sick, percentage_sick = count / population)
#
# #turning the year column of integers into a column that contains R categories (called factors)
# #Don't know for sure if I need to do this or not yet...
# #sick$year <- integer(sick$year, ordered = TRUE)
#
# #If I wanted to know the highest year in the dataset
# highest_year <- max(sick$year)
#
# #If I wanted to know the highest counts of diseases in the dataset
# highest_count <- max(sick$count)
#
# #If I wanted to know the highest percentage_sick that is found in the data set.
# #Also needed to do the na.rm=True in order for it to work
#
# highest_percentage_sick <- max(sick$percentage_sick, na.rm = TRUE)
#
# #Filter out all of the NA's for the percentage_sick
# filter(sick, !is.na(percentage_sick))
#
# #Create a new variable called "Sicker" that only has the percentage_sick values without any NA's
# Sicker <- filter(sick, !is.na(percentage_sick))
#
#
# #Calculate the top disease per State (by the highest percentage_sick)
# States_highest_sick <- ddply(Sicker, 'state', function(x) x[x$percentage_sick==max(x$percentage_sick),])
#
# #View the top disease per State and show the percentage_sick
# View(States_highest_sick)
#
#
#
#
# - Pushed docs to repo
#
# ##### Day 4 (Tue Week 2):
# - *Trying to clean up my data from what I worked on over the weekend*
# - *Trying to get Anova to Work*
#
#
# - Push docs / repo
#
# ##### Day 5 (Wed Week 2):
# - Project highlights
# - Identify question or cohort knowledge gap for sprint review
# - Develop Topic Project + Presentation
# - Push Repo / docs / Presentation
#
# ### Project Definition and README.MD Discussion
# *This is a discussion of how this project will fit into my overall roadmap. I will update my roadmap with the following project definition*
#
# *I will focus my project Repo's README.MD on the same topic, but with this additional detail.*

# %% [markdown]
# ---
# ## DAY 3: Thursday (Week 1)
#
# #### Setup for Repo and Documentation Push
# *Worked with Ben to get my exploratory data to display the way I wanted*
#
# #### Repo File Strategy Discussion
# *How I will present my repo files for clarity and demonstration*
#
# #### Work towards milestones
# *Good progress so far this week.  I will update this repo slightly more over the weekend but doing a quick push for our agreed upon Thursday night deadline *

# %% [markdown]
# ---
# ## DAY 4: Tuesday (Week 2) - Added Milestones...
#
#
# #### Work towards milestone 1
# *Over the weekend I added code to my R program to do the following:*
# #Create varible names for each of the seven diseases so that I can calculate per disease / per State the highest percentage sick*
#
#
#
# #### Work towards milestone 2
# *Then to calculate the mean for all the states for that particular Disease *
#
# #### Work towards milestone 3
# *Calculate the Statisical Signficance (ANOVA) for the Means between each Disease*

# %% [markdown]
# ---
#
# ## DAY 5: Wednesday (Week 2)
#
# ### Project Highlights: The things I am most excited about in my project
# Me
# - *That I learned my way around R Studio this week more so than the previous eight weeks*
#
# - *That I was able to take a dataset that I knew nothing about and be able to do exploratory*
# *analysis, figure out the means of the highest percentage sick from each state, per disease,*
# *And to finally get a start on Statistical Significance with using the suggestions and help from Ben on first doing a boxplot on all the data and then moving into ANOVA where I have been wanting to learn for a while*
#
# *The ANOVA data is being displayed with the following three lines of code:
# *res.aov <- aov(percentage_sick ~ disease, data = Sicker)
#
# *summary(res.aov)
#
# *res.aov <- aov(percentage_sick ~ disease, data = Sicker)
#
# *summary(res.aov)
# Df  Sum Sq   Mean Sq F value Pr(>F)
# disease         6 0.00695 0.0011580   655.9 <2e-16 ***
# Residuals   18659 0.03294 0.0000018
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# *TukeyHSD(res.aov)
#
#
# Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = percentage_sick ~ disease, data = Sicker)
#
# $disease
#                                diff           lwr           upr     p adj
# Measles-Hepatitis A    1.570313e-03  1.467500e-03  1.673126e-03 0.0000000
# Mumps-Hepatitis A      3.678351e-05 -8.530065e-05  1.588677e-04 0.9743939
# Pertussis-Hepatitis A  1.267136e-04  2.347115e-05  2.299560e-04 0.0055021
# Polio-Hepatitis A      1.267136e-04  2.347115e-05  2.299560e-04 0.0055021
# Rubella-Hepatitis A   -3.537908e-05 -1.556475e-04  8.488931e-05 0.9773157
# Smallpox-Hepatitis A   3.541386e-06 -1.328143e-04  1.398971e-04 1.0000000
# Mumps-Measles         -1.533529e-03 -1.644831e-03 -1.422228e-03 0.0000000
# Pertussis-Measles     -1.443599e-03 -1.533835e-03 -1.353363e-03 0.0000000
# Polio-Measles         -1.443599e-03 -1.533835e-03 -1.353363e-03 0.0000000
# Rubella-Measles       -1.605692e-03 -1.714999e-03 -1.496385e-03 0.0000000
# Smallpox-Measles      -1.566772e-03 -1.693564e-03 -1.439979e-03 0.0000000
# Pertussis-Mumps        8.993004e-05 -2.176876e-05  2.016288e-04 0.2096542
# Polio-Mumps            8.993004e-05 -2.176876e-05  2.016288e-04 0.2096542
# Rubella-Mumps         -7.216259e-05 -1.997640e-04  5.543879e-05 0.6378770
# Smallpox-Mumps        -3.324213e-05 -1.761074e-04  1.096232e-04 0.9933906
# Polio-Pertussis        1.013729e-17 -9.072526e-05  9.072526e-05 1.0000000
# Rubella-Pertussis     -1.620926e-04 -2.718039e-04 -5.238135e-05 0.0002677
# Smallpox-Pertussis    -1.231722e-04 -2.503136e-04  3.969289e-06 0.0648123
# Rubella-Polio         -1.620926e-04 -2.718039e-04 -5.238135e-05 0.0002677
# Smallpox-Polio        -1.231722e-04 -2.503136e-04  3.969289e-06 0.0648123
# Smallpox-Rubella       3.892046e-05 -1.023963e-04  1.802373e-04 0.9838277
#
#
#
# ### Peer Repo Feedback
#
# *Updated with a more different colors in my barplot per Runjini*

# %% [markdown]
# ## Day 6: Thursday (Week 2)
# ---
#
# #### Things I didn't get to
# *Was able to basically accomplish what I set out to do but did tweak a few things along the way.
# *Though I do not understand at this point what the ANOVA test is giving me for answers/data.  I need to read up on this.  But the important thing is R is giving me something concerning the ANOVA data..!*
#
# *Found this reference here for future projects, having nothing to do with this one:*
#
# *https://www.computerworld.com/article/2486425/business-intelligence/business-intelligence-4-data-wrangling-tasks-in-r-for-advanced-beginners.html*
#
# *companiesData$margin <- round(companiesData$margin, 1)*
#
# *That may help me rounded my Survey data to two digits since it did not quite do it right*
