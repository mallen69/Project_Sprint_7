# %% [markdown]
# # Sprint 5: Exploratory Data Analysis: Sprint Journal for Runjini Murthy

# %% [markdown]
# ---
# ## DAY 1: Tuesday (Week 1)
# ### What I Expect to Learn
# * I expect to have a better understanding of the initial step of the data analysis proces, i.e. EDA or exploratory data analysis.  This entails asking preliminary questions, trial and error queries with the data, and hopefully gaining a direction for where to take the analysis.
#
# ### Project References
# - Analyzing gym usage data in ten minute increments, with weather and school date data, to determine when is the best time to go to the gym (i.e. fewer attendees): https://www.kaggle.com/nsrose7224/crowdedness-at-the-campus-gym
# - Analysis of salary, region, and college data to determine how much of an impact your school and major have on your income: https://www.kaggle.com/cbhyphen/post-college-salaries-exploration-in-r/
# - *replace with Link to project and description of why it's of interest to you*
#
# ### Project Pitch
# - Comparison project using a Kaggle data set on Lego and comparing insights against what they found.  This relates to the process of exploring data set.
#
# ### Useful Links
# - Overview of basic calculations and summary stats: http://rcompanion.org/handbook/C_02.html
# - R data wrangling cheat sheet: https://github.com/devleague/BigDataAnalyst_ProjectDocumentation/blob/master/Sprint00_Meta_Content/03_Useful_Snippets/r-data-wrangling-cheatsheet.pdf
# - Learned how to rename a column name in R: https://stackoverflow.com/questions/7531868/how-to-rename-a-single-column-in-a-data-frame
# ```colnames(df)[colnames(df) == 'oldName'] <- 'newName'```
# - Got code for bar plots on this page: http://www.datacarpentry.org/dc_zurich/R-ecology/05-visualisation-ggplot2.html
# ```ggplot(yearly_sum, aes(x=year, y=count, color=theme_id)) +
# +     geom_bar(stat = "identity")```
#
# ### Discussion/Methodology for Contagious Disease Exercise
# - Histograms
# - Bar graphs/ggplot
# - Unique values
# - Frequency/total sum of diseases
# - Looking at sum of diseases over time; within HI
# - Mean/STD
# - Groupings by state, disease
#
# ### What is preventing you from being the ultimate exploratory data analyst?
# - How to construct a narrative
# - How to account for biases
# - How do you account for variables/data outside your data set
# - What are the functions to perform analysis?
# - Finding cool data sets
# - How important is domain knowledge in data analysis (ex. finance, medicine)
# - Easier to do in Excel than in R/Python -- lose train of thought
#
# ### Project Ideas/Points
# - Outline questions to ask
# - Steps to repurpose
# - Comment based on industry-specific knowledge
# - Developing inventory of tools/packages for data analysis (dyplr, tidyverse)
# - Put in biases into script to help frame -- process-driven EDA
# - Write down story and ask what would make you stop believing it?  What would it take to disprove the story?

# %%
# Install dslabs to access several data sets within R.
install.packages("dslabs")
library(dslabs)
data(package="dslabs")
list.files(system.file("script", package = "dslabs"))
unique(us_contagious_diseases$disease)
# Out:
# The downloaded binary packages are in
# 	/var/folders/sh/n4brlkdx3sb7ydnprmfnfwxn62mjg2/T//RtmpobFhbd/downloaded_packages
#  [1] "make-admissions.R"
#  [2] "make-divorce_margarine.R"
#  [3] "make-gapminder-rdas.R"
#  [4] "make-murders-rda.R"
#  [5] "make-na_example-rda.R"
#  [6] "make-outlier_example.R"
#  [7] "make-polls_us_election_2016.R"
#  [8] "make-reported_heights-rda.R"
#  [9] "make-research_funding_rates.R"
# [10] "make-weekly_us_contagious_diseases.R"
# [11] "save-gapminder-example-csv.R"
# [1] Hepatitis A Measles     Mumps       Pertussis   Polio       Rubella
# [7] Smallpox
# Levels: Hepatitis A Measles Mumps Pertussis Polio Rubella Smallpox

# %%
install.packages("ggplot2")
library(ggplot2)
ggplot(us_contagious_diseases) + geom_bar(aes(x=year,y=count),stat="summary", fun.y = "sum",fill=I("grey50"))
# Out:
# The downloaded binary packages are in
# 	/var/folders/sh/n4brlkdx3sb7ydnprmfnfwxn62mjg2/T//RtmpobFhbd/downloaded_packages
# plot without title

# %%
ggplot(us_contagious_diseases) 
+ geom_bar(aes(x=stateHIdisease <- subset(us_contagious_diseases, state == "Hawaii"),y=count),stat="summary", fun.y = "sum", fill=I("grey50"))
# Out:
# Error in +geom_bar(aes(x = stateHIdisease <- subset(us_contagious_diseases, : invalid argument to unary operator
# Traceback:
# plot without title

# %%
HIdisease <- subset(us_contagious_diseases, state == "Hawaii")
ggplot(HIdisease) + geom_bar(aes(x=year,y=count),stat="summary", fun.y = "sum",fill=I("grey50"))
# Out:
# plot without title

# %%
ggplot(HIdisease) + geom_bar(aes(x=disease,y=count),stat="summary", fun.y = "sum",fill=I("grey50"))
# Out:
# plot without title

# %%
 ggplot(us_contagious_diseases) + geom_bar(aes(x=disease,y=count),stat="summary", fun.y = "sum",fill=I("grey50"))
# Out:
# plot without title

# %% [markdown]
# ---
# ## DAY 2: Wednesday (Week 1)
# ### Pitch Feedback
# N/A
#
# ### Prototype Notes
# Kind of a mess today: Tried installing PostgreSQL, performing SQL functions in R Studio, plotting poorly in R Studio, and then landing in SQL Studio.  For project, describe some of this trial and error, and then recommend how to streamline the spiraling process to focus efforts for future.
#
# ### Pair Show & Tell Comments
# N/A
#
# ### Proposed Plan: Key Milestones by Day
#
# ##### Day 2 (Wed Week 1):
# - Develop Project Proposal -- Still TBD, but basically coming up with process and questions to ask of a Lego data set, focusing on a more simple join and the different options/questions to query there.
# - Push Docs / Repo / Roadmap Update
#
# ##### Day 3 (Thu Week 1):
# - Write out step by step process.
# - Save code snippets.
# - Save images.
# - Push docs / repo
#
# Helpful links:
# - Tutorial on R scatterplot: https://www.tutorialspoint.com/r/r_scatterplots.htm
# - Plyr package to count and get frequency of occurrences: https://www.miskatonic.org/2012/09/24/counting-and-aggregating-r/
# - Refresher on subset: https://www.statmethods.net/management/subset.html
# - How to format plots: https://www.statmethods.net/advgraphs/axes.html
# - Colors for plots: https://www.statmethods.net/advgraphs/parameters.html
# - Wikipedia page for EDA: https://en.wikipedia.org/wiki/Exploratory_data_analysis
# - Refresher on discrete vs. continuous variables: http://www.statisticshowto.com/discrete-vs-continuous-variables/
#
# Process notes:
# 1. Ensure you understand schema and how tables relate to each other.  Diagram if you don't have.
# ![downloads_schema.png](attachment:downloads_schema.png)
# 2. Change column headers as needed (ex. of "id" showing up multiple times across the Lego sets; had to determine if it was color_id and change it on the given data frame to perform joins.).
# 3. Scale down -- choose two sets to look at as a starting point for a simple join.
# 4. Attempt a plot of some kind.
# - Trial one: Bar graph -- Attempted to demonstrate the number of parts in different sets, but the output did not look meaningful/accurate.
# - Trial two: Scatter plot -- make sure you have numerical values to plot against.  First attempt at colors and part names... yields nothing.
# 5. Consider how colors/formatting of the plot may make patterns easier to review visually.
#
# ##### Day 4 (Tue Week 2):
# - *milestone X+1*
# - *milestone X+2*
# - *milestone X+3*
# - Push docs / repo
#
# ##### Day 5 (Wed Week 2):
# - Project highlights
# - Identify question or cohort knowledge gap for sprint review
# - Develop Topic Project + Presentation
# - Push Repo / docs / Presentation
#
# ### Project Definition and README.MD Discussion
# *This is a discussion of how this project will fit into my overall roadmap. I will update my roadmap with the following project definition*
#
# *I will focus my project Repo's README.MD on the same topic, but with this additional detail.*

# %% [markdown]
# ---
# ## DAY 3: Thursday (Week 1)
#
# #### Setup for Repo and Documentation Push
# *Setup and testing I did to make sure my repo and documentation were ready to push at the end of the day*
#
# #### Repo File Strategy Discussion
# *How I will present my repo files for clarity and demonstration*
#
# #### Work towards milestone 1
# Process steps started.
#
# #### Work towards milestone 2
# Code snippets for today's work shown in trial in error; need full list.
#
# #### Work towards milestone 3
# Screengrabs below.
#
# ### Trial and Error, a series of screenshots.
#
# First attempt at a scatter plot.  Learned I was plotting non-numerical values against each other, instead of the counts of them, which I thought I was doing.  Even still, I think this whole approach was wrong.
#
# ![scatter-plot-fail.jpeg](attachment:scatter-plot-fail.jpeg)
#
# Next up was going back to the somewhat tried and true ggplot.  To me, this yielded too many results to be valuable to visualize, and the color bands didn't really make sense.  I did decide to use year because that made logical sense as an X-axis value. ```ggplot(sets, aes(fill=theme_id, y=num_parts, x=year)) + geom_bar(position="dodge", stat="identity")```
#
# ![Ggplot-of-uncertainty.jpeg](attachment:Ggplot-of-uncertainty.jpeg)
#
# To help hone in on what was happening, I created a subset based off of year; I wanted data from 2000 on only.  Then I did the same ggplot.  ```ggplot(sets_2000, aes(fill=theme_id, y=num_parts, x=year)) + geom_bar(position="dodge", stat="identity")```  Apparently, this is equivalent to this call: ```plot(sets_join4$year, sets_join4$num_parts)```
#
# ![Subsetted-ggplot-of-uncertainty.jpeg](attachment:Subsetted-ggplot-of-uncertainty.jpeg)
#
# At some point, I did a regular ole plot and got the below. ```plot(sets_join4$year, sets_join4$num_parts)```
#
# ![Plain-old-plot.jpeg](attachment:Plain-old-plot.jpeg)
#
# As an example of what Michael did earlier, I did a histogram off of the subset (```hist(sets_2000$year)```) that returned the following.  I think I'm trying to get a bar plot, and keep searching through examples that are getting me nowhere.
#
# ![Histogram-test-unsure-what-freq-is.jpeg](attachment:Histogram-test-unsure-what-freq-is.jpeg)

# %% [markdown]
# ---
# ## DAY 4: Tuesday (Week 2)
#
# #### Work in Progress Feedback
# No real feedback from today.  Will share some helpful links:
# - To determine max in R: http://www.datasciencemadesimple.com/min-and-max-function-in-r/]
# - For counts and aggregating/subtotals, use plyr package: https://www.miskatonic.org/2012/09/24/counting-and-aggregating-r/
# - Book on R; this has been shared already but should really review: http://r4ds.had.co.nz/introduction.html
# - Tidyverse cheat sheet: http://datacamp-community.s3.amazonaws.com/e63a8f6b-2aa3-4006-89e0-badc294b179c
# - ggplot cheat sheet: file:///Users/runjini.murthy/Downloads/data-visualization-2.1.pdf
#
# #### Work towards milestone 1: Re-do script
# R script file is now compiled and much neater than before.
#
# #### Work towards milestone 2: Identify some questions to ask
# New questions:
# - How can I plot parent ID and theme ID?
# - Which parent ID has the most number of parts?
# - We have plotted the total number of parts over time; what is the mean of parts over time?
#
#
# #### Work towards milestone 3: Determine useful tips for cheat sheet task
# *Work I did towards Milestone *

# %%
# Import all files in Lego data set
library(readr)
colors <- read_csv("Desktop/GitHub/Runjini_Sprint_5/colors.csv")
inventories <- read_csv("Desktop/GitHub/Runjini_Sprint_5/inventories.csv")
inventory_parts <- read_csv("Desktop/GitHub/Runjini_Sprint_5/inventory_parts.csv")
inventory_sets <- read_csv("Desktop/GitHub/Runjini_Sprint_5/inventory_sets.csv")
part_categories <- read_csv("Desktop/GitHub/Runjini_Sprint_5/part_categories.csv")
parts <- read_csv("Desktop/GitHub/Runjini_Sprint_5/parts.csv")
sets <- read_csv("Desktop/GitHub/Runjini_Sprint_5/sets.csv")
themes <- read_csv("Desktop/GitHub/Runjini_Sprint_5/themes.csv")

# Install tidyverse package
install.packages("tidyverse")
library(tidyverse)

# Call ggplot library
library(ggplot2)

# Plot the number of parts by year, colored by theme.  Colors not showing...
ggplot(sets, aes(year, num_parts, colors = theme_id)) 
  +     geom_point()
# Out:
# Error: 'Desktop/GitHub/Runjini_Sprint_5/colors.csv' does not exist in current working directory ('/Users/runjini.murthy/Desktop/GitHub/BigDataAnalyst_ProjectDocumentation/Sprint05_Summarizing_Describing').
# Traceback:
#
# 1. read_csv("Desktop/GitHub/Runjini_Sprint_5/colors.csv")
# 2. read_delimited(file, tokenizer, col_names = col_names, col_types = col_types,
#  .     locale = locale, skip = skip, comment = comment, n_max = n_max,
#  .     guess_max = guess_max, progress = progress)
# 3. standardise_path(file)
# 4. check_path(path)
# 5. stop("'", path, "' does not exist", if (!is_absolute_path(path)) paste0(" in current working directory ('",
#  .     getwd(), "')"), ".", call. = FALSE)

# %% [markdown]
# ---
#
# ## DAY 5: Wednesday (Week 2)
#
# ### Project Highlights: The things I am most excited about in my project
# Me
# - Was able to pull together a script file.
# - Answered a handful of basic questions that came up.
# - That was about as good as it got this time.
#
# Peer Identified
#
# -
# -
# -
#
# ### Peer Repo Feedback
#
# *Here are the changes I am making to my repo structure for additional clarity*
# -
# -
# -

# %% [markdown]
# ## Day 6: Thursday (Week 2)
# ---
#
# #### Things I didn't get to
# - Loops/functions: Did many repetitive functions, so I really need to learn how to do this.
# - Not entirely sure I got far enough in the EDA process.  I need to get better at formulating questions.
