# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
df=pd.read_csv('us_contagious_diseases.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'disease', 'state', 'year', 'weeks_reporting', 'count',
#        'population'],
#       dtype='object')

# %%
df.plot

# %%
# %matplotlib inline

# %%
df.plot ('population')

# %%
df.plot ('count')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18870, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'disease', 'state', 'year', 'weeks_reporting', 'count',
#        'population'],
#       dtype='object')

# %%
import magrittr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-4bb8c3168536> in <module>()
# ----> 1 import magrittr
#
# ModuleNotFoundError: No module named 'magrittr'

# %%
df.columns
# Out:
# Index(['population'], dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-a189317bd463> in <module>()
# ----> 1 pd.columns
#
# AttributeError: module 'pandas' has no attribute 'columns'
