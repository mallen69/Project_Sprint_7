# %% [markdown]
# # Preliminary Findings & Hypothesis:  Sprint 6 Journal for S. Molla

# %% [markdown]
# ---
# ## DAY 1: Tuesday (Week 1)
# ### What I Expect to Learn
# * Load a dataset into Python and Perform Basic EDA
#
# ### Project References
# - *https://www.kaggle.com/ksuchris2000/oklahoma-earthquakes-and-saltwater-injection-wells
#
#
# ### Project Pitch
# - Develop documented EDA process, run through it.

# %% [markdown]
# ## Part 1 (Week 1): Pair EDA and Concept Demonstration
#
#
# ##### Day 2 (Wed Week 1):
# - Develop Project Proposal
# - Start EDA process
#
# ##### Day 3 (Thu Week 1):
# - Deliverable: Reproducable EDA process that can be reproduced by others
#
# ## Part 2 (Week 2): EDA of your Dataset
# Walk through a polished Exploratory Data Analysis exercise in your personal repo. This can include the steps that you laid out originally, any new steps and new ideas you have, or any new techniques you developed from the concepts in (5.) above.
#
# Your final deliverable repo should include a
# - 1.) readme and a script file OR
# - 2.) a notebook
#
# that illustrates your analysis and leads to preliminary findings and hypotheses about the dataset for future investigation or more thorough analysis.

# %% [markdown]
# ---
# ## DAY 3: Thursday (Week 1)
#
# #### Setup for Repo and Documentation Push
# Markdown Jupyter Notebook to make EDA process neat and reproducible
#
# #### Repo File Strategy Discussion
# I will present my repo files for clarity and demonstration by using a marked up notebook explaining each step as I code.
#
# #### Work towards EDA milestone
# Completed a marked down EDA process and pushed it to my repo.

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS PROCEDURE

# %% [markdown]
# #### Data Wrangling and Dependencies (Import these)

# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt

# %%
#### Import data sets (2)
(1) Earthquakes--pd.read_csv('C:/Users/SheuliMolla/Desktop/DEV LEAGUE/S5_Exploratory_Data_Analysis/okquakes.csv')
(2)Monitoring Wells-- pd.read_csv('C:/Users/SheuliMolla/Desktop/DEV LEAGUE/S5_Exploratory_Data_Analysis/InjectionWells.csv')

# %%
pd.read_csv('C:/Users/SheuliMolla/Desktop/DEV LEAGUE/S5_Exploratory_Data_Analysis/okquakes.csv')
pd.read_csv('C:/Users/SheuliMolla/Desktop/DEV LEAGUE/S5_Exploratory_Data_Analysis/InjectionWells.csv')
# Out:
#                API#                                Operator  Operator ID  \
# 0      3.500300e+09                   PHOENIX PETROCORP INC      19499.0
# 1      3.500300e+09                CHAMPLIN EXPLORATION INC       4030.0
# 2      3.500321e+09                      LINN OPERATING INC      22182.0
# 3      3.500321e+09  SANDRIDGE EXPLORATION & PRODUCTION LLC      22281.0
# 4      3.500321e+09                CHAMPLIN EXPLORATION INC       4030.0
# 5      3.500321e+09          PARADIGM PETROLEUM CORPORATION      22867.0
# 6      3.500321e+09                    PRIDE ENERGY COMPANY      19430.0
# 7      3.500321e+09           ZEIDERS BROS OIL & GAS CO LLC      22680.0
# 8      3.500321e+09       MARJO OPERATING MID-CONTINENT LLC      23610.0
# 9      3.500321e+09          PARADIGM PETROLEUM CORPORATION      22867.0
# 10     3.500321e+09               KIESTER OPERATING COMPANY       6999.0
# 11     3.500321e+09               KIESTER OPERATING COMPANY       6999.0
# ...

# %% [markdown]
# #### Alias the csv files for ease of use
# ####quakes= pd.read_csv('C:/Users/SheuliMolla/Desktop/DEV LEAGUE/S5_Exploratory_Data_Analysis/okquakes.csv')
# ####wells= pd.read_csv('C:/Users/SheuliMolla/Desktop/DEV LEAGUE/S5_Exploratory_Data_Analysis/InjectionWells.csv')

# %%
quakes= pd.read_csv('C:/Users/SheuliMolla/Desktop/DEV LEAGUE/S5_Exploratory_Data_Analysis/okquakes.csv')
wells= pd.read_csv('C:/Users/SheuliMolla/Desktop/DEV LEAGUE/S5_Exploratory_Data_Analysis/InjectionWells.csv')

# %% [markdown]
# #### Figure out what you're working with
# ##### What kind of data do you have?
# ##### Check out the columns
# ##### Investigate the rows

# %%
quakes? ####The ? tells you a lot about the dataset

# %%
wells? ####The ? tells you a lot about the dataset

# %%
print (quakes.columns)
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
print (wells.columns)
# Out:
# Index(['API#', 'Operator', 'Operator ID', 'WellType', 'WellName', 'WellNumber',
#        'OrderNumbers', 'Approval Date', 'County', 'Sec', 'Twp', 'Rng', 'QQQQ',
#        'LAT', 'LONG', 'PSI', 'BBLS', 'ZONE', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20'],
#       dtype='object')

# %% [markdown]
# ##### Ask yourself what might be able to be compared between the datasets?
# --TIME from quakes and approval date from wells are both measures of time
# --PLACE quakes and wells each have a lat/long component, so they can be compared spacially
# -- Other variables of each dataset may be able to be expressed as functions of time or place

# %% [markdown]
# #### Come up with some questions based on what the data sets have in common
# --Is there a temporal correlation between injection well location and earthquakes?
# --Is there a spatial correlation between injection well location and earthquakes?

# %% [markdown]
# ---
# ## DAY 4: Tuesday (Week 2)
#
# #### Work in Progress Feedback
# *Feedback and ideas from my work in progress presentation *
#
# #### Work towards milestone 1
# *Work I did towards Milestone *
#
# #### Work towards milestone 2
# *Work I did towards Milestone *
#
# #### Work towards milestone 3
# *Work I did towards Milestone *

# %% [markdown]
# ## Concept 2

# %% [markdown]
# ## Concept 3

# %% [markdown]
# ## Concept 4

# %% [markdown]
# ## Concept 5
